# %%
##エスペラント文の文字形式の変換関数
esperanto_to_x = { "ĉ": "cx", "ĝ": "gx", "ĥ": "hx", "ĵ": "jx", "ŝ": "sx", "ŭ": "ux",
                   "Ĉ": "Cx", "Ĝ": "Gx", "Ĥ": "Hx", "Ĵ": "Jx", "Ŝ": "Sx", "Ŭ": "Ux",
                   "c^": "cx", "g^": "gx", "h^": "hx", "j^": "jx", "s^": "sx", "u^": "ux",
                    "C^": "Cx", "G^": "Gx", "H^": "Hx", "J^": "Jx", "S^": "Sx", "U^": "Ux"}
x_to_jijofu={'cx': 'ĉ', 'gx': 'ĝ', 'hx': 'ĥ', 'jx': 'ĵ', 'sx': 'ŝ', 'ux': 'ŭ', 'Cx': 'Ĉ',
             'Gx': 'Ĝ', 'Hx': 'Ĥ', 'Jx': 'Ĵ', 'Sx': 'Ŝ', 'Ux': 'Ŭ'}
x_to_hat={'cx': 'c^', 'gx': 'g^', 'hx': 'h^', 'jx': 'j^', 'sx': 's^', 'ux': 'u^', 'Cx': 'C^',
          'Gx': 'G^', 'Hx': 'H^', 'Jx': 'J^', 'Sx': 'S^', 'Ux': 'U^'}

def replace_esperanto_chars(text,letter_dictionary):
    for esperanto_char, x_char in letter_dictionary.items():
        text = text.replace(esperanto_char, x_char)
    return text
#テスト用のエスペラント文
# text = "Ĝis revido! Mia nomo estas Ĵoĥano. Ĉu vi ŝatas ĥorojn? -Ne, mi s^tas felic^on. C^ S^ H^ c^ s^ h^  Ĉ Ĝ  Gxis revido! Mia nomo estas Jxohxano. Cxu vi sxatas hxorojn? -Ne, mi sxtas felicxon. Cx Sx Hx cx sx hx  Cx Gx"
#エスペラント文の文字形式の変換
# replaced_text = replace_esperanto_chars(text,esperanto_to_x)
# replaced_text =replace_esperanto_chars(text,x_to_jijofu)
# replaced_text =replace_esperanto_chars(text,x_to_hat)
# print("元のテキスト:", text)
# print("置換後のテキスト:", replaced_text)

# %%
##まず、"世界语全部单词_大约44100个(原pejvo.txt).txt"を小文字、X形式に変換する。 (変換コード上では小文字、X形式で統一。)
with open("世界语全部单词_大约44100个(原pejvo.txt)_original2024620_utf8_2列目以降修正_2通りの分解修正__更に修正.txt", 'r', encoding='utf-8') as file:
    text = file.read()
    converted_text=replace_esperanto_chars(text,esperanto_to_x)#エスペラントの特殊文字を対応するx形式に変換。
    converted_text=converted_text.lower()#小文字に変換。

#結果を"tmp.txt"に書き出す。
with open('tmp.txt', 'w', encoding='utf-8') as file:
    file.write(converted_text)

# %%
import os
import re
def contains_digit(s):#対象の文字列sに数字となりうる文字列(数字)が含まれるかどうかを確認する関数
    return any(char.isdigit() for char in s)

result=[]
# "tmp.txt"("世界语全部单词_大约44100个(原pejvo.txt).txt"を小文字、X形式に変換したもの)を開く。
with open("tmp.txt", 'r', encoding='utf-8') as file:
    # "tmp.txt"の各行をループ。
    for line in file:
        # ':'が出てくるまでの部分を取り出す。
        line=line.replace('-','/')##20240618追加
        word = line.split(":")[0]
        word = word.lstrip('/')##日本版,1列目だけ
        # さらに取り出した部分を'-'、' '、','で分ける。","もごくまれに存在する('tial')
        parts = re.split('-| |,', word)
        # 各部分をループし、単語の語尾の形式によって品詞分類しながら、その語尾をカットする。
        for jj in range(len(parts)):
            if jj>=0:##1列目も2列目以降も
                part=parts[jj]
                if not (contains_digit(part) or len(part)<2):##2文字以上
                    if "/" in part:
                        if part.endswith(('/o','/on','oj','/o!','ojn','on!')):
                            AA=["/".join(part.split("/")[:-1])]
                            AA.append('名詞')
                        elif part.endswith(('/a','/aj','/an','/an!')):
                            AA=["/".join(part.split("/")[:-1])]
                            AA.append('形容詞')
                        elif part.endswith(('/e','/e!')):
                            AA=["/".join(part.split("/")[:-1])]
                            AA.append('副詞')
                        elif part.endswith(('/e/n','/e/n!')):##'/e/n'は後で気をつける
                            AA=["/".join(part.split("/")[:-2])]
                            AA.append('副詞')    
                        elif part.endswith(('/i','/u','/u!')):
                            AA=["/".join(part.split("/")[:-1])]
                            AA.append('動詞')
                        elif part.endswith(('/n')):
                            AA=["/".join(part.split("/")[:-1])]
                            AA.append('n語')            
                    else:
                        AA=[part,"無詞"]
                    result.append(AA)

# %%
##すべての単語の語尾が正しくカットされているかどうかチェックする。 ここまで情報は何一つ減っていないはず。
with open("检查世界语所有单词的结尾是否被正确切除(result).txt","w",encoding='utf-8') as g:
    for hh in result:
        if len(hh)==2:##不要な条件と思われる。
            g.write(hh[0]+','+hh[1]+"\n")
            # g.write(replace_esperanto_chars(hh[0],x_to_jijofu)+"##"+"\n")

# %%
##上の作業で抽出した、'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換するための、漢字置換リストを作成していく。
##"'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換し終えたリスト"こそが最終的な漢字置換リストの大元になる。
##'既に完全に語根分解された状態の単語'が対象であれば、文字数の多い語根順に漢字置換するだけで完璧な精度の漢字置換ができる!
##ただし、その完璧な漢字置換のためにはあらかじめ"世界语全部单词_大约44100个(原pejvo.txt).txt"から"从世界语全部单词_大约44100个(原pejvo.txt).txt中提取并输出世界语所有词根_大约11360个.txt_带中文日文注释.ipynb"を用いてエスペラントの全語根を抽出しておく必要がある。

replacements_dict={}##一旦辞書型を使う。(後で内容(value)を更新するため)
with open("世界语所有词根_大约11222个_20240621.txt", 'r', encoding='utf-8') as file:
# with open("世界语所有词根_大约11289个_20240619.txt", 'r', encoding='utf-8') as file:
    ##"世界语所有词根_大约11360个.txt"は"世界语全部单词_大约44100个(原pejvo.txt).txt"から"从世界语全部单词_大约44100个(原pejvo.txt).txt中提取并输出世界语所有词根_大约11360个.txt_带中文日文注释.ipynb"を用いて抽出したエスペラントの全語根である。
    roots = file.readlines()
    for root in roots:
        root = root.strip()
        if not root.isdigit():##混入していた数字の'10'と'7'を削除
            replacements_dict[root]=[root,len(root)]##各エスペラント語根に対する'置換後の単語'(この作業では元の置換対象の語根のまま)と、その置換順序として、'置換対象の語根の文字数'を設定。　置換順序の数字が大きい('置換対象の語根の文字数が多い')ほど、先に置換される仕組みにする。
len(replacements_dict)
# Out:
# 11141

# %%
##上の作業に引き続き、"'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換するための、漢字置換リスト"を作成していく。　
##ここでは漢字置換リストに自分で作成したエスペラント語根の漢字化リストを反映させる。

def conversion_format(hanzi, word, format_type):##変換形式を決める。
    if format_type == 'HTML Format':
        return '<ruby>{}<rt>{}</rt></ruby>'.format(hanzi, word)
    elif format_type == 'Parentheses Format':
        return '{}({})'.format(hanzi, word)
    elif format_type == 'Parentheses Format2':
        return '{}({})'.format(word, hanzi)
    elif format_type == 'Only Hanzi':
        return '{}'.format(hanzi)
    
# format_type='Parentheses Format'
# format_type='Parentheses Format2'
format_type='HTML Format'


# input_file="Ruby形式＿日本語.csv"
input_file="Ruby形式＿日本語.csv"

# input_file="世界语汉字表格_20240312.csv"
with open(input_file, 'r', encoding='utf-8') as file:
    for line in file:
        line = line.strip()
        j = line.split(',')
        if len(j)>=2:
            word,hanzi=j[0],j[1]
            if (hanzi!='') and (word!='') and ('#' not in word):
                replacements_dict[word]=[conversion_format(hanzi, word, format_type),len(word)]#辞書式配列では要素(key)に対する値(value)を後から更新できることを利用している。
# with open("replacements_dict.txt", 'w', encoding='utf-8') as file:
#     for old,new in replacements_dict.items():
#         file.write(f'{old},{new[0]},{new[1]}\n')

# %%
##'漢字置換リスト'を置換順序の数字の大きさ順にソート。
pre_replacements=[]
for old,new in replacements_dict.items():
    pre_replacements.append((old,new[0],new[1]))
pre_replacements3 = sorted(pre_replacements, key=lambda x: x[2], reverse=True)#x[2]がポイント
# pre_replacements3

# %%
##'漢字置換リスト'の各置換に対して'place holder'を追加し、'replacements'リストとして完成させた。
##'place holder'法とは、既に置換を終えた文字列が後続の置換によって重複して置換されてしまうことを避けるために、その置換を終えた部分に一時的に無関係な文字列(place holder)を置いておいて、
##全ての置換が終わった後に、改めてその'無関係な文字列(place holder)'から'目的の置換後文字列'に変換していく手法である。

with open('No.10000_500000.txt', 'r', encoding='utf-8') as file:##漢字置換時に用いる"place holder"ファイルを予め読み込んでおく。
    loaded_strings = [line.strip() for line in file]

replacements=[]
for kk in range(len(pre_replacements3)):
    replacements.append([pre_replacements3[kk][0],pre_replacements3[kk][1],loaded_strings[kk]])


##置換に用いる関数。正規表現、C++など様々な形式の置換を試したが、pythonで'place holder'を用いる形式の置換が、最も処理が高速であった。(しかも大変シンプルでわかりやすい。)
def safe_replace(text, replacements):
    valid_replacements = {}
    # 置換対象(old)を'place holder'に一時的に置換
    for old, new, placeholder in replacements:
        if old in text:
            text = text.replace(old, placeholder)
            valid_replacements[placeholder] = new# 後で置換後の文字列(new)に置換し直す必要がある'place holder'を辞書(valid_replacements)に記録しておく。
    #'place holder'を置換後の文字列(new)に置換)
    for placeholder, new in valid_replacements.items():
        text = text.replace(placeholder, new)
    return text



#replacementsリスト("'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換するための、漢字置換リスト"の完成版)の内容確認
with open("replacements_list.txt", 'w', encoding='utf-8') as file:
    for old,new,priority in replacements:
        file.write(f'{old},{new},{priority}\n')

# %%
len(result)
# Out:
# 50678

# %% [markdown]
# 以下の3つはスキップしても良い。(時間がかかるので)

# %%
##'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を実際にreplacementsリスト(漢字置換リストの完成版)によって漢字置換。　
##ここで作成される、"漢字置換し終えたリスト(辞書型)"(SS)が最終的な漢字置換リストの大元になる。
##リストresultまでは情報の損失は殆どないはず。

SS={}
for j in result:##20秒ほどかかる。　先にリストの要素を全て結合して、一つの文字列にしてから漢字置換する方法を試しても(上述)、さほど高速化しなかった。
    if len(j)==2:##(j[0]がエスペラント語根、j[1]が品詞。)
        if len(j[0])>=2:##2文字以上のエスペラント語根のみが対象
            if j[0] in SS:
                if j[1] not in SS[j[0]][1]:
                    SS[j[0]] = [SS[j[0]][0],SS[j[0]][1] + ', ' + j[1]]##複数品詞の追加
            else:
                SS[j[0]]=[safe_replace(j[0], replacements),j[1]]##辞書敷配列の追加法

# %%
# 上の作業で作成した辞書型リスト(SS)の最初から20個分を表示
for key, value in dict(list(SS.items())[:10]).items():
    print(f"{key}: {value}")
# Out:
# abak: ['abak', '名詞']
# abat/ec: ['<ruby>修道院長<rt>abat</rt></ruby>/<ruby>性質<rt>ec</rt></ruby>', '名詞']
# abat/ej: ['<ruby>修道院長<rt>abat</rt></ruby>/<ruby>場所<rt>ej</rt></ruby>', '名詞']
# abat/in: ['<ruby>修道院長<rt>abat</rt></ruby>/<ruby>女性<rt>in</rt></ruby>', '名詞']
# abat: ['<ruby>修道院長<rt>abat</rt></ruby>', '名詞']
# abdik: ['<ruby>退く<rt>abdik</rt></ruby>', '動詞, 名詞']
# abdomen: ['abdomen', '名詞']
# abel: ['<ruby>ミツバチ<rt>abel</rt></ruby>', '形容詞, 名詞']
# miel: ['<ruby>蜂蜜<rt>miel</rt></ruby>', '名詞, 形容詞']
# pik/il: ['<ruby>刺す<rt>pik</rt></ruby>/<ruby>道具<rt>il</rt></ruby>', '名詞']

# %%
with open("SS.txt", 'w', encoding='utf-8') as file:
    for old,new in  SS.items():
        file.write(f'{old},{new[0]},{new[1]}\n')

# %%
# # テキストファイルから辞書を再構築する
# テキストファイルから辞書を再構築する
SS = {}
with open("SS.txt", 'r', encoding='utf-8') as file:
    for line in file:
        # 各行をコンマで分割
        parts = line.strip().split(',')
        if len(parts)>=3:
            # parts[2:] のリストをカンマ区切りの文字列に変換
            parts_of_speech = ', '.join(part.strip() for part in parts[2:])
            # 分割したデータを辞書に追加（リストとして保存）
            SS[parts[0]] = [parts[1], parts_of_speech]##:がないと品詞が一つになってしまう。
# # 再構築された辞書の内容を表示
# for key, value in dict(list(reconstructed_dict.items())[:5]).items():
#     print(f"{key}: {value}")

# 上の作業で作成した辞書型リスト(SS)の最初から20個分を表示
for key, value in dict(list(SS.items())[:10]).items():
    print(f"{key}: {value}")
# Out:
# abak: ['abak', '名詞']
# abat/ec: ['<ruby>修道院長<rt>abat</rt></ruby>/<ruby>性質<rt>ec</rt></ruby>', '名詞']
# abat/ej: ['<ruby>修道院長<rt>abat</rt></ruby>/<ruby>場所<rt>ej</rt></ruby>', '名詞']
# abat/in: ['<ruby>修道院長<rt>abat</rt></ruby>/<ruby>女性<rt>in</rt></ruby>', '名詞']
# abat: ['<ruby>修道院長<rt>abat</rt></ruby>', '名詞']
# abdik: ['<ruby>退く<rt>abdik</rt></ruby>', '動詞, 名詞']
# abdomen: ['abdomen', '名詞']
# abel: ['<ruby>ミツバチ<rt>abel</rt></ruby>', '形容詞, 名詞']
# miel: ['<ruby>蜂蜜<rt>miel</rt></ruby>', '名詞, 形容詞']
# pik/il: ['<ruby>刺す<rt>pik</rt></ruby>/<ruby>道具<rt>il</rt></ruby>', '名詞']

# %%
# スラッシュを取り除いたキーでデータを整理するための辞書
normalized_keys = {}

# 各キーからスラッシュを取り除き、既存のキーとして整理
for old, value in SS.items():
    # スラッシュを取り除く
    normalized_key = old.replace('/', '')

    # 辞書に追加
    if normalized_key not in normalized_keys:
        normalized_keys[normalized_key] = []
    normalized_keys[normalized_key].append((old, value))

# 抜き出すためのファイル出力
with open("SS_chofuku.txt", 'w', encoding='utf-8') as file:
    for key, entries in normalized_keys.items():
        # 同じ語根を持つ要素が複数ある場合のみファイルに書き込む
        if len(entries) > 1:
            for old, value in entries:
                file.write(f'{old},{value[0]},{value[1]}\n')


# 各語根ごとに最長のキーを保持する辞書
max_length_keys = {}

# スラッシュを取り除いた語根をキーとして、最長のキーと値を保存
for old, value in SS.items():
    # スラッシュを取り除く
    normalized_key = old.replace('/', '')
    # 辞書にこの語根が存在するか、存在する場合は現在のキーと比較
    if normalized_key not in max_length_keys or len(max_length_keys[normalized_key][0]) < len(old):
        max_length_keys[normalized_key] = (old, value)

# 最終的な辞書を作成
SS_ = {k: v for _, (k, v) in max_length_keys.items()}

with open("SS.txt", 'w', encoding='utf-8') as file:
    for old,new in  SS.items():
        file.write(f'{old},{new[0]},{new[1]}\n')
    
with open("SS_.txt", 'w', encoding='utf-8') as file:
    for old,new in  SS_.items():
        file.write(f'{old},{new[0]},{new[1]}\n')
len(SS),len(SS_)
# 結果を出力
print(SS_)
##品詞によって分けることは可能か？20240616
# Out:
# {'abak': ['abak', '名詞'], 'abat/ec': ['<ruby>修道院長<rt>abat</rt></ruby>/<ruby>性質<rt>ec</rt></ruby>', '名詞'], 'abat/ej': ['<ruby>修道院長<rt>abat</rt></ruby>/<ruby>場所<rt>ej</rt></ruby>', '名詞'], 'abat/in': ['<ruby>修道院長<rt>abat</rt></ruby>/<ruby>女性<rt>in</rt></ruby>', '名詞'], 'abat': ['<ruby>修道院長<rt>abat</rt></ruby>', '名詞'], 'abdik': ['<ruby>退く<rt>abdik</rt></ruby>', '動詞, 名詞'], 'abdomen': ['abdomen', '名詞'], 'abel': ['<ruby>ミツバチ<rt>abel</rt></ruby>', '形容詞, 名詞'], 'miel': ['<ruby>蜂蜜<rt>miel</rt></ruby>', '名詞, 形容詞'], 'pik/il': ['<ruby>刺す<rt>pik</rt></ruby>/<ruby>道具<rt>il</rt></ruby>', '名詞'], 'abel/bred/ad': ['<ruby>ミツバチ<rt>abel</rt></ruby>/<ruby>飼育する<rt>bred</rt></ruby>/<ruby>行為<rt>ad</rt></ruby>', '名詞'], 'abel/bred/ist': ['<ruby>ミツバチ<rt>abel</rt></ruby>/<ruby>飼育する<rt>bred</rt></ruby>/<ruby>従事者<rt>ist</rt></ruby>', '名詞'], 'abel/bred': ['<ruby>ミツバチ<rt>abel</rt></ruby>/<ruby>飼育する<rt>bred</rt></ruby>', '名詞'], 'abel/ej': ['<ruby>ミツバチ<rt>abel</rt></ruby>/<ruby>場所<rt>ej</rt></ruby>', '名詞'], 'abel/in': ['<ruby>ミツバチ<rt>abel</rt></ruby>/<ruby>女性<rt>in</rt></ruby>', '名詞'], 'abel/ist': ['<ruby>ミツバチ<rt>abel</rt></ruby>/<ruby>従事者<rt>ist</rt></ruby>', '名詞'], 'abel/kest': ['<ruby>ミツバチ<rt>abel</rt></ruby>/<ruby>箱<rt>kest</rt></ruby>', '名詞'], 'abel/korb': ['<ruby>ミツバチ<rt>abel</rt></ruby>/<ruby>かご<rt>korb</rt></ruby>', '名詞'], 'abel/kultur': ['<ruby>ミツバチ<rt>abel</rt></ruby>/<ruby>栽培する<rt>kultur</rt></ruby>', '名詞'], 'abel/mangx/ul': ['<ruby>ミツバチ<rt>abel</rt></ruby>/<ruby>食べる<rt>mangx</rt></ruby>/<ruby>人<rt>ul</rt></ruby>', '名詞'], 'abel/regx/in': ['<ruby>ミツバチ<rt>abel</rt></ruby>/<ruby>王<rt>regx</rt></ruby>/<ruby>女性<rt>in</rt></ruby>', '名詞'], 'abel/svarm': ['<ruby>ミツバチ<rt>abel</rt></ruby>/<ruby>群がっている<rt>svarm</rt></ruby>', '名詞'], 'abel/uj': ['<ruby>ミツバチ<rt>abel</rt></ruby>/<ruby>容器<rt>uj</rt></ruby>', '名詞'], 'abel/vaks': ['<ruby>ミツバチ<rt>abel</rt></ruby>/<ruby>ワックス<rt>vaks</rt></ruby>', '名詞'], 'aberaci': ['aberaci', '名詞'], 'abhxaz/i': ['abhxaz/i', '名詞'], 'abi/ar': ['<ruby>モミ<rt>abi</rt></ruby>/<ruby>集団<rt>ar</rt></ruby>', '名詞'], 'abi': ['<ruby>モミ<rt>abi</rt></ruby>', '名詞'], 'abi/pice': ['<ruby>モミ<rt>abi</rt></ruby>/<ruby>トウヒ<rt>pice</rt></ruby>', '名詞'], 'abi/pingl': ['<ruby>モミ<rt>abi</rt></ruby>/<ruby>ピン<rt>pingl</rt></ruby>', '名詞'], 'abisen/i': ['abisen/i', '名詞'], 'abisen': ['abisen', '名詞'], 'abisen/uj': ['abisen/<ruby>容器<rt>uj</rt></ruby>', '名詞'], 'abism': ['<ruby>深淵<rt>abism</rt></ruby>', '形容詞, 名詞'], 'abiturient': ['<ruby>アビトゥリエント<rt>abiturient</rt></ruby>', '名詞'], 'ablativ': ['<ruby>奪格<rt>ablativ</rt></ruby>', '名詞'], 'abnegaci': ['<ruby>自己犠牲<rt>abnegaci</rt></ruby>', '動詞, 名詞'], 'aboc': ['aboc', '名詞'], 'aboc/o/libr': ['aboc/o/<ruby>本<rt>libr</rt></ruby>', '名詞'], 'abol': ['abol', '動詞'], 'abolici': ['abolici', '動詞, 名詞'], 'abolici/ism': ['abolici/<ruby>主義<rt>ism</rt></ruby>', '名詞'], 'abomen': ['<ruby>嫌悪<rt>abomen</rt></ruby>', '形容詞, 動詞, 名詞'], 'abomen/ajx': ['<ruby>嫌悪<rt>abomen</rt></ruby>/<ruby>事物<rt>ajx</rt></ruby>', '名詞'], 'kanajl': ['<ruby>ごろつき<rt>kanajl</rt></ruby>', '名詞'], 'abomen/ig': ['<ruby>嫌悪<rt>abomen</rt></ruby>/<ruby>させる<rt>ig</rt></ruby>', '動詞'], 'abomen/ind': ['<ruby>嫌悪<rt>abomen</rt></ruby>/<ruby>価値<rt>ind</rt></ruby>', '形容詞'], 'abomen/ind/ajx': ['<ruby>嫌悪<rt>abomen</rt></ruby>/<ruby>価値<rt>ind</rt></ruby>/<ruby>事物<rt>ajx</rt></ruby>', '名詞'], 'milit': ['<ruby>戦争する<rt>milit</rt></ruby>', '名詞, 形容詞, 動詞'], 'abon': ['<ruby>予約する<rt>abon</rt></ruby>', '形容詞, 動詞, 名詞'], 'mon': ['<ruby>金銭<rt>mon</rt></ruby>', '名詞, 形容詞'], 'abon/ant': ['<ruby>予約する<rt>abon</rt></ruby>/<ruby>能動・継続<rt>ant</rt></ruby>', '名詞'], 'abon/bilet': ['<ruby>予約する<rt>abon</rt></ruby>/<ruby>切符<rt>bilet</rt></ruby>', '名詞'], 'abon/ebl': ['<ruby>予約する<rt>abon</rt></ruby>/<ruby>可能<rt>ebl</rt></ruby>', '形容詞'], 'abon/help': ['<ruby>予約する<rt>abon</rt></ruby>/<ruby>手助けする<rt>help</rt></ruby>', '形容詞'], 'fondus': ['fondus', '名詞'], 'abon/il': ['<ruby>予約する<rt>abon</rt></ruby>/<ruby>道具<rt>il</rt></ruby>', '名詞'], 'abon/kotiz': ['<ruby>予約する<rt>abon</rt></ruby>/<ruby>払う<rt>kotiz</rt></ruby>', '名詞'], 'abon/pag': [' ...

# %%
len(SS)
# Out:
# 32045

# %%
##ここから、"'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換し終えたリスト(辞書型)"(SS)を最終的な漢字置換リストに成形していく。

# %%
##更改替换方式(关于如何更改汉字转换,请编辑第一个csv文件)  (置換の仕方の変更(漢字変換の仕方の変更については最初のcsvファイルを編集する))
# never_used_as_roots_only=[" vin "," lin "," min "," amas "]
# for i in never_used_as_roots_only:
#     SS[i]=[i,"無詞"]

# %%
##ここで、2通りの語根分解を消去していると考えられるが、品詞別に語根分解の方法を残すべきではないのか→日本語版の全単語語根分解リストについては解決。

## SS→QQ  ("'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換し終えたリスト"(SS)を最終的な漢字置換リストに成形していく。)
##SSの'置換対象の単語'、'漢字置換後の単語'から"/"を抜く(html形式にしたい場合、"</rt></ruby>"は"/"を含むので要注意！)。
##新たに置換優先順位を表す数字を追加し(漢字化する単語は'文字数×10000'、漢字化しない単語は'文字数×10000-2500')、辞書式配列QQとして保存。
QQ={}
for i,j in SS.items():##(iが置換対象の単語、j[0]が漢字置換後の単語、j[1]が品詞。)
    if i==j[0]:##漢字化しない単語
        QQ[i.replace('/', '')]=[j[0].replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),j[1],len(i.replace('/', ''))*10000-3000]##漢字化しない単語は優先順位を下げる
    else:
        QQ[i.replace('/', '')]=[j[0].replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),j[1],len(i.replace('/', ''))*10000]

# QQ
with open("QQ.txt", 'w', encoding='utf-8') as file:
    for old,new in  QQ.items():
        file.write(f'{old},{new[0]},{new[1]},{new[2]}\n')

# %%
# # 上の作業で作成した辞書型リスト(QQ)の最初から10個分を表示
# for key, value in dict(list(QQ.items())[:10]).items():
#     print(f"{key}: {value}")

# %%
### 基本的には動詞に対してのみ活用語尾を追加し、置換対象の単語の文字数を増やす(置換の優先順位を上げる。)

verb_suffix_2l={'as':'as', 'is':'is', 'os':'os', 'us':'us','at':'at','it':'it','ot':'ot', 'ad':'ad','igx':'igx','ig':'ig','ant':'ant','int':'int','ont':'ont'}
##接頭辞接尾時の追加については、主に動詞が対象である。
verb_suffix_2l_2={}
for d1,d2 in verb_suffix_2l.items():
    verb_suffix_2l_2[d1]=safe_replace(d2, replacements)

# %%
verb_suffix_2l_2
# Out:
# {'as': '<ruby>現在形<rt>as</rt></ruby>',
#  'is': '<ruby>過去形<rt>is</rt></ruby>',
#  'os': '<ruby>未来形<rt>os</rt></ruby>',
#  'us': '<ruby>条件法<rt>us</rt></ruby>',
#  'at': '<ruby>受動・継続<rt>at</rt></ruby>',
#  'it': '<ruby>受動・完了<rt>it</rt></ruby>',
#  'ot': '<ruby>受動・将然<rt>ot</rt></ruby>',
#  'ad': '<ruby>行為<rt>ad</rt></ruby>',
#  'igx': '<ruby>なる<rt>igx</rt></ruby>',
#  'ig': '<ruby>させる<rt>ig</rt></ruby>',
#  'ant': '<ruby>能動・継続<rt>ant</rt></ruby>',
#  'int': '<ruby>能動・完了<rt>int</rt></ruby>',
#  'ont': '<ruby>能動・将然<rt>ont</rt></ruby>'}

# %%
# RR={}
# # 辞書をコピーする
# QQ_copy = QQ.copy()
# for i,j in QQ_copy.items():##j[0]:置換後の文字列　j[1]:品詞 j[2]:置換優先順位
#     if (j[1] == "名詞") and (len(i)<=6) and not(j[2]==60000 or j[2]==50000 or j[2]==40000 or j[2]==30000 or j[2]==20000):##名詞だけで、6文字以下で、漢字化しないやつ  ##置換ミスを防ぐための条件(20240614) altajo,aviso,malm,abes 固有名詞対策  意味ふりがなのときは再検討
#         for k in ["o"]:##4 ['buro', 'haloo', 'tauxro', 'unesko']
#             if not i+k in QQ_copy:##if not ありのままで良い。
#                 RR[i+k]=[j[0]+k,j[2]+len(k)*10000-2000]#実質5000 #既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
#         QQ.pop(i, None)

# for i,j in QQ.items():##j[0]:置換後の文字列　j[1]:品詞 j[2]:置換優先順位
#     if j[2]==20000:##2文字で漢字化するやつ##len(i)<=2:#1文字は存在しないはずではある。
#         ##基本的に非動詞の2文字の語根単体を以て漢字置換することはない。　ただし、世界语全部单词_大约44100个(原pejvo.txt).txtに最初から含まれている2文字の語根は既に漢字化されており、実際の漢字置換にも反映されることになる。
#         ##2文字の語根でも、動詞については活用語尾を追加することで、自動的に+2文字以上できるので追加した。
#         if "名詞" in j[1]:
#             for k in ["o","on",'oj']:##"ojn"は不要か
#                 if not i+k in QQ:
#                     RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
#         if "形容詞" in j[1]:
#             for k in ["a","aj",'an']:##"ajn"は不要か  ##sia pian
#                 # if not i+k in QQ:##if not なしのほうが良い
#                 RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
#         if "副詞" in j[1]:
#             for k in ["e",'en']:##ege   エーゲ海を意味するegeoを元の辞書に追加
#                 # if not i+k in QQ:##if not なしのほうが良い
#                 RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
#         if "動詞" in j[1]:
#             for k1,k2 in verb_suffix_2l_2.items():
#                 if not i+k1 in QQ:
#                     RR[i+k1]=[j[0]+k2,j[2]+len(k1)*10000-3000]
#             for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。["u ","u!","u?","u.","u,","i ","i.","i?","i,","i!"]
#                 if not i+k in QQ:
#                     RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-3000]
#         continue

#     else:
#         RR[i]=[j[0],j[2]]##品詞情報はここで用いるためにあった。以後は不要なので省いていく。
#         if j[2]==60000 or j[2]==50000 or j[2]==40000 or j[2]==30000:##文字数が比較的少なく(<=5)、実際に漢字化するエスペラント語根(文字数×10000)のみを対象とする 
#             if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
#                 for k in ["o","oj"]:
#                     if not i+k in QQ:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
#             if "形容詞" in j[1]:
#                 for k in ["a","aj",'an']:
#                     if not i+k in QQ:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
#             if "副詞" in j[1]:
#                 for k in ["e",'en']:
#                     if not i+k in QQ:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
#             if "動詞" in j[1]:
#                 for k1,k2 in verb_suffix_2l_2.items():
#                     if not i+k1 in QQ:
#                         RR[i+k1]=[j[0]+k2,j[2]+len(k1)*10000-3000]
#                 for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。 premi premio
#                     if not i+k in QQ:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                        
#         elif len(i)>=3 and len(i)<=6:##3文字から6文字の語根で漢字化しないもの　　結局2文字の語根で漢字化しないものについては、完全に除外している。
#             if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
#                 for k in ["o"]:
#                     if not i+k in QQ:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]#実質3000#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
#             if "形容詞" in j[1]:
#                 for k in ["a"]:
#                     if not i+k in QQ:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
#             if "副詞" in j[1]:
#                 for k in ["e"]:
#                     if not i+k in QQ:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
#             if "動詞" in j[1]:
#                 for k1,k2 in verb_suffix_2l_2.items():
#                     if not i+k1 in QQ:
#                         RR[i+k1]=[j[0]+k2,j[2]+(len(k1)-1)*10000-5000]
#                 for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
#                     if not i+k in QQ:
#                         RR[i+k]=[j[0]+k,j[2]+(len(k)-1)*10000-5000]
        
#         elif  i in ["regulus","kolorad","satirus","spirant","traktat","akirant","ordinat"]:#7文字以上の例外処理
#             if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
#                 for k in ["o"]:
#                     if not i+k in QQ:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]#実質3000#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
#             if "形容詞" in j[1]:
#                 for k in ["a"]:
#                     if not i+k in QQ:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
#             if "副詞" in j[1]:
#                 for k in ["e"]:
#                     if not i+k in QQ:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
#             if "動詞" in j[1]:
#                 for k1,k2 in verb_suffix_2l_2.items():
#                     if not i+k1 in QQ:
#                         RR[i+k1]=[j[0]+k2,j[2]+(len(k1)-1)*10000-5000]
#                 for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
#                     if not i+k in QQ:
#                         RR[i+k]=[j[0]+k,j[2]+(len(k)-1)*10000-5000]

# %%
###一番の工夫ポイント(如何にして置換の優先順位を定め、置換精度を向上させるか。)
##基本は単語の文字数が多い順に置換していくことになるが、
##例えば、"置換対象の単語に接頭辞、接尾辞を追加し、単語の文字数を増やし、置換の優先順位を上げたものを、置換対象の単語として新たに追加する。"などが、置換精度を上げる方策として考えられる。
##しかし、いろいろ試した結果、動詞に対してのみ活用語尾を追加し、置換対象の単語の文字数を増やす(置換の優先順位を上げる。)のが、ベストに近いことがわかった。

## SS→QQ→RR  ("'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換し終えたリスト"(SS)を最終的な漢字置換リストに成形していく。)
### if not i+k in QQ:の働きを調べる。 
### if not i+k in QQ:の働きを調べる。 
UU_0,UU,VV,WW=[],[],[],[]
UU_2,VV_2,WW_2,XX=[],[],[],[]
XXX=[]
RR={}
kosu_1,kosu_2,kosu_3,kosu_4,kosu_5=0,0,0,0,0
kei_1,kei_2,kei_3,kei_4=0,0,0,0
# 辞書をコピーする
QQ_copy = QQ.copy()##これがあるので、2回繰り返しするときは数個前のセルに戻ってQQを作り直してからでないといけない。
for i,j in QQ_copy.items():##j[0]:置換後の文字列　j[1]:品詞 j[2]:置換優先順位
    if (j[1] == "名詞") and (len(i)<=6) and not(j[2]==60000 or j[2]==50000 or j[2]==40000 or j[2]==30000 or j[2]==20000):##名詞だけで、6文字以下で、漢字化しないやつ  ##置換ミスを防ぐための条件(20240614) altajo,aviso,malm,abes 固有名詞対策  意味ふりがなのときは再検討
        for k in ["o"]:##4 ['buro', 'haloo', 'tauxro', 'unesko']
            if not i+k in QQ_copy:##if not ありのままで良い。
                RR[i+k]=[j[0]+k,j[2]+len(k)*10000-2000]#実質5000 #既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
                kosu_1+=1
        QQ.pop(i, None)

for i,j in QQ.items():##j[0]:置換後の文字列　j[1]:品詞 j[2]:置換優先順位
    if j[2]==20000:##2文字で漢字化するやつ##len(i)<=2:#1文字は存在しないはずではある。
        ##基本的に非動詞の2文字の語根単体を以て漢字置換することはない。　ただし、世界语全部单词_大约44100个(原pejvo.txt).txtに最初から含まれている2文字の語根は既に漢字化されており、実際の漢字置換にも反映されることになる。
        ##2文字の語根でも、動詞については活用語尾を追加することで、自動的に+2文字以上できるので追加した。
        if "名詞" in j[1]:
            for k in ["o","on",'oj']:##"ojn"は不要か
                if not i+k in RR:
                    RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
                if (i+k in RR):
                    UU.append([i+k,RR[i+k][0],j[0]+k])
        if "形容詞" in j[1]:
            for k in ["a","aj",'an']:##"ajn"は不要か  ##sia pian ,'an 'も不要
                # if not i+k in QQ:##if not なしのほうが良い
                RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
                # else:
                #     UU.append(i+k)
            kei_1+=1
        if "副詞" in j[1]:
            for k in ["e",'en']:##ege   エーゲ海を意味するegeoを元の辞書に追加
                # if not i+k in QQ:##if not なしのほうが良い
                RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
                # else:
                # UU.append(i+k)
        if "動詞" in j[1]:
            for k1,k2 in verb_suffix_2l_2.items():
                if not i+k1 in RR:
                    RR[i+k1]=[j[0]+k2,j[2]+len(k1)*10000-3000]
                if (i+k1 in RR) and (j[0]+k2 != RR[i+k1][0]):
                    UU_2.append([i+k1,RR[i+k1][0],j[0]+k2])##該当なし
            for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                if not i+k in RR:
                    RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                    UU_2.append([i+k,RR[i+k][0],j[0]+k])##該当なし
        kosu_2+=1
        continue

    else:
        if (i in RR) and (j[0] != RR[i][0]):
            XXX.append([i,RR[i][0],j[0]])##該当なし
        RR[i]=[j[0],j[2]]##品詞情報はここで用いるためにあった。以後は不要なので省いていく。
        if j[2]==60000 or j[2]==50000 or j[2]==40000 or j[2]==30000:##文字数が比較的少なく(<=5)、実際に漢字化するエスペラント語根(文字数×10000)のみを対象とする 
            if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
                for k in ["o","on",'oj']:
                    if not i+k in RR:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        VV.append([i+k,RR[i+k][0],j[0]+k])##該当なし
            if "形容詞" in j[1]:
                for k in ["a","aj",'an']:
                    if not i+k in RR:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        VV.append([i+k,RR[i+k][0],j[0]+k])##該当なし
                kei_2+=1
            if "副詞" in j[1]:
                for k in ["e",'en']:
                    if not i+k in RR:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        VV.append([i+k,RR[i+k][0],j[0]+k])##該当なし
            if "動詞" in j[1]:
                for k1,k2 in verb_suffix_2l_2.items():
                    if not i+k1 in RR:
                        RR[i+k1]=[j[0]+k2,j[2]+len(k1)*10000-3000]
                    if (i+k1 in RR) and (j[0]+k2 != RR[i+k1][0]):
                        VV_2.append([i+k1,RR[i+k1][0],j[0]+k2])##該当なし
                for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                    if not i+k in RR:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        VV_2.append([i+k,RR[i+k][0],j[0]+k])##該当なし
            kosu_3+=1            
        elif len(i)>=3 and len(i)<=6:##3文字から6文字の語根で漢字化しないもの　　結局2文字の語根で漢字化しないものについては、完全に除外している。
            if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
                for k in ["o","on",'oj']:
                    if not i+k in RR:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]#実質3000#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        WW.append([i+k,RR[i+k][0],j[0]+k])##該当なし
            if "形容詞" in j[1]:
                for k in ["a","aj",'an']:
                    if not i+k in RR:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        WW.append([i+k,RR[i+k][0],j[0]+k])##該当なし
                kei_3+=1
            if "副詞" in j[1]:
                for k in ["e",'en']:
                    if not i+k in RR:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        WW.append([i+k,RR[i+k][0],j[0]+k])##該当なし
            if "動詞" in j[1]:
                for k1,k2 in verb_suffix_2l_2.items():
                    if not i+k1 in RR:
                        RR[i+k1]=[j[0]+k2,j[2]+(len(k1)-1)*10000-5000]
                    if (i+k1 in RR) and (j[0]+k2 != RR[i+k1][0]):
                        WW_2.append([i+k1,RR[i+k1][0],j[0]+k2])##該当なし
                for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                    if not i+k in RR:
                        RR[i+k]=[j[0]+k,j[2]+(len(k)-1)*10000-5000]
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        WW_2.append([i+k,RR[i+k][0],j[0]+k])##該当なし
            kosu_4+=1
        elif  i in ["regulus","kolorad","satirus","spirant","traktat","akirant","ordinat"]:#7文字以上の例外処理
            if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
                for k in ["o"]:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]#実質3000#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        WW_2.append([i+k,RR[i+k][0],j[0]+k])##該当なし
            if "形容詞" in j[1]:
                for k in ["a"]:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        WW_2.append([i+k,RR[i+k][0],j[0]+k])##該当なし
            if "副詞" in j[1]:
                for k in ["e"]:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        WW_2.append([i+k,RR[i+k][0],j[0]+k])##該当なし
            if "動詞" in j[1]:
                for k1,k2 in verb_suffix_2l_2.items():
                    if not i+k1 in QQ:
                        RR[i+k1]=[j[0]+k2,j[2]+(len(k1)-1)*10000-5000]
                    if (i+k1 in RR) and (j[0]+k2 != RR[i+k1][0]):
                        WW_2.append([i+k1,RR[i+k1][0],j[0]+k2])##該当なし
                for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+(len(k)-1)*10000-5000]
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        WW_2.append([i+k,RR[i+k][0],j[0]+k])##該当なし
            kosu_5+=1
print(len(UU_0),UU_0)
print(len(UU),UU)
print(len(VV),VV)
print(len(WW),WW)

print(len(UU_2),UU_2)
print(len(VV_2),VV_2)
print(len(WW_2),WW_2)
print(len(XX),XX)
print(len(XXX),XXX)
print(kosu_1,kosu_2,kosu_3,kosu_4,kosu_5)
print(kei_1,kei_2,kei_3)
# Out:
# 0 []
# 1 [['duon', '<ruby>二<rt>du</rt></ruby><ruby>分数<rt>on</rt></ruby>', '<ruby>二<rt>du</rt></ruby>on']]
# 8 [['ordon', '<ruby>命令する<rt>ordon</rt></ruby>', '<ruby>順序<rt>ord</rt></ruby>on'], ['teren', '<ruby>地所<rt>teren</rt></ruby>', '<ruby>土地<rt>ter</rt></ruby>en'], ['kanon', '<ruby>大砲<rt>kanon</rt></ruby>', '<ruby>アシ<rt>kan</rt></ruby>on'], ['kolon', '<ruby>円柱<rt>kolon</rt></ruby>', '<ruby>首<rt>kol</rt></ruby>on'], ['komision', '<ruby>委員会<rt>komision</rt></ruby>', '<ruby>委託する<rt>komisi</rt></ruby>on'], ['menton', '<ruby>下あご<rt>menton</rt></ruby>', '<ruby>ハッカ<rt>ment</rt></ruby>on'], ['samo', 'samo', '<ruby>同一の<rt>sam</rt></ruby>o'], ['saten', '<ruby>サテン<rt>saten</rt></ruby>', '<ruby>満腹した<rt>sat</rt></ruby>en']]
# 3 [['budhan', 'budh<ruby>会員<rt>an</rt></ruby>', 'budhan'], ['roman', '<ruby>長編小説<rt>roman</rt></ruby>', 'roman'], ['person', '<ruby>人<rt>person</rt></ruby>', 'person']]
# 1 [['amas', '<ruby>集積<rt>amas</rt></ruby>', '<ruby>愛する<rt>am</rt></ruby><ruby>現在形<rt>as</rt></ruby>']]
# 26 [['akirant', 'akirant', '<ruby>獲得する<rt>akir</rt></ruby><ruby>能動・継続<rt>ant</rt></ruby>'], ['statu', '<ruby>立像<rt>statu</rt></ruby>', '<ruby>状態<rt>stat</rt></ruby>u'], ['devi', 'devi', '<ruby>しなければならない<rt>dev</rt></ruby>i'], ['diplomat', '<ruby>外交官<rt>diplomat</rt></ruby>', '<ruby>免状<rt>diplom</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['pensi', '<ruby>年金<rt>pensi</rt></ruby>', '<ruby>思う<rt>pens</rt></ruby>i'], ['konus', '<ruby>円錐<rt>konus</rt></ruby>', '<ruby>知っている<rt>kon</rt></ruby><ruby>条件法<rt>us</rt></ruby>'], ['salat', '<ruby>サラダ<rt>salat</rt></ruby>', '<ruby>塩<rt>sal</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['konsili', 'konsili', '<ruby>助言する<rt>konsil</rt></ruby>i'], ['legat', '<ruby>教皇特使<rt>legat</rt></ruby>', '<ruby>読む<rt>leg</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['legi', '<ruby>軍団<rt>legi</rt></ruby>', '<ruby>読む<rt>leg</rt></ruby>i'], ['lekant', '<ruby>マーガレット<rt>lekant</rt></ruby>', '<ruby>なめる<rt>lek</rt></ruby><ruby>能動・継続<rt>ant</rt></ruby>'], ['licenci', 'licenci', '<ruby>認可<rt>licenc</rt></ruby>i'], ['lotus', '<ruby>ハス<rt>lotus</rt></ruby>', '<ruby>くじ<rt>lot</rt></ruby><ruby>条件法<rt>us</rt></ruby>'], ['patos', '<ruby>パトス<rt>patos</rt></ruby>', '<ruby>フライパン<rt>pat</rt></ruby><ruby>未来形<rt>os</rt></ruby>'], ['revu', '<ruby>専門雑誌<rt>revu</rt></ruby>', '<ruby>空想する<rt>rev</rt></ruby>u'], ['predikat', '<ruby>述部<rt>predikat</rt></ruby>', '<ruby>説教する<rt>predik</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['rabat', '<ruby>割引<rt>rabat</rt></ruby>', '<ruby>強奪する<rt>rab</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['religi', '<ruby>宗教<rt>religi</rt></ruby>', '<ruby>再び<rt>re</rt></ruby><ruby>結ぶ<rt>lig</rt></ruby>i'], ['sekci', '<ruby>部<rt>sekci</rt></ruby>', '<ruby>切断する<rt>sekc</rt></ruby>i'], ['sendat', '<ruby>なしで<rt>sen</rt></ruby><ruby>日付<rt>dat</rt></ruby>', '<ruby>送る<rt>send</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['spirit', '<ruby>精神<rt>spirit</rt></ruby>', '<ruby>呼吸する<rt>spir</rt></ruby><ruby>受動・完了<rt>it</rt></ruby>'], ['spirant', 'spirant', '<ruby>呼吸する<rt>spir</rt></ruby><ruby>能動・継続<rt>ant</rt></ruby>'], ['tenis', 'tenis', '<ruby>支え持つ<rt>ten</rt></ruby><ruby>過去形<rt>is</rt></ruby>'], ['traktat', '<ruby>条約<rt>traktat</rt></ruby>', '<ruby>取り扱う<rt>trakt</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['vaku', 'vaku', '<ruby>あいている<rt>vak</rt></ruby>u'], ['vizit', '<ruby>訪問する<rt>vizit</rt></ruby>', '<ruby>ビザ<rt>viz</rt></ruby><ruby>受動・完了<rt>it</rt></ruby>']]
# 4 [['arogant', '<ruby>横柄な<rt>arogant</rt></ruby>', 'arog<ruby>能動・継続<rt>ant</rt></ruby>'], ['brokant', '<ruby>古物売買する<rt>brokant</rt></ruby>', 'brok<ruby>能動・継続<rt>ant</rt></ruby>'], ['ferlad', '<ruby>鉄<rt>fer</rt></ruby><ruby>ブリキ板<rt>lad</rt></ruby>', 'ferl<ruby>行為<rt>ad</rt></ruby>'], ['ordinat', 'ordinat', 'ordin<ruby>受動・継続<rt>at</rt></ruby>']]
# 0 []
# 229 [['afrikan', '<ruby>アフリカ<rt>afrik</rt></ruby>an', '<ruby>アフリカ<rt>afrik</rt></ruby><ruby>会員<rt>an</rt></ruby>'], ['agat', '<ruby>行動する<rt>ag</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>', '<ruby>メノウ<rt>agat</rt></ruby>'], ['agit', '<ruby>行動する<rt>ag</rt></ruby><ruby>受動・完了<rt>it</rt></ruby>', '<ruby>扇動する<rt>agit</rt></ruby>'], ['agxi', '<ruby>年齢<rt>agx</rt></ruby>i', '<ruby>打ち歩<rt>agxi</rt></ruby>'], ['akcian', '<ruby>株式<rt>akci</rt></ruby>an', '<ruby>株式<rt>akci</rt></ruby><ruby>会員<rt>an</rt></ruby>'], ['aldon', '<ruby>アルト<rt>ald</rt></ruby>on', '<ruby>～の方へ<rt>al</rt></ruby><ruby>与える<rt>don</rt></ruby>'], ['alte', '<ruby>高い<rt>alt</rt></ruby>e', '<ruby>タチアオイ<rt>alte</rt></ruby>'], ['karbon', '<ruby>炭<rt>karb</rt></ruby>on', '<ruby>炭素<rt>karbon</rt></ruby>'], ['aparten', '<ruby>別々の<rt>apart</rt></ruby>en', '<ruby>所属する<rt>aparten</rt></ruby>'], ['apoge', '<ruby>支える<rt>apog</rt></ruby>e', '<ruby>遠地点<rt>apoge</rt></ruby>'], ['asocian', '<ruby>協会<rt>asoci</rt></ruby>an', '<ruby>協会<rt>asoci</rt></ruby><ruby>会員<rt>an</rt></ruby>'], ['azian', '<ruby>アジア<rt>azi</rt></ruby>an', '<ruby>アジア<rt>azi</rt></ruby><ruby>会員<rt>an</rt></ruby>'], ['balon', '<ruby>舞踏会<rt>bal</rt></ruby>on', '<ruby>気球<rt>balon</rt></ruby>'], ['bari', '<ruby>障害<rt>bar</rt></ruby>i', 'bari'], ['baron', '<ruby>障害<rt>bar</rt></ruby>on', '<ruby>男爵<rt>baron</rt></ruby>'], ['baston', '<ruby>じん皮<rt>bast</rt></ruby>on', '<ruby>棒<rt>baston</rt></ruby>'], ['beton', '<ruby>ビート<rt>bet</rt></ruby>on', 'beton'], ['bombon', '<ruby>爆弾<rt>bomb</rt></ruby>on', '<ruby>キャンデー<rt>bombon</rt></ruby>'], ['brazilan', 'brazilan', 'brazil<ruby>会員<rt>an</rt></ruby>'], ['breton', '<ruby>棚<rt>bret</rt></ruby>on', 'breton'], ['burgxon', '<ruby>ブルジョワ<rt>burgx</rt></ruby>on', '<ruby>芽<rt>burgxon</rt></ruby>'], ['centon', '<ruby>百<rt>cent</rt></ruby>on', '<ruby>百<rt>cent</rt></ruby><ruby>分数<rt>on</rt></ruby>'], ['ciklon', '<ruby>周期<rt>cikl</rt></ruby>on', '<ruby>低気圧<rt>ciklon</rt></ruby>'], ['citron', '<ruby>チター<rt>citr</rt></ruby>on', '<ruby>シトロン<rt>citron</rt></ruby>'], ['dekan', '<ruby>十<rt>dek</rt></ruby>an', '<ruby>学部長<rt>dekan</rt></ruby>'], ['dekon', '<ruby>十<rt>dek</rt></ruby>on', '<ruby>十<rt>dek</rt></ruby><ruby>分数<rt>on</rt></ruby>'], ['dezertan', '<ruby>砂漠<rt>dezert</rt></ruby>an', '<ruby>砂漠<rt>dezert</rt></ruby><ruby>会員<rt>an</rt></ruby>'], ['platon', '<ruby>平たい<rt>plat</rt></ruby>on', 'platon'], ['dietan', '<ruby>規定食<rt>diet</rt></ruby>an', '<ruby>規定食<rt>diet</rt></ruby><ruby>会員<rt>an</rt></ruby>'], ['diskont', '<ruby>円盤<rt>disk</rt></ruby><ruby>能動・将然<rt>ont</rt></ruby>', '<ruby>手形割引する<rt>diskont</rt></ruby>'], ['doman', '<ruby>家<rt>dom</rt></ruby>an', '<ruby>家<rt>dom</rt></ruby><ruby>会員<rt>an</rt></ruby>'], ['domen', '<ruby>家<rt>dom</rt></ruby>en', '<ruby>ドミノ<rt>domen</rt></ruby>'], ['dragon', 'dragon', '<ruby>竜騎兵<rt>dragon</rt></ruby>'], ['drakon', '<ruby>竜<rt>drak</rt></ruby>on', 'drakon'], ['premi', '<ruby>押える<rt>prem</rt></ruby>i', '<ruby>賞品<rt>premi</rt></ruby>'], ['egiptan', 'egiptan', 'egipt<ruby>会員<rt>an</rt></ruby>'], ['eklezian', '<ruby>教会<rt>eklezi</rt></ruby>an', '<ruby>教会<rt>eklezi</rt></ruby><ruby>会員<rt>an</rt></ruby>'], ['elektron', '<ruby>電気<rt>elektr</rt></ruby>on', 'elektron'], ['endos', '<ruby>必要<rt>end</rt></ruby><ruby>未来形<rt>os</rt></ruby>', 'endos'], ['enlandan', '<ruby>中で<rt>en</rt></ruby><ruby>国<rt>land</rt></ruby>an', '<ruby>中で<rt>en</rt></ruby><ruby>国<rt>land</rt></ruby><ruby>会員<rt>an</rt></ruby>'], ['epikuran', 'epikuran', 'epikur<ruby>会員<rt>an</rt></ruby>'], ['eskadron', '<ruby>艦隊<rt>eskadr</rt></ruby>on', 'eskadron'], ['esperant', '<ruby>希望する<rt>esper</rt></ruby><ruby>能動・継続<rt>ant</rt></ruby>', '<ruby>エスペラント<rt>esperant</rt></ruby>'], ['eston', '<ruby>である<rt>est</rt></ruby>on', 'eston'], ['estraran', '<ruby>長<rt>estr</rt></ruby><ruby>集団<rt>ar</rt></ruby>an', '<ruby>長<rt>estr</rt></ruby><ruby>集団<rt>ar</rt></ruby><ruby>会員<rt>an</rt></ruby>'], ['etnan', '<ruby>民族<rt>etn</rt></ruby>an', '<ruby>民族<rt>etn</rt></ruby><ruby>会員<rt>an</rt></ruby>'], ['euxropan', '<ruby>ヨー ...
# 2601 72 6982 1007 7
# 25 1967 520

# %%
###一番の工夫ポイント(如何にして置換の優先順位を定め、置換精度を向上させるか。)
##基本は単語の文字数が多い順に置換していくことになるが、
##例えば、"置換対象の単語に接頭辞、接尾辞を追加し、単語の文字数を増やし、置換の優先順位を上げたものを、置換対象の単語として新たに追加する。"などが、置換精度を上げる方策として考えられる。
##しかし、いろいろ試した結果、動詞に対してのみ活用語尾を追加し、置換対象の単語の文字数を増やす(置換の優先順位を上げる。)のが、ベストに近いことがわかった。

## SS→QQ→RR  ("'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換し終えたリスト"(SS)を最終的な漢字置換リストに成形していく。)
### if not i+k in QQ:の働きを調べる。 
### if not i+k in QQ:の働きを調べる。 
UU_0,UU,VV,WW=[],[],[],[]
UU_2,VV_2,WW_2,XX=[],[],[],[]
XXX=[]
RR={}
kosu_1,kosu_2,kosu_3,kosu_4,kosu_5=0,0,0,0,0
kei_1,kei_2,kei_3,kei_4=0,0,0,0
# 辞書をコピーする
QQ_copy = QQ.copy()##これがあるので、2回繰り返しするときは数個前のセルに戻ってQQを作り直してからでないといけない。
for i,j in QQ_copy.items():##j[0]:置換後の文字列　j[1]:品詞 j[2]:置換優先順位
    if (j[1] == "名詞") and (len(i)<=6) and not(j[2]==60000 or j[2]==50000 or j[2]==40000 or j[2]==30000 or j[2]==20000):##名詞だけで、6文字以下で、漢字化しないやつ  ##置換ミスを防ぐための条件(20240614) altajo,aviso,malm,abes 固有名詞対策  意味ふりがなのときは再検討
        for k in ["o"]:##4 ['buro', 'haloo', 'tauxro', 'unesko']
            if not i+k in QQ_copy:##if not ありのままで良い。
                RR[i+k]=[j[0]+k,j[2]+len(k)*10000-2000]#実質5000 #既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
                kosu_1+=1
            if (i+k in RR) and (j[0]+k != RR[i+k][0]):##該当なし
                UU_0.append([i+k,QQ_copy[i+k][0],j[0]+k])
                kosu_1+=1
        QQ.pop(i, None)

for i,j in QQ.items():##j[0]:置換後の文字列　j[1]:品詞 j[2]:置換優先順位
    if j[2]==20000:##2文字で漢字化するやつ##len(i)<=2:#1文字は存在しないはずではある。
        ##基本的に非動詞の2文字の語根単体を以て漢字置換することはない。　ただし、世界语全部单词_大约44100个(原pejvo.txt).txtに最初から含まれている2文字の語根は既に漢字化されており、実際の漢字置換にも反映されることになる。
        ##2文字の語根でも、動詞については活用語尾を追加することで、自動的に+2文字以上できるので追加した。
        if "名詞" in j[1]:
            for k in ["o","on",'oj']:##"ojn"は不要か
                if not i+k in QQ:
                    RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
                if (i+k in RR):
                    UU.append([i+k,QQ[i+k][0],j[0]+k])
        if "形容詞" in j[1]:
            for k in ["a","aj",'an']:##"ajn"は不要か  ##sia pian ,'an 'も不要
                # if not i+k in QQ:##if not なしのほうが良い
                RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
                # else:
                #     UU.append(i+k)
            kei_1+=1
        if "副詞" in j[1]:
            for k in ["e",'en']:##ege   エーゲ海を意味するegeoを元の辞書に追加
                # if not i+k in QQ:##if not なしのほうが良い
                RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
                # else:
                # UU.append(i+k)
        if "動詞" in j[1]:
            for k1,k2 in verb_suffix_2l_2.items():
                if not i+k1 in QQ:
                    RR[i+k1]=[j[0]+k2,j[2]+len(k1)*10000-3000]
                if (i+k1 in RR) and (j[0]+k2 != RR[i+k1][0]):
                    UU_2.append([i+k1,QQ[i+k1][0],j[0]+k2])##該当なし
            for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                if not i+k in QQ:
                    RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                    UU_2.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
        kosu_2+=1
        continue

    else:
        if (i in RR) and (j[0] != RR[i][0]):
            XXX.append([i,RR[i][0],j[0]])##該当なし
        RR[i]=[j[0],j[2]]##品詞情報はここで用いるためにあった。以後は不要なので省いていく。
        if j[2]==60000 or j[2]==50000 or j[2]==40000 or j[2]==30000:##文字数が比較的少なく(<=5)、実際に漢字化するエスペラント語根(文字数×10000)のみを対象とする 
            if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
                for k in ["o","on",'oj']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        VV.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            if "形容詞" in j[1]:
                for k in ["a","aj",'an']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        VV.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
                kei_2+=1
            if "副詞" in j[1]:
                for k in ["e",'en']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        VV.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            if "動詞" in j[1]:
                for k1,k2 in verb_suffix_2l_2.items():
                    if not i+k1 in QQ:
                        RR[i+k1]=[j[0]+k2,j[2]+len(k1)*10000-3000]
                    if (i+k1 in RR) and (j[0]+k2 != RR[i+k1][0]):
                        VV_2.append([i+k1,QQ[i+k1][0],j[0]+k2])##該当なし
                for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        VV_2.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            kosu_3+=1            
        elif len(i)>=3 and len(i)<=6:##3文字から6文字の語根で漢字化しないもの　　結局2文字の語根で漢字化しないものについては、完全に除外している。
            if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
                for k in ["o","on",'oj']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]#実質3000#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        WW.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            if "形容詞" in j[1]:
                for k in ["a","aj",'an']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        WW.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
                kei_3+=1
            if "副詞" in j[1]:
                for k in ["e",'en']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        WW.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            if "動詞" in j[1]:
                for k1,k2 in verb_suffix_2l_2.items():
                    if not i+k1 in QQ:
                        RR[i+k1]=[j[0]+k2,j[2]+(len(k1)-1)*10000-5000]
                    if (i+k1 in RR) and (j[0]+k2 != RR[i+k1][0]):
                        WW_2.append([i+k1,QQ[i+k1][0],j[0]+k2])##該当なし
                for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+(len(k)-1)*10000-5000]
                    if (i+k in RR) and (j[0]+k != RR[i+k][0]):
                        WW_2.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            kosu_4+=1
        elif  i in ["regulus","kolorad","satirus","spirant","traktat","akirant","ordinat"]:#7文字以上の例外処理
            if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
                for k in ["o"]:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]#実質3000#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
            if "形容詞" in j[1]:
                for k in ["a"]:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
            if "副詞" in j[1]:
                for k in ["e"]:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
            if "動詞" in j[1]:
                for k1,k2 in verb_suffix_2l_2.items():
                    if not i+k1 in QQ:
                        RR[i+k1]=[j[0]+k2,j[2]+(len(k1)-1)*10000-5000]
                for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+(len(k)-1)*10000-5000]
            kosu_5+=1
print(len(UU_0),UU_0)
print(len(UU),UU)
print(len(VV),VV)
print(len(WW),WW)

print(len(UU_2),UU_2)
print(len(VV_2),VV_2)
print(len(WW_2),WW_2)
print(len(XX),XX)
print(len(XXX),XXX)
print(kosu_1,kosu_2,kosu_3,kosu_4,kosu_5)
print(kei_1,kei_2,kei_3)
# Out:
# 0 []
# 1 [['duon', '<ruby>二<rt>du</rt></ruby><ruby>分数<rt>on</rt></ruby>', '<ruby>二<rt>du</rt></ruby>on']]
# 8 [['ordon', '<ruby>命令する<rt>ordon</rt></ruby>', '<ruby>順序<rt>ord</rt></ruby>on'], ['teren', '<ruby>地所<rt>teren</rt></ruby>', '<ruby>土地<rt>ter</rt></ruby>en'], ['kanon', '<ruby>大砲<rt>kanon</rt></ruby>', '<ruby>アシ<rt>kan</rt></ruby>on'], ['kolon', '<ruby>円柱<rt>kolon</rt></ruby>', '<ruby>首<rt>kol</rt></ruby>on'], ['komision', '<ruby>委員会<rt>komision</rt></ruby>', '<ruby>委託する<rt>komisi</rt></ruby>on'], ['menton', '<ruby>下あご<rt>menton</rt></ruby>', '<ruby>ハッカ<rt>ment</rt></ruby>on'], ['samo', 'samo', '<ruby>同一の<rt>sam</rt></ruby>o'], ['saten', '<ruby>サテン<rt>saten</rt></ruby>', '<ruby>満腹した<rt>sat</rt></ruby>en']]
# 3 [['budhan', 'budh<ruby>会員<rt>an</rt></ruby>', 'budhan'], ['roman', '<ruby>長編小説<rt>roman</rt></ruby>', 'roman'], ['person', '<ruby>人<rt>person</rt></ruby>', 'person']]
# 1 [['amas', '<ruby>集積<rt>amas</rt></ruby>', '<ruby>愛する<rt>am</rt></ruby><ruby>現在形<rt>as</rt></ruby>']]
# 26 [['akirant', 'akirant', '<ruby>獲得する<rt>akir</rt></ruby><ruby>能動・継続<rt>ant</rt></ruby>'], ['statu', '<ruby>立像<rt>statu</rt></ruby>', '<ruby>状態<rt>stat</rt></ruby>u'], ['devi', 'devi', '<ruby>しなければならない<rt>dev</rt></ruby>i'], ['diplomat', '<ruby>外交官<rt>diplomat</rt></ruby>', '<ruby>免状<rt>diplom</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['pensi', '<ruby>年金<rt>pensi</rt></ruby>', '<ruby>思う<rt>pens</rt></ruby>i'], ['konus', '<ruby>円錐<rt>konus</rt></ruby>', '<ruby>知っている<rt>kon</rt></ruby><ruby>条件法<rt>us</rt></ruby>'], ['salat', '<ruby>サラダ<rt>salat</rt></ruby>', '<ruby>塩<rt>sal</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['konsili', 'konsili', '<ruby>助言する<rt>konsil</rt></ruby>i'], ['legat', '<ruby>教皇特使<rt>legat</rt></ruby>', '<ruby>読む<rt>leg</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['legi', '<ruby>軍団<rt>legi</rt></ruby>', '<ruby>読む<rt>leg</rt></ruby>i'], ['lekant', '<ruby>マーガレット<rt>lekant</rt></ruby>', '<ruby>なめる<rt>lek</rt></ruby><ruby>能動・継続<rt>ant</rt></ruby>'], ['licenci', 'licenci', '<ruby>認可<rt>licenc</rt></ruby>i'], ['lotus', '<ruby>ハス<rt>lotus</rt></ruby>', '<ruby>くじ<rt>lot</rt></ruby><ruby>条件法<rt>us</rt></ruby>'], ['patos', '<ruby>パトス<rt>patos</rt></ruby>', '<ruby>フライパン<rt>pat</rt></ruby><ruby>未来形<rt>os</rt></ruby>'], ['revu', '<ruby>専門雑誌<rt>revu</rt></ruby>', '<ruby>空想する<rt>rev</rt></ruby>u'], ['predikat', '<ruby>述部<rt>predikat</rt></ruby>', '<ruby>説教する<rt>predik</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['rabat', '<ruby>割引<rt>rabat</rt></ruby>', '<ruby>強奪する<rt>rab</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['religi', '<ruby>宗教<rt>religi</rt></ruby>', '<ruby>再び<rt>re</rt></ruby><ruby>結ぶ<rt>lig</rt></ruby>i'], ['sekci', '<ruby>部<rt>sekci</rt></ruby>', '<ruby>切断する<rt>sekc</rt></ruby>i'], ['sendat', '<ruby>なしで<rt>sen</rt></ruby><ruby>日付<rt>dat</rt></ruby>', '<ruby>送る<rt>send</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['spirit', '<ruby>精神<rt>spirit</rt></ruby>', '<ruby>呼吸する<rt>spir</rt></ruby><ruby>受動・完了<rt>it</rt></ruby>'], ['spirant', 'spirant', '<ruby>呼吸する<rt>spir</rt></ruby><ruby>能動・継続<rt>ant</rt></ruby>'], ['tenis', 'tenis', '<ruby>支え持つ<rt>ten</rt></ruby><ruby>過去形<rt>is</rt></ruby>'], ['traktat', '<ruby>条約<rt>traktat</rt></ruby>', '<ruby>取り扱う<rt>trakt</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['vaku', 'vaku', '<ruby>あいている<rt>vak</rt></ruby>u'], ['vizit', '<ruby>訪問する<rt>vizit</rt></ruby>', '<ruby>ビザ<rt>viz</rt></ruby><ruby>受動・完了<rt>it</rt></ruby>']]
# 4 [['arogant', '<ruby>横柄な<rt>arogant</rt></ruby>', 'arog<ruby>能動・継続<rt>ant</rt></ruby>'], ['brokant', '<ruby>古物売買する<rt>brokant</rt></ruby>', 'brok<ruby>能動・継続<rt>ant</rt></ruby>'], ['ferlad', '<ruby>鉄<rt>fer</rt></ruby><ruby>ブリキ板<rt>lad</rt></ruby>', 'ferl<ruby>行為<rt>ad</rt></ruby>'], ['ordinat', 'ordinat', 'ordin<ruby>受動・継続<rt>at</rt></ruby>']]
# 0 []
# 0 []
# 0 72 6982 1007 7
# 25 1967 520

# %%
###一番の工夫ポイント(如何にして置換の優先順位を定め、置換精度を向上させるか。)
##基本は単語の文字数が多い順に置換していくことになるが、
##例えば、"置換対象の単語に接頭辞、接尾辞を追加し、単語の文字数を増やし、置換の優先順位を上げたものを、置換対象の単語として新たに追加する。"などが、置換精度を上げる方策として考えられる。
##しかし、いろいろ試した結果、動詞に対してのみ活用語尾を追加し、置換対象の単語の文字数を増やす(置換の優先順位を上げる。)のが、ベストに近いことがわかった。

## SS→QQ→RR  ("'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換し終えたリスト"(SS)を最終的な漢字置換リストに成形していく。)
### if not i+k in QQ:の働きを調べる。 
### if not i+k in QQ:の働きを調べる。 
UU_0,UU,VV,WW=[],[],[],[]
UU_2,VV_2,WW_2,XX=[],[],[],[]
RR={}
kosu_1,kosu_2,kosu_3,kosu_4,kosu_5=0,0,0,0,0
kei_1,kei_2,kei_3,kei_4=0,0,0,0
# 辞書をコピーする
QQ_copy = QQ.copy()##これがあるので、2回繰り返しするときは数個前のセルに戻ってQQを作り直してからでないといけない。
for i,j in QQ_copy.items():##j[0]:置換後の文字列　j[1]:品詞 j[2]:置換優先順位
    if (j[1] == "名詞") and (len(i)<=6) and not(j[2]==60000 or j[2]==50000 or j[2]==40000 or j[2]==30000 or j[2]==20000):##名詞だけで、6文字以下で、漢字化しないやつ  ##置換ミスを防ぐための条件(20240614) altajo,aviso,malm,abes 固有名詞対策  意味ふりがなのときは再検討
        for k in ["o"]:##4 ['buro', 'haloo', 'tauxro', 'unesko']
            if not i+k in QQ_copy:##if not ありのままで良い。
                RR[i+k]=[j[0]+k,j[2]+len(k)*10000-2000]#実質5000 #既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
                kosu_1+=1
            elif j[0]+k != QQ_copy[i+k][0]:##該当なし
                UU_0.append([i+k,QQ_copy[i+k][0],j[0]+k])
                kosu_1+=1
        QQ.pop(i, None)

for i,j in QQ.items():##j[0]:置換後の文字列　j[1]:品詞 j[2]:置換優先順位
    if j[2]==20000:##2文字で漢字化するやつ##len(i)<=2:#1文字は存在しないはずではある。
        ##基本的に非動詞の2文字の語根単体を以て漢字置換することはない。　ただし、世界语全部单词_大约44100个(原pejvo.txt).txtに最初から含まれている2文字の語根は既に漢字化されており、実際の漢字置換にも反映されることになる。
        ##2文字の語根でも、動詞については活用語尾を追加することで、自動的に+2文字以上できるので追加した。
        if "名詞" in j[1]:
            for k in ["o","on",'oj']:##"ojn"は不要か
                if not i+k in QQ:
                    RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
                else:
                    UU.append([i+k,QQ[i+k][0],j[0]+k])
        if "形容詞" in j[1]:
            for k in ["a","aj",'an']:##"ajn"は不要か  ##sia pian ,'an 'も不要
                # if not i+k in QQ:##if not なしのほうが良い
                RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
                # else:
                #     UU.append(i+k)
            kei_1+=1
        if "副詞" in j[1]:
            for k in ["e",'en']:##ege   エーゲ海を意味するegeoを元の辞書に追加
                # if not i+k in QQ:##if not なしのほうが良い
                RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
                # else:
                # UU.append(i+k)
        if "動詞" in j[1]:
            for k1,k2 in verb_suffix_2l_2.items():
                if not i+k1 in QQ:
                    RR[i+k1]=[j[0]+k2,j[2]+len(k1)*10000-3000]
                elif j[0]+k2 != QQ[i+k1][0]:
                    UU_2.append([i+k1,QQ[i+k1][0],j[0]+k2])##該当なし
            for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                if not i+k in QQ:
                    RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                elif j[0]+k != QQ[i+k][0]:
                    UU_2.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
        kosu_2+=1
        continue

    else:
        RR[i]=[j[0],j[2]]##品詞情報はここで用いるためにあった。以後は不要なので省いていく。
        if j[2]==60000 or j[2]==50000 or j[2]==40000 or j[2]==30000:##文字数が比較的少なく(<=5)、実際に漢字化するエスペラント語根(文字数×10000)のみを対象とする 
            if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
                for k in ["o","on",'oj']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
                    elif j[0]+k != QQ[i+k][0]:
                        VV.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            if "形容詞" in j[1]:
                for k in ["a","aj",'an']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                    elif j[0]+k != QQ[i+k][0]:
                        VV.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
                kei_2+=1
            if "副詞" in j[1]:
                for k in ["e",'en']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                    elif j[0]+k != QQ[i+k][0]:
                        VV.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            if "動詞" in j[1]:
                for k1,k2 in verb_suffix_2l_2.items():
                    if not i+k1 in QQ:
                        RR[i+k1]=[j[0]+k2,j[2]+len(k1)*10000-3000]
                    elif j[0]+k2 != QQ[i+k1][0]:
                        VV_2.append([i+k1,QQ[i+k1][0],j[0]+k2])##該当なし
                for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                    elif j[0]+k != QQ[i+k][0]:
                        VV_2.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            kosu_3+=1            
        elif len(i)>=3 and len(i)<=6:##3文字から6文字の語根で漢字化しないもの　　結局2文字の語根で漢字化しないものについては、完全に除外している。
            if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
                for k in ["o","on",'oj']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]#実質3000#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
                    elif j[0]+k != QQ[i+k][0]:
                        WW.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            if "形容詞" in j[1]:
                for k in ["a","aj",'an']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
                    elif j[0]+k != QQ[i+k][0]:
                        WW.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
                kei_3+=1
            if "副詞" in j[1]:
                for k in ["e",'en']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
                    elif j[0]+k != QQ[i+k][0]:
                        WW.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            if "動詞" in j[1]:
                for k1,k2 in verb_suffix_2l_2.items():
                    if not i+k1 in QQ:
                        RR[i+k1]=[j[0]+k2,j[2]+(len(k1)-1)*10000-5000]
                    elif j[0]+k2 != QQ[i+k1][0]:
                        WW_2.append([i+k1,QQ[i+k1][0],j[0]+k2])##該当なし
                for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+(len(k)-1)*10000-5000]
                    elif j[0]+k != QQ[i+k][0]:
                        WW_2.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            kosu_4+=1
        elif  i in ["regulus","kolorad","satirus","spirant","traktat","akirant","ordinat"]:#7文字以上の例外処理
            if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
                for k in ["o"]:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]#実質3000#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
            if "形容詞" in j[1]:
                for k in ["a"]:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
            if "副詞" in j[1]:
                for k in ["e"]:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
            if "動詞" in j[1]:
                for k1,k2 in verb_suffix_2l_2.items():
                    if not i+k1 in QQ:
                        RR[i+k1]=[j[0]+k2,j[2]+(len(k1)-1)*10000-5000]
                for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+(len(k)-1)*10000-5000]
            kosu_5+=1
print(len(UU_0),UU_0)
print(len(UU),UU)
print(len(VV),VV)
print(len(WW),WW)

print(len(UU_2),UU_2)
print(len(VV_2),VV_2)
print(len(WW_2),WW_2)
print(len(XX),XX)
print(kosu_1,kosu_2,kosu_3,kosu_4,kosu_5)
print(kei_1,kei_2,kei_3)
# Out:
# 0 []
# 3 [['alo', '<ruby>アロエ<rt>alo</rt></ruby>', '<ruby>～の方へ<rt>al</rt></ruby>o'], ['duon', '<ruby>二<rt>du</rt></ruby><ruby>分数<rt>on</rt></ruby>', '<ruby>二<rt>du</rt></ruby>on'], ['okon', '<ruby>八<rt>ok</rt></ruby><ruby>分数<rt>on</rt></ruby>', '<ruby>八<rt>ok</rt></ruby>on']]
# 152 [['dietan', '<ruby>規定食<rt>diet</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>規定食<rt>diet</rt></ruby>an'], ['nombron', '<ruby>数<rt>nombr</rt></ruby><ruby>分数<rt>on</rt></ruby>', '<ruby>数<rt>nombr</rt></ruby>on'], ['patron', '<ruby>後援者<rt>patron</rt></ruby>', '<ruby>父<rt>patr</rt></ruby>on'], ['afrikan', '<ruby>アフリカ<rt>afrik</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>アフリカ<rt>afrik</rt></ruby>an'], ['movadan', '<ruby>動かす<rt>mov</rt></ruby><ruby>行為<rt>ad</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>動かす<rt>mov</rt></ruby><ruby>行為<rt>ad</rt></ruby>an'], ['akcian', '<ruby>株式<rt>akci</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>株式<rt>akci</rt></ruby>an'], ['karbon', '<ruby>炭素<rt>karbon</rt></ruby>', '<ruby>炭<rt>karb</rt></ruby>on'], ['ciklon', '<ruby>低気圧<rt>ciklon</rt></ruby>', '<ruby>周期<rt>cikl</rt></ruby>on'], ['aldon', '<ruby>～の方へ<rt>al</rt></ruby><ruby>与える<rt>don</rt></ruby>', '<ruby>アルト<rt>ald</rt></ruby>on'], ['alte', '<ruby>タチアオイ<rt>alte</rt></ruby>', '<ruby>高い<rt>alt</rt></ruby>e'], ['montaran', '<ruby>山<rt>mont</rt></ruby><ruby>集団<rt>ar</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>山<rt>mont</rt></ruby><ruby>集団<rt>ar</rt></ruby>an'], ['forten', '<ruby>離れて<rt>for</rt></ruby><ruby>支え持つ<rt>ten</rt></ruby>', '<ruby>強い<rt>fort</rt></ruby>en'], ['amerikan', '<ruby>アメリカ<rt>amerik</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>アメリカ<rt>amerik</rt></ruby>an'], ['regnan', '<ruby>国家<rt>regn</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>国家<rt>regn</rt></ruby>an'], ['aparten', '<ruby>所属する<rt>aparten</rt></ruby>', '<ruby>別々の<rt>apart</rt></ruby>en'], ['apoge', '<ruby>遠地点<rt>apoge</rt></ruby>', '<ruby>支える<rt>apog</rt></ruby>e'], ['dezertan', '<ruby>砂漠<rt>dezert</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>砂漠<rt>dezert</rt></ruby>an'], ['asocian', '<ruby>協会<rt>asoci</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>協会<rt>asoci</rt></ruby>an'], ['insulan', '<ruby>島<rt>insul</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>島<rt>insul</rt></ruby>an'], ['azian', '<ruby>アジア<rt>azi</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>アジア<rt>azi</rt></ruby>an'], ['balon', '<ruby>気球<rt>balon</rt></ruby>', '<ruby>舞踏会<rt>bal</rt></ruby>on'], ['sxtatan', '<ruby>国家<rt>sxtat</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>国家<rt>sxtat</rt></ruby>an'], ['baron', '<ruby>男爵<rt>baron</rt></ruby>', '<ruby>障害<rt>bar</rt></ruby>on'], ['baston', '<ruby>棒<rt>baston</rt></ruby>', '<ruby>じん皮<rt>bast</rt></ruby>on'], ['magneton', 'magneton', '<ruby>磁石<rt>magnet</rt></ruby>on'], ['beton', 'beton', '<ruby>ビート<rt>bet</rt></ruby>on'], ['doman', '<ruby>家<rt>dom</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>家<rt>dom</rt></ruby>an'], ['domen', '<ruby>ドミノ<rt>domen</rt></ruby>', '<ruby>家<rt>dom</rt></ruby>en'], ['montan', '<ruby>山<rt>mont</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>山<rt>mont</rt></ruby>an'], ['bombon', '<ruby>キャンデー<rt>bombon</rt></ruby>', '<ruby>爆弾<rt>bomb</rt></ruby>on'], ['familian', '<ruby>家族<rt>famili</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>家族<rt>famili</rt></ruby>an'], ['breton', 'breton', '<ruby>棚<rt>bret</rt></ruby>on'], ['burgxon', '<ruby>芽<rt>burgxon</rt></ruby>', '<ruby>ブルジョワ<rt>burgx</rt></ruby>on'], ['centon', '<ruby>百<rt>cent</rt></ruby><ruby>分数<rt>on</rt></ruby>', '<ruby>百<rt>cent</rt></ruby>on'], ['milon', '<ruby>千<rt>mil</rt></ruby><ruby>分数<rt>on</rt></ruby>', '<ruby>千<rt>mil</rt></ruby>on'], ['kanton', '<ruby>郡<rt>kanton</rt></ruby>', '<ruby>歌う<rt>kant</rt></ruby>on'], ['citron', '<ruby>シトロン<rt>citron</rt></ruby>', '<ruby>チター<rt>citr</rt></ruby>on'], ['papilion', 'papilion', '<ruby>チョウ<rt>papili</rt></ruby>on'], ['kaze', '<ruby>凝乳<rt>kaze</rt></ruby>', '<ruby>格<rt>kaz</rt></ruby>e'], ['urban', '<ruby>市<rt>urb</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>市<rt>urb</rt></ruby>an'], ['inka', 'inka', '<ruby>インク<rt>ink</rt></ruby>a'], ['popolan', '<ruby>人民<rt>popol</rt></ruby><ruby>会員<rt>an</rt></ruby>', '<ruby>人民<rt>popol</rt></ruby>an'], ['platon', 'platon', '<ruby>平たい<rt>plat</rt></ruby>on'], ['platen', '<ruby>白金<rt>platen</rt></ ...
# 34 [['brazilan', 'brazil<ruby>会員<rt>an</rt></ruby>', 'brazilan'], ['budhan', 'budh<ruby>会員<rt>an</rt></ruby>', 'budhan'], ['dragon', '<ruby>竜騎兵<rt>dragon</rt></ruby>', 'dragon'], ['egiptan', 'egipt<ruby>会員<rt>an</rt></ruby>', 'egiptan'], ['gvinean', 'gvine<ruby>会員<rt>an</rt></ruby>', 'gvinean'], ['epikuran', 'epikur<ruby>会員<rt>an</rt></ruby>', 'epikuran'], ['ilirian', 'iliri<ruby>会員<rt>an</rt></ruby>', 'ilirian'], ['ionian', 'ioni<ruby>会員<rt>an</rt></ruby>', 'ionian'], ['iranan', 'iran<ruby>会員<rt>an</rt></ruby>', 'iranan'], ['irlandan', 'irland<ruby>会員<rt>an</rt></ruby>', 'irlandan'], ['islaman', 'islam<ruby>会員<rt>an</rt></ruby>', 'islaman'], ['islandan', 'island<ruby>会員<rt>an</rt></ruby>', 'islandan'], ['israelan', 'israel<ruby>会員<rt>an</rt></ruby>', 'israelan'], ['kanadan', 'kanad<ruby>会員<rt>an</rt></ruby>', 'kanadan'], ['roman', '<ruby>長編小説<rt>roman</rt></ruby>', 'roman'], ['laosan', 'laos<ruby>会員<rt>an</rt></ruby>', 'laosan'], ['libian', 'libi<ruby>会員<rt>an</rt></ruby>', 'libian'], ['malavian', 'malavi<ruby>会員<rt>an</rt></ruby>', 'malavian'], ['meksikan', 'meksik<ruby>会員<rt>an</rt></ruby>', 'meksikan'], ['nepalan', 'nepal<ruby>会員<rt>an</rt></ruby>', 'nepalan'], ['person', '<ruby>人<rt>person</rt></ruby>', 'person'], ['romian', 'romi<ruby>会員<rt>an</rt></ruby>', 'romian'], ['sirian', 'siri<ruby>会員<rt>an</rt></ruby>', 'sirian'], ['somalian', 'somali<ruby>会員<rt>an</rt></ruby>', 'somalian'], ['sovetan', 'sovet<ruby>会員<rt>an</rt></ruby>', 'sovetan'], ['sovetian', 'soveti<ruby>会員<rt>an</rt></ruby>', 'sovetian'], ['sudanan', 'sudan<ruby>会員<rt>an</rt></ruby>', 'sudanan'], ['tibetan', 'tibet<ruby>会員<rt>an</rt></ruby>', 'tibetan'], ['togolan', 'togol<ruby>会員<rt>an</rt></ruby>', 'togolan'], ['tokian', 'toki<ruby>会員<rt>an</rt></ruby>', 'tokian'], ['tongan', 'tong<ruby>会員<rt>an</rt></ruby>', 'tongan'], ['triban', 'trib<ruby>会員<rt>an</rt></ruby>', 'triban'], ['trojan', 'troj<ruby>会員<rt>an</rt></ruby>', 'trojan'], ['usonan', 'uson<ruby>会員<rt>an</rt></ruby>', 'usonan']]
# 5 [['agat', '<ruby>メノウ<rt>agat</rt></ruby>', '<ruby>行動する<rt>ag</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['agit', '<ruby>扇動する<rt>agit</rt></ruby>', '<ruby>行動する<rt>ag</rt></ruby><ruby>受動・完了<rt>it</rt></ruby>'], ['amas', '<ruby>集積<rt>amas</rt></ruby>', '<ruby>愛する<rt>am</rt></ruby><ruby>現在形<rt>as</rt></ruby>'], ['iris', '<ruby>虹彩<rt>iris</rt></ruby>', '<ruby>行く<rt>ir</rt></ruby><ruby>過去形<rt>is</rt></ruby>'], ['irit', 'irit', '<ruby>行く<rt>ir</rt></ruby><ruby>受動・完了<rt>it</rt></ruby>']]
# 71 [['regulus', 'regulus', '<ruby>規則<rt>regul</rt></ruby><ruby>条件法<rt>us</rt></ruby>'], ['agxi', '<ruby>打ち歩<rt>agxi</rt></ruby>', '<ruby>年齢<rt>agx</rt></ruby>i'], ['akirant', 'akirant', '<ruby>獲得する<rt>akir</rt></ruby><ruby>能動・継続<rt>ant</rt></ruby>'], ['radius', 'radius', '<ruby>線<rt>radi</rt></ruby><ruby>条件法<rt>us</rt></ruby>'], ['premis', '<ruby>前提<rt>premis</rt></ruby>', '<ruby>押える<rt>prem</rt></ruby><ruby>過去形<rt>is</rt></ruby>'], ['premi', '<ruby>賞品<rt>premi</rt></ruby>', '<ruby>押える<rt>prem</rt></ruby>i'], ['sonat', '<ruby>ソナタ<rt>sonat</rt></ruby>', '<ruby>音がする<rt>son</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['bari', 'bari', '<ruby>障害<rt>bar</rt></ruby>i'], ['format', '<ruby>判<rt>format</rt></ruby>', '<ruby>形<rt>form</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['markot', '<ruby>取木<rt>markot</rt></ruby>', '<ruby>しるし<rt>mark</rt></ruby><ruby>受動・将然<rt>ot</rt></ruby>'], ['tempi', '<ruby>こめかみ<rt>tempi</rt></ruby>', '<ruby>時間<rt>temp</rt></ruby>i'], ['noktu', '<ruby>コフクロウ<rt>noktu</rt></ruby>', '<ruby>夜<rt>nokt</rt></ruby>u'], ['vakcini', 'vakcini', '<ruby>ワクチン<rt>vakcin</rt></ruby>i'], ['nomad', '<ruby>遊牧民<rt>nomad</rt></ruby>', '<ruby>名前<rt>nom</rt></ruby><ruby>行為<rt>ad</rt></ruby>'], ['kantat', '<ruby>カンタータ<rt>kantat</rt></ruby>', '<ruby>歌う<rt>kant</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['procesi', '<ruby>行列<rt>procesi</rt></ruby>', '<ruby>訴訟<rt>proces</rt></ruby>i'], ['statu', '<ruby>立像<rt>statu</rt></ruby>', '<ruby>状態<rt>stat</rt></ruby>u'], ['kolorad', 'kolorad', '<ruby>色<rt>kolor</rt></ruby><ruby>行為<rt>ad</rt></ruby>'], ['devi', 'devi', '<ruby>しなければならない<rt>dev</rt></ruby>i'], ['diplomat', '<ruby>外交官<rt>diplomat</rt></ruby>', '<ruby>免状<rt>diplom</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['diskont', '<ruby>手形割引する<rt>diskont</rt></ruby>', '<ruby>円盤<rt>disk</rt></ruby><ruby>能動・将然<rt>ont</rt></ruby>'], ['endos', 'endos', '<ruby>必要<rt>end</rt></ruby><ruby>未来形<rt>os</rt></ruby>'], ['esperant', '<ruby>エスペラント<rt>esperant</rt></ruby>', '<ruby>希望する<rt>esper</rt></ruby><ruby>能動・継続<rt>ant</rt></ruby>'], ['feri', '<ruby>休日<rt>feri</rt></ruby>', '<ruby>鉄<rt>fer</rt></ruby>i'], ['fleksi', '<ruby>語尾変化<rt>fleksi</rt></ruby>', '<ruby>曲げる<rt>fleks</rt></ruby>i'], ['forkant', '<ruby>離れて<rt>for</rt></ruby><ruby>歌う<rt>kant</rt></ruby>', '<ruby>フォーク<rt>fork</rt></ruby><ruby>能動・継続<rt>ant</rt></ruby>'], ['pensi', '<ruby>年金<rt>pensi</rt></ruby>', '<ruby>思う<rt>pens</rt></ruby>i'], ['gravit', 'gravit', '<ruby>重要な<rt>grav</rt></ruby><ruby>受動・完了<rt>it</rt></ruby>'], ['konus', '<ruby>円錐<rt>konus</rt></ruby>', '<ruby>知っている<rt>kon</rt></ruby><ruby>条件法<rt>us</rt></ruby>'], ['jesu', '<ruby>イエス<rt>jesu</rt></ruby>', '<ruby>はい<rt>jes</rt></ruby>u'], ['jxaluzi', 'jxaluzi', '<ruby>嫉妬深い<rt>jxaluz</rt></ruby>i'], ['konfesi', 'konfesi', '<ruby>告白する<rt>konfes</rt></ruby>i'], ['salat', '<ruby>サラダ<rt>salat</rt></ruby>', '<ruby>塩<rt>sal</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['konsili', 'konsili', '<ruby>助言する<rt>konsil</rt></ruby>i'], ['legat', '<ruby>教皇特使<rt>legat</rt></ruby>', '<ruby>読む<rt>leg</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>'], ['legi', '<ruby>軍団<rt>legi</rt></ruby>', '<ruby>読む<rt>leg</rt></ruby>i'], ['lekant', '<ruby>マーガレット<rt>lekant</rt></ruby>', '<ruby>なめる<rt>lek</rt></ruby><ruby>能動・継続<rt>ant</rt></ruby>'], ['licenci', 'licenci', '<ruby>認可<rt>licenc</rt></ruby>i'], ['logxi', '<ruby>桟敷<rt>logxi</rt></ruby>', '<ruby>住む<rt>logx</rt></ruby>i'], ['lotus', '<ruby>ハス<rt>lotus</rt></ruby>', '<ruby>くじ<rt>lot</rt></ruby><ruby>条件法<rt>us</rt></ruby>'], ['malvolont', '<ruby>正反対<rt>mal</rt></ruby><ruby>自ら進んで<rt>volont</rt></ruby>', '<ruby>正反対<rt>mal</rt></ruby><ruby>意志がある<rt>vol</rt></ruby><ruby>能動・将然<rt>ont</rt></ruby>'], ['mankis', '<ruby>手<rt>man</rt></ruby><ruby>キスする<rt>kis</rt></ruby>', '<ruby>欠けている<rt>mank</rt></ruby><ruby>過去形<rt>is</rt></ruby>'], ['meti', '<ruby>手仕事<rt>meti</rt></ruby>', '<ruby>置く<rt>met</rt></ruby>i'], ['minus', '<ruby>マイナス<rt>minus</rt></ruby>', '<ruby>鉱山<rt>min</rt></ruby><ruby>条件法<rt>us</rt></ruby>'], ['pasi', '<ruby>情熱<rt>pas ...
# 9 [['arogant', '<ruby>横柄な<rt>arogant</rt></ruby>', 'arog<ruby>能動・継続<rt>ant</rt></ruby>'], ['brokant', '<ruby>古物売買する<rt>brokant</rt></ruby>', 'brok<ruby>能動・継続<rt>ant</rt></ruby>'], ['ferlad', '<ruby>鉄<rt>fer</rt></ruby><ruby>ブリキ板<rt>lad</rt></ruby>', 'ferl<ruby>行為<rt>ad</rt></ruby>'], ['harpi', '<ruby>ハルピュイア<rt>harpi</rt></ruby>', 'harpi'], ['ordinat', 'ordinat', 'ordin<ruby>受動・継続<rt>at</rt></ruby>'], ['patrici', '<ruby>貴族<rt>patrici</rt></ruby>', 'patrici'], ['revizit', '<ruby>再び<rt>re</rt></ruby><ruby>訪問する<rt>vizit</rt></ruby>', 'reviz<ruby>受動・完了<rt>it</rt></ruby>'], ['revizi', '<ruby>校閲する<rt>revizi</rt></ruby>', 'revizi'], ['sugesti', '<ruby>暗示<rt>sugesti</rt></ruby>', 'sugesti']]
# 0 []
# 2601 72 6982 1007 7
# 25 1967 520

# %%
RR["dekano"]
# Out:
# ['<ruby>学部長<rt>dekan</rt></ruby>o', 57000]

# %%
##RRの編集(主に置換の優先順位の変更) ここでも置換の仕方の変更ができないことはないが、品詞の種類に応じて接尾辞や接頭辞を追加するところをスキップすることになってしまう。

never_used_as_roots_only=["vin","lin","sin","min"]
for i in never_used_as_roots_only:
    RR[i]=[i,len(i)*10000+3000]##これらについては数字の大きさはそこまで重要ではない
# QQ[i.replace('/', '')]=[j[0].replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),j[1],len(i.replace('/', ''))*10000-3000]##漢字化しない単語は優先順位を下げる
# conversion_format(hanzi, word, format_type)


# RR['amas']=['<ruby>爱<rt>am</rt></ruby>as',len('amas')*10000+2500]##漢字化しない語根単体については上記で、うまく処理できているはずだが、amasoは群oと漢字化するので。
RR['farigx'][1]=len('farigx')*10000+27500##優先順位だけ変更

x='mondo/n'
RR[x.replace('/', '')]=[safe_replace(x,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),  len(x.replace('/', ''))*10000+3000]

##正しく語根分解・漢字変換してほしいやつ  anとenは念の為a/n/,e/n/としておく。ant,int,ontは大丈夫  空白を使うのは最終手段。  ","は絶対に使っては駄目
y1=[['gvid/ant/o',73000],['am/as',33000],["kor/a/n",43000],["ink/a",33000],["post/e/n",53000],["per/e",33000],["fer/o",33000],["kor/e",33000],["mal/a/j",43000],["mal/e",33000],
    ['sam/o',33000],['sat/a/n',43000],['sav/oj',43000],['sud/a/n',43000],['vet/o',33000],['ir/is',33000],['regul/us',63000],['akir/ant',63000],["prem/is",53000],
    ["mark/ot",53000],["kolor/ad",63000],["lot/us",43000],["mank/is",53000],["pat/os",43000],["rem/ont",53000],["satir/us",63000],["send/at",53000],["send/ot",53000],
    ["spir/ant",63000],["ten/is",43000],["trakt/at",63000],["alt/e",33000],["apog/e ",53000],["dom/e/n",4300],["kaz/e/ ",43000],
    ["post/e/n",53000],["posten/ul",73000],["kalk/a/n ",63000],["faz/a/n",43000],["hav/a/j",43000],["sol/e",33000],["lam/a",33000],
    ["ref/oj",43000],["akir/ant",63000],["ordin/at",63000],["form/at",53000],["kant/at",53000],["end/os",43000],
    ["konus ",53000],["lek/ant",53000],["leg/at",43000],["taks/us",53000]]##["pi/a/n",38000] anをa/n/で分けるのは正しくはないが。  havaj
for i in y1:
    RR[i[0].replace('/', '')]=[safe_replace(i[0],replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), i[1]]

##an系
y2=['diet/a/n','afrik/a/n','mov/ad/a/n','akci/a/n','mont/ar/a/n','amerik/a/n','regn/a/n','dezert/a/n','asoci/a/n','insul/a/n','azi/a/n','sxtat/a/n','dom/a/n',
    'mont/a/n','famili/a/n','urb/a/n','popol/a/n','parti/a/n','lok/a/n','sxip/a/n','eklezi/a/n','land/a/n','orient/a/n','lern/ej/a/n','en/land/a/n','estr/ar/a/n',
    'etn/a/n','euxrop/a/n','polic/a/n','soci/a/n','soci/et/a/n','grup/a/n','lig/a/n','naci/a/n','religi/a/n','kub/a/n','major/a/n','pariz/a/n','parok/a/n','podi/a/n',
    'rus/i/a/n','sekt/a/n','senat/a/n','skism/a/n','utopi/a/n','vilagx/a/n',"dek/a/n","nord/a/n","sat/a/n","par/a/n"]##["pi/a/n",38000] anをa/n/で分けるのは正しくはないが。  havaj
for i2 in y2:
    RR[i2.replace('/', '')]=[safe_replace(i2,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i2)-1)*10000+3000]
    i3 = re.sub(r"/a/n$", "", i2)##正規表現を使わないと、etn/a/n　において、etnのnまで削られてしまった。
    i4=i3+"/an/o"
    i5=i3+"/an/a"
    i6=i3+"/an/e"
    RR[i4.replace('/', '')]=[safe_replace(i4,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i4)-1)*10000+3000]
    RR[i5.replace('/', '')]=[safe_replace(i5,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i5)-1)*10000+3000]
    RR[i6.replace('/', '')]=[safe_replace(i6,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i6)-1)*10000+3000]

##正しく語根分解・漢字変換してほしいやつ  anとenは念の為a/n/,e/n/としておく。ant,int,ontは大丈夫  空白を使うのは最終手段。  ","は絶対に使っては駄目
y1=[['sole/o',43000],['sole/a',43000],["sudan/o",53000],["sudan/a",53000],["fazan/o",53000],["fazan/a",53000],["re/foj/a",53000],["re/foj/o",53000],
    ["re/foj/e",53000],["tenis/o",53000],["paran/o",53000],["paran/a",53000],["dekan/o",53000],["dekan/a",53000],["satan/a",53000],["satan/o",53000]]##["pi/a/n",38000] anをa/n/で分けるのは正しくはないが。  havaj
for i in y1:
    RR[i[0].replace('/', '')]=[safe_replace(i[0],replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), i[1]]


##以下は完全手作業
RR['dat/um/i'.replace('/', '')]=[safe_replace('dat/um/i',replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),  len('dat/um/i'.replace('/', ''))*10000+3000]
RR['dat/um/u'.replace('/', '')]=[safe_replace('dat/um/u',replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),  len('dat/um/u'.replace('/', ''))*10000+3000]
RR['dat/um/u!'.replace('/', '')]=[safe_replace('dat/um/u!',replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),  len('dat/um/u!'.replace('/', ''))*10000+3000]
#dat/um/u  dat/um/u!
RR['tra/met/i'.replace('/', '')]=[safe_replace('tra/met/i',replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),  len('tra/met/i'.replace('/', ''))*10000+3000]
RR['tra/met/u'.replace('/', '')]=[safe_replace('tra/met/u',replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),  len('tra/met/u'.replace('/', ''))*10000+3000]
RR['tra/met/u!'.replace('/', '')]=[safe_replace('tra/met/u!',replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),  len('tra/met/u!'.replace('/', ''))*10000+3000]

# RR['trametu!']=['<ruby>通<rt>tra</rt></ruby><ruby>置<rt>met</rt></ruby>u!',len('trametu!')*10000+2500]
#tra/met/u  tra/met/u!

# %%
AAA={}
i2="etn/a/n"
AAA[i2.replace('/', '')]=[safe_replace(i2,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i2.replace('/', ''))-1)*10000+3000]
i3 = re.sub(r"/a/n$", "", i2)
i4=i3+"/an/o"
i5=i3+"/an/a"
i6=i3+"/an/e"
AAA[i4.replace('/', '')]=[safe_replace(i4,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i4.replace('/', ''))-1)*10000+3000]
AAA[i5.replace('/', '')]=[safe_replace(i5,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i5.replace('/', ''))-1)*10000+3000]
AAA[i6.replace('/', '')]=[safe_replace(i6,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i6.replace('/', ''))-1)*10000+3000]

# %%
AAA
# Out:
# {'etnan': ['<ruby>民族<rt>etn</rt></ruby>an', 43000],
#  'etnano': ['<ruby>民族<rt>etn</rt></ruby><ruby>会員<rt>an</rt></ruby>o', 53000],
#  'etnana': ['<ruby>民族<rt>etn</rt></ruby><ruby>会員<rt>an</rt></ruby>a', 53000],
#  'etnane': ['<ruby>民族<rt>etn</rt></ruby><ruby>会員<rt>an</rt></ruby>e', 53000]}

# %%
print(RR["dekano"],RR["satano"],RR["satana"])
print(RR["etnano"],RR["dekano"],RR["satano"],RR["satana"])
print(RR["parano"],RR["parana"],RR["montane"],RR["satan"])
# Out:
# ['<ruby>学部長<rt>dekan</rt></ruby>o', 53000] ['<ruby>サタン<rt>satan</rt></ruby>o', 53000] ['<ruby>サタン<rt>satan</rt></ruby>a', 53000]
# ['<ruby>民族<rt>etn</rt></ruby><ruby>会員<rt>an</rt></ruby>o', 73000] ['<ruby>学部長<rt>dekan</rt></ruby>o', 53000] ['<ruby>サタン<rt>satan</rt></ruby>o', 53000] ['<ruby>サタン<rt>satan</rt></ruby>a', 53000]
# ['parano', 53000] ['parana', 53000] ['<ruby>山<rt>mont</rt></ruby><ruby>会員<rt>an</rt></ruby>e', 83000] ['<ruby>満腹した<rt>sat</rt></ruby>an', 63000]

# %%
print(RR["gvidanto"],RR["amas"],RR["koran"],RR["lian"])
print(RR["inka"],RR["posten"],RR["pere"],RR["fero"])
print(RR["korano"],RR["kore"],RR["malaj"],RR["male"],RR["paran"],RR["samo"])
print(RR["satan"],RR["savoj"],RR["sudan"],RR["veto"],RR["iris"],RR["regulus"])
print(RR["akirant"],RR["premis"],RR["markot"],RR["kolorad"],RR["iris"],RR["regulus"])
print(RR["lotus"],RR["premis"],RR["markot"],RR["kolorad"],RR["lotus"],RR["mankis"])
print(RR["patos"],RR["remont"],RR["satirus"],RR["sendat"],RR["sendot"],RR["spirant"])
print(RR["tenis "],RR["traktat"],RR["alte"],RR["apoge "],RR["domen"],RR["kaze "])
print(RR["dekan"],RR["posten"],RR["postenul"],RR["kalkan "],RR["fazan "],RR["havaj"])
print(RR["sole "],RR["lama"],RR["malaj"],RR["nordan "],RR["refoj "],RR["refojn"])
print(RR["ordinat"],RR["akirant"],RR["format"],RR["kantat"],RR["endos"])
print(RR["konus "],RR["lekant"],RR["legat"],RR["taksus"],RR["reguluso"],RR["endos"])

print(RR["reguluso"],RR["akiranto"],RR["kolorado"],RR["satiruso"],RR["spiranto"]
      ,RR["traktato"],RR["nordano"],RR["akiranto"],RR["ordinato"])
# zzzz=[['regul/us',63000],['akir/ant',63000],["kolor/ad",63000],["satir/us",63000]
#     ,["spir/ant",63000],["trakt/at",63000],["nord/a/n ",63000],["akir/ant",63000],["ordin/at",63000]]
# Out:
# ['<ruby>案内する<rt>gvid</rt></ruby><ruby>能動・継続<rt>ant</rt></ruby>o', 73000] ['<ruby>愛する<rt>am</rt></ruby><ruby>現在形<rt>as</rt></ruby>', 33000] ['<ruby>心<rt>kor</rt></ruby>an', 43000] ['<ruby>つる植物<rt>lian</rt></ruby>', 40000]
# ['<ruby>インク<rt>ink</rt></ruby>a', 33000] ['<ruby>後で<rt>post</rt></ruby>en', 53000] ['<ruby>よって<rt>per</rt></ruby>e', 33000] ['<ruby>鉄<rt>fer</rt></ruby>o', 33000]
# ['<ruby>コーラン<rt>koran</rt></ruby>o', 57000] ['<ruby>心<rt>kor</rt></ruby>e', 33000] ['<ruby>正反対<rt>mal</rt></ruby>aj', 43000] ['<ruby>正反対<rt>mal</rt></ruby>e', 33000] ['<ruby>一対<rt>par</rt></ruby>an', 63000] ['<ruby>同一の<rt>sam</rt></ruby>o', 33000]
# ['<ruby>満腹した<rt>sat</rt></ruby>an', 63000] ['<ruby>救助する<rt>sav</rt></ruby>oj', 43000] ['<ruby>南<rt>sud</rt></ruby>an', 43000] ['<ruby>賭ける<rt>vet</rt></ruby>o', 33000] ['<ruby>行く<rt>ir</rt></ruby><ruby>過去形<rt>is</rt></ruby>', 33000] ['<ruby>規則<rt>regul</rt></ruby><ruby>条件法<rt>us</rt></ruby>', 63000]
# ['<ruby>獲得する<rt>akir</rt></ruby><ruby>能動・継続<rt>ant</rt></ruby>', 63000] ['<ruby>押える<rt>prem</rt></ruby><ruby>過去形<rt>is</rt></ruby>', 53000] ['<ruby>しるし<rt>mark</rt></ruby><ruby>受動・将然<rt>ot</rt></ruby>', 53000] ['<ruby>色<rt>kolor</rt></ruby><ruby>行為<rt>ad</rt></ruby>', 63000] ['<ruby>行く<rt>ir</rt></ruby><ruby>過去形<rt>is</rt></ruby>', 33000] ['<ruby>規則<rt>regul</rt></ruby><ruby>条件法<rt>us</rt></ruby>', 63000]
# ['<ruby>くじ<rt>lot</rt></ruby><ruby>条件法<rt>us</rt></ruby>', 43000] ['<ruby>押える<rt>prem</rt></ruby><ruby>過去形<rt>is</rt></ruby>', 53000] ['<ruby>しるし<rt>mark</rt></ruby><ruby>受動・将然<rt>ot</rt></ruby>', 53000] ['<ruby>色<rt>kolor</rt></ruby><ruby>行為<rt>ad</rt></ruby>', 63000] ['<ruby>くじ<rt>lot</rt></ruby><ruby>条件法<rt>us</rt></ruby>', 43000] ['<ruby>欠けている<rt>mank</rt></ruby><ruby>過去形<rt>is</rt></ruby>', 53000]
# ['<ruby>フライパン<rt>pat</rt></ruby><ruby>未来形<rt>os</rt></ruby>', 43000] ['<ruby>漕ぐ<rt>rem</rt></ruby><ruby>能動・将然<rt>ont</rt></ruby>', 53000] ['<ruby>諷刺<rt>satir</rt></ruby><ruby>条件法<rt>us</rt></ruby>', 63000] ['<ruby>送る<rt>send</rt></ruby><ruby>受動・継続<rt>at</rt></ruby>', 53000] ['<ruby>送る<rt>send</rt></ruby><ruby>受動・将然<rt>ot</rt></ruby>', 53000] ['<ruby>呼吸する<rt>spir</rt></ruby><ruby>能動・継続<rt>ant</rt></ruby>', 63000]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 8
#       6 print(RR["lotus"],RR["premis"],RR["markot"],RR["kolorad"],RR["lotus"],RR["mankis"])
#       7 print(RR["patos"],RR["remont"],RR["satirus"],RR["sendat"],RR["sendot"],RR["spirant"])
# ----> 8 print(RR["tenis "],RR["traktat"],RR["alte"],RR["apoge "],RR["domen"],RR["kaze "])
#       9 print(RR["dekan"],RR["posten"],RR["postenul"],RR["kalkan "],RR["fazan "],RR["havaj"])
#      10 print(RR["sole "],RR["lama"],RR["malaj"],RR["nordan "],RR["refoj "],RR["refojn"])
#
# KeyError: 'tenis '

# %%
with open("RR.txt", 'w', encoding='utf-8') as file:
    for old,new in  RR.items():
        file.write(f'{old},{new[0]},{new[1]}\n')

# %%
##リストreplacementはコードの前半と後半で別物になるので注意が必要。
safe_replace("amas",replacements),safe_replace("min",replacements),safe_replace("mondo/n",replacements),safe_replace('gvid/ant/o',replacements)
# Out:
# ('<ruby>集積<rt>amas</rt></ruby>',
#  '<ruby>鉱山<rt>min</rt></ruby>',
#  '<ruby>世界<rt>mond</rt></ruby>o/n',
#  '<ruby>案内する<rt>gvid</rt></ruby>/<ruby>能動・継続<rt>ant</rt></ruby>/o')

# %%
TT=[]
for old,new in  RR.items():
    if isinstance(new[1], int):
        TT.append((old,new[0],new[1]))
# print(len(TT),len(RR))

# %%
pre_replacements3= sorted(TT, key=lambda x: x[2], reverse=True)##(置換順序の数字の大きさ順にソート!)

# %%
with open("pre_replacements3.txt", 'w', encoding='utf-8') as file:
    for old,new,priority in pre_replacements3:
        file.write(f'{old},{new},{priority}\n')

# %%
##'エスペラント語根'、'置換漢字'、'place holder'の順に並べ、最終的な置換に用いる"replacements"リストを作成。
replacements=[]
for kk in range(len(pre_replacements3)):
    if len(pre_replacements3[kk][0])>1:
        replacements.append([pre_replacements3[kk][0],pre_replacements3[kk][1],loaded_strings[kk]])

# %%
len(replacements)
# Out:
# 103294

# %%
##'大文字'、'小文字'、'文頭だけ大文字'のケースに対応。
replacements2=[]
for old,new,place_holder in replacements:
    replacements2.append((old,new,place_holder))
    replacements2.append((old.upper(),new.upper(),place_holder[:-1]+'up$'))##place holderを少し変更する必要があった。
    if old[0]==' ':
        replacements2.append((old[0] + old[1].upper() + old[2:],new[0] + new[1].upper() + new[2:],place_holder[:-1]+'cap$'))##new[0] + new[1].upper() + new[2:]は本当は怪しいが。。  
    else:
        replacements2.append((old.capitalize(),new.capitalize(),place_holder[:-1]+'cap$'))
len(replacements2)
# Out:
# 309882

# %%
#"replacements2"リストの内容を確認
with open("replacements_list_html.txt", 'w', encoding='utf-8') as file:
    for old,new,place_holder in replacements2:
        file.write(f'{old},{new},{place_holder}\n')
#最終的な置換に用いる"replacements2"リストの長さ。

# %%
replacements3=[]
with open("replacements_list_html.txt", 'r', encoding='utf-8') as file:
    for line in file:
        line = line.rstrip()##stripでは置換に最初の空白を反映できなくなってしまう。
        j = line.split(',')
        if len(j)==3:
            old,new,place_holder=j[0],j[1],j[2]
            replacements3.append((old,new,place_holder))
#len(replacements3)  
#replacements2とreplacements3は全く同一のリストである。

# %%
##置換に用いる関数。正規表現、C++など様々な形式の置換を試したが、pythonで'place holder'を用いる形式の置換が、最も処理が高速であった。(しかも大変シンプルでわかりやすい。)
def safe_replace(text, replacements):
    valid_replacements = {}
    # 置換対象(old)を'place holder'に一時的に置換
    for old, new, placeholder in replacements:
        if old in text:
            text = text.replace(old, placeholder)
            valid_replacements[placeholder] = new# 後で置換後の文字列(new)に置換し直す必要がある'place holder'を辞書(valid_replacements)に記録しておく。
    #'place holder'を置換後の文字列(new)に置換)
    for placeholder, new in valid_replacements.items():
        text = text.replace(placeholder, new)
    return text

# %%
## multiprocessingのための関数群　テキストを行数によって設定プロセス数(num_processes)に等分割して、それぞれのプロセスで並列に置換処理を実行してから、再度分割したテキストを結合する。

import multiprocessing
def process_segment(lines, replacements):
    # 文字列のリストを結合してから置換処理を実行 linesには\nが含まれていない状態の文字列群が格納されている。
    segment = '\n'.join(lines)
    segment = safe_replace(segment, replacements)#ここでsafe_replace関数の実行
    return segment

def parallel_process(text, num_processes,replacements):
    #テキストを行で分割
    lines = text.split('\n')
    num_lines = len(lines)
    lines_per_process = num_lines // num_processes

    #各プロセスに割り当てる行のリストを決定
    ranges = [(i * lines_per_process, (i + 1) * lines_per_process) for i in range(num_processes)]
    ranges[-1] = (ranges[-1][0], num_lines)  #最後のプロセスが残り全てを処理

    with multiprocessing.Pool(processes=num_processes) as pool:
        # 並列処理を実行
        results = pool.starmap(process_segment, [(lines[start:end], replacements) for start, end in ranges])

    # 結果を結合
    return '\n'.join(result for result in results)

# %%
text="koran dankon vin sin lin lino sino amas amaso havis aviso  altaj altajo"
text=replace_esperanto_chars(text,esperanto_to_x)
safe_replace(text,replacements3)
# parallel_process(text*1,1, replacements)
# Out:
# '<ruby>心<rt>kor</rt></ruby>an <ruby>感謝する<rt>dank</rt></ruby>on vin sin lin <ruby>亜麻<rt>lin</rt></ruby>o <ruby>懐<rt>sin</rt></ruby>o <ruby>愛する<rt>am</rt></ruby><ruby>現在形<rt>as</rt></ruby> <ruby>集積<rt>amas</rt></ruby>o <ruby>持っている<rt>hav</rt></ruby><ruby>過去形<rt>is</rt></ruby> aviso  <ruby>高い<rt>alt</rt></ruby>aj altajo'

# %%
# safe_replace("Membroj havas  Mi farigxis multaj taskoj  Mi amas vin multe necese movado sin senegal nova ",replacements3)
# safe_replace("mondon mondonas amon amo amonj! amojn! mondon mondo vino vinon  vinojn vin vino nova ",replacements3)
# safe_replace("sin sindoni sindonemo dion Dion amon amon dio dia Senegala senegal senegala senegalo",replacements3)
safe_replace("popolan parizan/popolan. senatan senatan/ skisman parizan skisman/ aman aman/dankon vin sin lin lino sino amas amaso havis aviso  altaj altajo",replacements3)
# Out:
# '<ruby>人民<rt>popol</rt></ruby>an <ruby>パリ<rt>pariz</rt></ruby>an/<ruby>人民<rt>popol</rt></ruby>an. <ruby>参議院<rt>senat</rt></ruby>an <ruby>参議院<rt>senat</rt></ruby>an/ <ruby>分裂<rt>skism</rt></ruby>an <ruby>パリ<rt>pariz</rt></ruby>an <ruby>分裂<rt>skism</rt></ruby>an/ a<ruby>手<rt>man</rt></ruby> a<ruby>手<rt>man</rt></ruby>/<ruby>感謝する<rt>dank</rt></ruby>on vin sin lin <ruby>亜麻<rt>lin</rt></ruby>o <ruby>懐<rt>sin</rt></ruby>o <ruby>愛する<rt>am</rt></ruby><ruby>現在形<rt>as</rt></ruby> <ruby>集積<rt>amas</rt></ruby>o <ruby>持っている<rt>hav</rt></ruby><ruby>過去形<rt>is</rt></ruby> aviso  <ruby>高い<rt>alt</rt></ruby>aj altajo'

# %%
import re
def find_strings_in_text(text):
    # 正規表現パターンを定義
    pattern = re.compile(r'%%(.{1,50}?)%%')
    matches = []
    used_indices = set()

    # 正規表現のマッチを見つける
    for match in pattern.finditer(text):
        start, end = match.span()
        # 重複する%%を避けるためにインデックスをチェック
        if start not in used_indices and end-2 not in used_indices:  # end-2 because of double %%
            matches.append(match.group(1))
            # インデックスを使用済みセットに追加
            used_indices.update(range(start, end))
    return matches
def load_placeholders(filename):
    with open(filename, 'r') as file:
        placeholders = [line.strip() for line in file if line.strip()]
    return placeholders
def create_replacements(text, placeholders):
    # テキストから%%で囲まれた部分を抽出
    matches = find_strings_in_text(text)
    replacements_list_for_intact_parts = []
    # プレースホルダーとマッチを対応させる
    for i, match in enumerate(matches):
        if i < len(placeholders):
            replacements_list_for_intact_parts.append([f"%%{match}%%", placeholders[i]])
        else:
            break  # プレースホルダーが足りなくなった場合は終了
    return replacements_list_for_intact_parts
# 使用例
text = text = """%%L. Zamenhof.%% Kongresaj paroladoj
Kongresaj paroladoj
# %%Lazarj Markoviĉ Zamenhof%%

Kongresaj paroladoj

Serio Scio, №2

La 1a eldono: %%Jekaterinburgo%% Ruslanda Esperantisto, 1995.
La 2a eldono: %%Kaliningrado%%: Sezonoj; %%Kaunas: LEA, 2015.%%
"""
# プレースホルダーファイルから読み込む
placeholders = load_placeholders('No.1000_9999.txt')
# リストを作成
replacements_list_for_intact_parts = create_replacements(text, placeholders)
sorted_replacements_list_for_intact_parts = sorted(replacements_list_for_intact_parts, key=lambda x: len(x[0]), reverse=True)
# 結果を表示
# for item in sorted_replacements_list_for_intact_parts:
#     print(item)

# %%
with open('例文4.txt','r') as g:
    ll=g.read()
text2=replace_esperanto_chars(ll,esperanto_to_x)

replacements_list_for_intact_parts = create_replacements(text2, placeholders)
sorted_replacements_list_for_intact_parts = sorted(replacements_list_for_intact_parts, key=lambda x: len(x[0]), reverse=True)
for original, place_holder_ in sorted_replacements_list_for_intact_parts:
    text2 = text2.replace(original, place_holder_)

text3=safe_replace(text2, replacements3)

for original, place_holder_ in sorted_replacements_list_for_intact_parts:
    text3 = text3.replace(place_holder_, original.replace("%%",""))

# text3=parallel_process(text2*1,1, replacements2)
with open('出力4.html','w', encoding='utf-8') as h:
    h.write(text3)

# %%
sorted_replacements_list_for_intact_parts
# text2
# Out:
# [['%%Lazarj Markovicx Zamenhof%%', '&%1001&%'],
#  ['%%Aleksander Korjxenkov%%', '&%1005&%'],
#  ['%%Aleksander Korjxenkov%%', '&%1007&%'],
#  ['%%Aleksander Korjxenkov%%', '&%1010&%'],
#  ['%%Aleksander Korjxenkov%%', '&%1011&%'],
#  ['%%Aleksander Korjxenkov%%', '&%1012&%'],
#  ['%%Aleksander Korjxenkov%%', '&%1013&%'],
#  ['%%Kaunas: LEA, 2015.%%', '&%1004&%'],
#  ['%%Jekaterinburgo%%', '&%1002&%'],
#  ['%%Halina Gorecka%%', '&%1008&%'],
#  ['%%Halina Gorecka%%', '&%1009&%'],
#  ['%%L. Zamenhof.%%', '&%1000&%'],
#  ['%%Kaliningrado%%', '&%1003&%'],
#  ['%%Alla Dzjuba%%', '&%1006&%']]

# %% [markdown]
# 以下是附录(以下はおまけ)
