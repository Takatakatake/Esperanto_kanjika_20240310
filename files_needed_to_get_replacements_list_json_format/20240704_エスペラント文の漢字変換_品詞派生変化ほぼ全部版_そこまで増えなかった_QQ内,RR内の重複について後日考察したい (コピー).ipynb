# %%
##エスペラント文の文字形式の変換関数
esperanto_to_x = { "ĉ": "cx", "ĝ": "gx", "ĥ": "hx", "ĵ": "jx", "ŝ": "sx", "ŭ": "ux",
                   "Ĉ": "Cx", "Ĝ": "Gx", "Ĥ": "Hx", "Ĵ": "Jx", "Ŝ": "Sx", "Ŭ": "Ux",
                   "c^": "cx", "g^": "gx", "h^": "hx", "j^": "jx", "s^": "sx", "u^": "ux",
                    "C^": "Cx", "G^": "Gx", "H^": "Hx", "J^": "Jx", "S^": "Sx", "U^": "Ux"}
x_to_jijofu={'cx': 'ĉ', 'gx': 'ĝ', 'hx': 'ĥ', 'jx': 'ĵ', 'sx': 'ŝ', 'ux': 'ŭ', 'Cx': 'Ĉ',
             'Gx': 'Ĝ', 'Hx': 'Ĥ', 'Jx': 'Ĵ', 'Sx': 'Ŝ', 'Ux': 'Ŭ'}
x_to_hat={'cx': 'c^', 'gx': 'g^', 'hx': 'h^', 'jx': 'j^', 'sx': 's^', 'ux': 'u^', 'Cx': 'C^',
          'Gx': 'G^', 'Hx': 'H^', 'Jx': 'J^', 'Sx': 'S^', 'Ux': 'U^'}

def replace_esperanto_chars(text,letter_dictionary):
    for esperanto_char, x_char in letter_dictionary.items():
        text = text.replace(esperanto_char, x_char)
    return text
#テスト用のエスペラント文
# text = "Ĝis revido! Mia nomo estas Ĵoĥano. Ĉu vi ŝatas ĥorojn? -Ne, mi s^tas felic^on. C^ S^ H^ c^ s^ h^  Ĉ Ĝ  Gxis revido! Mia nomo estas Jxohxano. Cxu vi sxatas hxorojn? -Ne, mi sxtas felicxon. Cx Sx Hx cx sx hx  Cx Gx"
#エスペラント文の文字形式の変換
# replaced_text = replace_esperanto_chars(text,esperanto_to_x)
# replaced_text =replace_esperanto_chars(text,x_to_jijofu)
# replaced_text =replace_esperanto_chars(text,x_to_hat)
# print("元のテキスト:", text)
# print("置換後のテキスト:", replaced_text)

# %%
##まず、"世界语全部单词_大约44100个(原pejvo.txt).txt"を小文字、X形式に変換する。 (変換コード上では小文字、X形式で統一。)
with open("世界语全部单词_大约44100个(原pejvo.txt)_original2024620_utf8_2列目以降修正_2通りの分解修正__更に修正.txt", 'r', encoding='utf-8') as file:
    text = file.read()
    converted_text=replace_esperanto_chars(text,esperanto_to_x)#エスペラントの特殊文字を対応するx形式に変換。
    converted_text=converted_text.lower()#小文字に変換。

#結果を"tmp.txt"に書き出す。
with open('tmp.txt', 'w', encoding='utf-8') as file:
    file.write(converted_text)

# %%
import os
import re
def contains_digit(s):#対象の文字列sに数字となりうる文字列(数字)が含まれるかどうかを確認する関数
    return any(char.isdigit() for char in s)

result=[]
# "tmp.txt"("世界语全部单词_大约44100个(原pejvo.txt).txt"を小文字、X形式に変換したもの)を開く。
with open("tmp.txt", 'r', encoding='utf-8') as file:
    # "tmp.txt"の各行をループ。
    for line in file:
        # ':'が出てくるまでの部分を取り出す。
        line=line.replace('-','/')##20240618追加
        word = line.split(":")[0]
        word = word.lstrip('/')##日本版,1列目だけ
        # さらに取り出した部分を'-'、' '、','で分ける。","もごくまれに存在する('tial')
        parts = re.split('-| |,', word)
        # 各部分をループし、単語の語尾の形式によって品詞分類しながら、その語尾をカットする。
        for jj in range(len(parts)):
            if jj>=0:##1列目も2列目以降も
                part=parts[jj]
                if not (contains_digit(part) or len(part)<2):##2文字以上
                    if "/" in part:
                        if part.endswith(('/o','/on','oj','/o!','ojn','on!')):
                            AA=["/".join(part.split("/")[:-1])]
                            AA.append('名詞')
                        elif part.endswith(('/a','/aj','/an','/an!')):
                            AA=["/".join(part.split("/")[:-1])]
                            AA.append('形容詞')
                        elif part.endswith(('/e','/e!')):
                            AA=["/".join(part.split("/")[:-1])]
                            AA.append('副詞')
                        elif part.endswith(('/e/n','/e/n!')):##'/e/n'は後で気をつける
                            AA=["/".join(part.split("/")[:-2])]
                            AA.append('副詞')    
                        elif part.endswith(('/i','/u','/u!')):
                            AA=["/".join(part.split("/")[:-1])]
                            AA.append('動詞')
                        elif part.endswith(('/n')):
                            AA=["/".join(part.split("/")[:-1])]
                            AA.append('n語')            
                    else:
                        AA=[part,"無詞"]
                    result.append(AA)

# %%
##すべての単語の語尾が正しくカットされているかどうかチェックする。 ここまで情報は何一つ減っていないはず。
with open("检查世界语所有单词的结尾是否被正确切除(result).txt","w",encoding='utf-8') as g:
    for hh in result:
        if len(hh)==2:##不要な条件と思われる。
            g.write(hh[0]+','+hh[1]+"\n")
            # g.write(replace_esperanto_chars(hh[0],x_to_jijofu)+"##"+"\n")

# %%
##上の作業で抽出した、'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換するための、漢字置換リストを作成していく。
##"'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換し終えたリスト"こそが最終的な漢字置換リストの大元になる。
##'既に完全に語根分解された状態の単語'が対象であれば、文字数の多い語根順に漢字置換するだけで完璧な精度の漢字置換ができる!
##ただし、その完璧な漢字置換のためにはあらかじめ"世界语全部单词_大约44100个(原pejvo.txt).txt"から"从世界语全部单词_大约44100个(原pejvo.txt).txt中提取并输出世界语所有词根_大约11360个.txt_带中文日文注释.ipynb"を用いてエスペラントの全語根を抽出しておく必要がある。

replacements_dict={}##一旦辞書型を使う。(後で内容(value)を更新するため)
with open("世界语所有词根_大约11222个_20240621.txt", 'r', encoding='utf-8') as file:
# with open("世界语所有词根_大约11289个_20240619.txt", 'r', encoding='utf-8') as file:
    ##"世界语所有词根_大约11360个.txt"は"世界语全部单词_大约44100个(原pejvo.txt).txt"から"从世界语全部单词_大约44100个(原pejvo.txt).txt中提取并输出世界语所有词根_大约11360个.txt_带中文日文注释.ipynb"を用いて抽出したエスペラントの全語根である。
    roots = file.readlines()
    for root in roots:
        root = root.strip()
        if not root.isdigit():##混入していた数字の'10'と'7'を削除
            replacements_dict[root]=[root,len(root)]##各エスペラント語根に対する'置換後の単語'(この作業では元の置換対象の語根のまま)と、その置換順序として、'置換対象の語根の文字数'を設定。　置換順序の数字が大きい('置換対象の語根の文字数が多い')ほど、先に置換される仕組みにする。
len(replacements_dict)
# Out:
# 11141

# %%
##上の作業に引き続き、"'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換するための、漢字置換リスト"を作成していく。　
##ここでは漢字置換リストに自分で作成したエスペラント語根の漢字化リストを反映させる。

def conversion_format(hanzi, word, format_type):##変換形式を決める。
    if format_type == 'HTML Format':
        return '<ruby>{}<rt>{}</rt></ruby>'.format(hanzi, word)
    elif format_type == 'Parentheses Format':
        return '{}({})'.format(hanzi, word)
    elif format_type == 'Parentheses Format2':
        return '{}({})'.format(word, hanzi)
    elif format_type == 'Parentheses Format3':
        return '(!){}({})'.format(word, hanzi)
    elif format_type == 'Only Hanzi':
        return '{}'.format(hanzi)
    
# format_type='Parentheses Format'
# format_type='Parentheses Format2'
format_type='Parentheses Format3'


# input_file="Ruby形式＿日本語.csv"
input_file="Ruby形式＿日本語.csv"

# input_file="世界语汉字表格_20240312.csv"
with open(input_file, 'r', encoding='utf-8') as file:
    for line in file:
        line = line.strip()
        j = line.split(',')
        if len(j)>=2:
            word,hanzi=j[0],j[1]
            if (hanzi!='') and (word!='') and ('#' not in word):
                replacements_dict[word]=[conversion_format(hanzi, word, format_type),len(word)]#辞書式配列では要素(key)に対する値(value)を後から更新できることを利用している。
# with open("replacements_dict.txt", 'w', encoding='utf-8') as file:
#     for old,new in replacements_dict.items():
#         file.write(f'{old},{new[0]},{new[1]}\n')

# %%
##'漢字置換リスト'を置換順序の数字の大きさ順にソート。
pre_replacements=[]
for old,new in replacements_dict.items():
    pre_replacements.append((old,new[0],new[1]))
pre_replacements3 = sorted(pre_replacements, key=lambda x: x[2], reverse=True)#x[2]がポイント
# pre_replacements3

# %%
##'漢字置換リスト'の各置換に対して'place holder'を追加し、'replacements'リストとして完成させた。
##'place holder'法とは、既に置換を終えた文字列が後続の置換によって重複して置換されてしまうことを避けるために、その置換を終えた部分に一時的に無関係な文字列(place holder)を置いておいて、
##全ての置換が終わった後に、改めてその'無関係な文字列(place holder)'から'目的の置換後文字列'に変換していく手法である。

with open('No.10000_500000.txt', 'r', encoding='utf-8') as file:##漢字置換時に用いる"place holder"ファイルを予め読み込んでおく。
    loaded_strings = [line.strip() for line in file]

replacements=[]
for kk in range(len(pre_replacements3)):
    replacements.append([pre_replacements3[kk][0],pre_replacements3[kk][1],loaded_strings[kk]])


##置換に用いる関数。正規表現、C++など様々な形式の置換を試したが、pythonで'place holder'を用いる形式の置換が、最も処理が高速であった。(しかも大変シンプルでわかりやすい。)
def safe_replace(text, replacements):
    valid_replacements = {}
    # 置換対象(old)を'place holder'に一時的に置換
    for old, new, placeholder in replacements:
        if old in text:
            text = text.replace(old, placeholder)
            valid_replacements[placeholder] = new# 後で置換後の文字列(new)に置換し直す必要がある'place holder'を辞書(valid_replacements)に記録しておく。
    #'place holder'を置換後の文字列(new)に置換)
    for placeholder, new in valid_replacements.items():
        text = text.replace(placeholder, new)
    return text



#replacementsリスト("'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換するための、漢字置換リスト"の完成版)の内容確認
with open("replacements_list.txt", 'w', encoding='utf-8') as file:
    for old,new,priority in replacements:
        file.write(f'{old},{new},{priority}\n')

# %%
len(result)
# Out:
# 50678

# %% [markdown]
# 以下の3つはスキップしても良い。(時間がかかるので)

# %%
##'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を実際にreplacementsリスト(漢字置換リストの完成版)によって漢字置換。　
##ここで作成される、"漢字置換し終えたリスト(辞書型)"(SS)が最終的な漢字置換リストの大元になる。
##リストresultまでは情報の損失は殆どないはず。

SS={}
for j in result:##20秒ほどかかる。　先にリストの要素を全て結合して、一つの文字列にしてから漢字置換する方法を試しても(上述)、さほど高速化しなかった。
    if len(j)==2:##(j[0]がエスペラント語根、j[1]が品詞。)
        if len(j[0])>=2:##2文字以上のエスペラント語根のみが対象
            if j[0] in SS:
                if j[1] not in SS[j[0]][1]:
                    SS[j[0]] = [SS[j[0]][0],SS[j[0]][1] + ', ' + j[1]]##複数品詞の追加
            else:
                SS[j[0]]=[safe_replace(j[0], replacements),j[1]]##辞書敷配列の追加法

# %%
# 上の作業で作成した辞書型リスト(SS)の最初から20個分を表示
for key, value in dict(list(SS.items())[:10]).items():
    print(f"{key}: {value}")
# Out:
# abak: ['abak', '名詞']
# abat/ec: ['(!)abat(修道院長)/(!)ec(性質)', '名詞']
# abat/ej: ['(!)abat(修道院長)/(!)ej(場所)', '名詞']
# abat/in: ['(!)abat(修道院長)/(!)in(女性)', '名詞']
# abat: ['(!)abat(修道院長)', '名詞']
# abdik: ['(!)abdik(退く)', '動詞, 名詞']
# abdomen: ['abdomen', '名詞']
# abel: ['(!)abel(ミツバチ)', '形容詞, 名詞']
# miel: ['(!)miel(蜂蜜)', '名詞, 形容詞']
# pik/il: ['(!)pik(刺す)/(!)il(道具)', '名詞']

# %%
with open("SS.txt", 'w', encoding='utf-8') as file:
    for old,new in  SS.items():
        file.write(f'{old},{new[0]},{new[1]}\n')

# %%
# # テキストファイルから辞書を再構築する
# テキストファイルから辞書を再構築する
SS = {}
with open("SS.txt", 'r', encoding='utf-8') as file:
    for line in file:
        # 各行をコンマで分割
        parts = line.strip().split(',')
        if len(parts)>=3:
            # parts[2:] のリストをカンマ区切りの文字列に変換
            parts_of_speech = ', '.join(part.strip() for part in parts[2:])
            # 分割したデータを辞書に追加（リストとして保存）
            SS[parts[0]] = [parts[1], parts_of_speech]##:がないと品詞が一つになってしまう。
# # 再構築された辞書の内容を表示
# for key, value in dict(list(reconstructed_dict.items())[:5]).items():
#     print(f"{key}: {value}")

# 上の作業で作成した辞書型リスト(SS)の最初から20個分を表示
for key, value in dict(list(SS.items())[:10]).items():
    print(f"{key}: {value}")
# Out:
# abak: ['abak', '名詞']
# abat/ec: ['(!)abat(修道院長)/(!)ec(性質)', '名詞']
# abat/ej: ['(!)abat(修道院長)/(!)ej(場所)', '名詞']
# abat/in: ['(!)abat(修道院長)/(!)in(女性)', '名詞']
# abat: ['(!)abat(修道院長)', '名詞']
# abdik: ['(!)abdik(退く)', '動詞, 名詞']
# abdomen: ['abdomen', '名詞']
# abel: ['(!)abel(ミツバチ)', '形容詞, 名詞']
# miel: ['(!)miel(蜂蜜)', '名詞, 形容詞']
# pik/il: ['(!)pik(刺す)/(!)il(道具)', '名詞']

# %%
# スラッシュを取り除いたキーでデータを整理するための辞書
normalized_keys = {}

# 各キーからスラッシュを取り除き、既存のキーとして整理
for old, value in SS.items():
    # スラッシュを取り除く
    normalized_key = old.replace('/', '')

    # 辞書に追加
    if normalized_key not in normalized_keys:
        normalized_keys[normalized_key] = []
    normalized_keys[normalized_key].append((old, value))

# 抜き出すためのファイル出力
with open("SS_chofuku.txt", 'w', encoding='utf-8') as file:
    for key, entries in normalized_keys.items():
        # 同じ語根を持つ要素が複数ある場合のみファイルに書き込む
        if len(entries) > 1:
            for old, value in entries:
                file.write(f'{old},{value[0]},{value[1]}\n')


# 各語根ごとに最長のキーを保持する辞書
max_length_keys = {}

# スラッシュを取り除いた語根をキーとして、最長のキーと値を保存
for old, value in SS.items():
    # スラッシュを取り除く
    normalized_key = old.replace('/', '')
    # 辞書にこの語根が存在するか、存在する場合は現在のキーと比較
    if normalized_key not in max_length_keys or len(max_length_keys[normalized_key][0]) < len(old):
        max_length_keys[normalized_key] = (old, value)

# 最終的な辞書を作成
SS_ = {k: v for _, (k, v) in max_length_keys.items()}

with open("SS.txt", 'w', encoding='utf-8') as file:
    for old,new in  SS.items():
        file.write(f'{old},{new[0]},{new[1]}\n')
    
with open("SS_.txt", 'w', encoding='utf-8') as file:
    for old,new in  SS_.items():
        file.write(f'{old},{new[0]},{new[1]}\n')
len(SS),len(SS_)
# 結果を出力
print(SS_)
##品詞によって分けることは可能か？20240616
# Out:
# {'abak': ['abak', '名詞'], 'abat/ec': ['(!)abat(修道院長)/(!)ec(性質)', '名詞'], 'abat/ej': ['(!)abat(修道院長)/(!)ej(場所)', '名詞'], 'abat/in': ['(!)abat(修道院長)/(!)in(女性)', '名詞'], 'abat': ['(!)abat(修道院長)', '名詞'], 'abdik': ['(!)abdik(退く)', '動詞, 名詞'], 'abdomen': ['abdomen', '名詞'], 'abel': ['(!)abel(ミツバチ)', '形容詞, 名詞'], 'miel': ['(!)miel(蜂蜜)', '名詞, 形容詞'], 'pik/il': ['(!)pik(刺す)/(!)il(道具)', '名詞'], 'abel/bred/ad': ['(!)abel(ミツバチ)/(!)bred(飼育する)/(!)ad(行為)', '名詞'], 'abel/bred/ist': ['(!)abel(ミツバチ)/(!)bred(飼育する)/(!)ist(従事者)', '名詞'], 'abel/bred': ['(!)abel(ミツバチ)/(!)bred(飼育する)', '名詞'], 'abel/ej': ['(!)abel(ミツバチ)/(!)ej(場所)', '名詞'], 'abel/in': ['(!)abel(ミツバチ)/(!)in(女性)', '名詞'], 'abel/ist': ['(!)abel(ミツバチ)/(!)ist(従事者)', '名詞'], 'abel/kest': ['(!)abel(ミツバチ)/(!)kest(箱)', '名詞'], 'abel/korb': ['(!)abel(ミツバチ)/(!)korb(かご)', '名詞'], 'abel/kultur': ['(!)abel(ミツバチ)/(!)kultur(栽培する)', '名詞'], 'abel/mangx/ul': ['(!)abel(ミツバチ)/(!)mangx(食べる)/(!)ul(人)', '名詞'], 'abel/regx/in': ['(!)abel(ミツバチ)/(!)regx(王)/(!)in(女性)', '名詞'], 'abel/svarm': ['(!)abel(ミツバチ)/(!)svarm(群がっている)', '名詞'], 'abel/uj': ['(!)abel(ミツバチ)/(!)uj(容器)', '名詞'], 'abel/vaks': ['(!)abel(ミツバチ)/(!)vaks(ワックス)', '名詞'], 'aberaci': ['aberaci', '名詞'], 'abhxaz/i': ['abhxaz/i', '名詞'], 'abi/ar': ['(!)abi(モミ)/(!)ar(集団)', '名詞'], 'abi': ['(!)abi(モミ)', '名詞'], 'abi/pice': ['(!)abi(モミ)/(!)pice(トウヒ)', '名詞'], 'abi/pingl': ['(!)abi(モミ)/(!)pingl(ピン)', '名詞'], 'abisen/i': ['abisen/i', '名詞'], 'abisen': ['abisen', '名詞'], 'abisen/uj': ['abisen/(!)uj(容器)', '名詞'], 'abism': ['(!)abism(深淵)', '形容詞, 名詞'], 'abiturient': ['(!)abiturient(アビトゥリエント)', '名詞'], 'ablativ': ['(!)ablativ(奪格)', '名詞'], 'abnegaci': ['(!)abnegaci(自己犠牲)', '動詞, 名詞'], 'aboc': ['aboc', '名詞'], 'aboc/o/libr': ['aboc/o/(!)libr(本)', '名詞'], 'abol': ['abol', '動詞'], 'abolici': ['abolici', '動詞, 名詞'], 'abolici/ism': ['abolici/(!)ism(主義)', '名詞'], 'abomen': ['(!)abomen(嫌悪)', '形容詞, 動詞, 名詞'], 'abomen/ajx': ['(!)abomen(嫌悪)/(!)ajx(事物)', '名詞'], 'kanajl': ['(!)kanajl(ごろつき)', '名詞'], 'abomen/ig': ['(!)abomen(嫌悪)/(!)ig(させる)', '動詞'], 'abomen/ind': ['(!)abomen(嫌悪)/(!)ind(価値)', '形容詞'], 'abomen/ind/ajx': ['(!)abomen(嫌悪)/(!)ind(価値)/(!)ajx(事物)', '名詞'], 'milit': ['(!)milit(戦争する)', '名詞, 形容詞, 動詞'], 'abon': ['(!)abon(予約する)', '形容詞, 動詞, 名詞'], 'mon': ['(!)mon(金銭)', '名詞, 形容詞'], 'abon/ant': ['(!)abon(予約する)/(!)ant(能動・継続)', '名詞'], 'abon/bilet': ['(!)abon(予約する)/(!)bilet(切符)', '名詞'], 'abon/ebl': ['(!)abon(予約する)/(!)ebl(可能)', '形容詞'], 'abon/help': ['(!)abon(予約する)/(!)help(手助けする)', '形容詞'], 'fondus': ['fondus', '名詞'], 'abon/il': ['(!)abon(予約する)/(!)il(道具)', '名詞'], 'abon/kotiz': ['(!)abon(予約する)/(!)kotiz(払う)', '名詞'], 'abon/pag': ['(!)abon(予約する)/(!)pag(支払う)', '名詞'], 'abon/prez': ['(!)abon(予約する)/(!)prez(価格)', '名詞'], 'abon/son/ajx': ['(!)abon(予約する)/(!)son(音がする)/(!)ajx(事物)', '名詞'], 'abon/tarif': ['(!)abon(予約する)/(!)tarif(関税表)', '名詞'], 'aborigen': ['aborigen', '名詞'], 'abort/ajx': ['(!)abort(流産する)/(!)ajx(事物)', '名詞'], 'abort/em': ['(!)abort(流産する)/(!)em(傾向)', '形容詞'], 'abort': ['(!)abort(流産する)', '動詞, 名詞'], 'abort/ig': ['(!)abort(流産する)/(!)ig(させる)', '動詞, 名詞'], 'abort/ig/il': ['(!)abort(流産する)/(!)ig(させる)/(!)il(道具)', '名詞'], 'abort/it': ['(!)abort(流産する)/(!)it(受動・完了)', '名詞'], 'abort/ul': ['(!)abort(流産する)/(!)ul(人)', '名詞'], 'abraham': ['abraham', '名詞'], 'abrikot': ['(!)abrikot(アンズ)', '形容詞, 名詞'], 'marmelad': ['(!)marmelad(ママレード)', '名詞'], 'abrikot/arb': ['(!)abrikot(アンズ)/(!)arb(木)', '名詞'], 'abrikot/uj': ['(!)abrikot(アンズ)/(!)uj(容器)', '名詞'], 'abrotan': ['abrotan', '名詞'], 'abrupt': ['(!)abrupt(突然の)', '形容詞, 副詞'], 'abrupt/ajx': ['(!)abrupt(突然の)/(!)ajx(事物)', '名詞'], 'vocx': ['(!)vocx(声)', '名詞, 形容詞, 副詞, 動詞'], 'abruz': ['abruz', '名詞'], 'absces': ['(!)absces(膿瘍)', '動詞, 名詞'], 'abscis': ['abscis', '名詞'], 'absid/et': ['absid/(!)et(弱小)', '名詞'], 'absid': ['absid', '名詞'], 'absint/ajx': ['(!)absint(ニガヨモギ)/(!)ajx(事物)', '名詞'], 'absint': ['(!)absint(ニガヨモギ)', '形容詞, 名詞'], 'likvor': ['(!)likvor(リキュール)', '名詞'], 'absint/ism': ['(!)absint(ニガヨモギ)/(!)ism(主義)', '名詞'], 'absolut': ['(!)absolut(絶対の)', '形容詞, 副詞, 名詞'], 'adres': ['(!)adres(住所)', '名詞, 動詞'], 'alkohol': ['(!)alkohol(アルコール) ...

# %%
len(SS)
# Out:
# 32045

# %%
##ここから、"'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換し終えたリスト(辞書型)"(SS)を最終的な漢字置換リストに成形していく。

# %%
##更改替换方式(关于如何更改汉字转换,请编辑第一个csv文件)  (置換の仕方の変更(漢字変換の仕方の変更については最初のcsvファイルを編集する))
# never_used_as_roots_only=[" vin "," lin "," min "," amas "]
# for i in never_used_as_roots_only:
#     SS[i]=[i,"無詞"]

# %%
##ここで、2通りの語根分解を消去していると考えられるが、品詞別に語根分解の方法を残すべきではないのか→日本語版の全単語語根分解リストについては解決。

## SS→QQ  ("'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換し終えたリスト"(SS)を最終的な漢字置換リストに成形していく。)
##SSの'置換対象の単語'、'漢字置換後の単語'から"/"を抜く(html形式にしたい場合、"</rt></ruby>"は"/"を含むので要注意！)。
##新たに置換優先順位を表す数字を追加し(漢字化する単語は'文字数×10000'、漢字化しない単語は'文字数×10000-2500')、辞書式配列QQとして保存。
QQ={}
for i,j in SS.items():##(iが置換対象の単語、j[0]が漢字置換後の単語、j[1]が品詞。)
    if i==j[0]:##漢字化しない単語
        QQ[i.replace('/', '')]=[j[0].replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),j[1],len(i.replace('/', ''))*10000-3000]##漢字化しない単語は優先順位を下げる
    else:
        QQ[i.replace('/', '')]=[j[0].replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),j[1],len(i.replace('/', ''))*10000]

# QQ
with open("QQ.txt", 'w', encoding='utf-8') as file:
    for old,new in  QQ.items():
        file.write(f'{old},{new[0]},{new[1]},{new[2]}\n')

# %%
### 基本的には動詞に対してのみ活用語尾を追加し、置換対象の単語の文字数を増やす(置換の優先順位を上げる。)

verb_suffix_2l={'as':'as', 'is':'is', 'os':'os', 'us':'us','at':'at','it':'it','ot':'ot', 'ad':'ad','igx':'igx','ig':'ig','ant':'ant','int':'int','ont':'ont'}
##接頭辞接尾時の追加については、主に動詞が対象である。
verb_suffix_2l_2={}
for d1,d2 in verb_suffix_2l.items():
    verb_suffix_2l_2[d1]=safe_replace(d2, replacements)

# %%
verb_suffix_2l_2
# Out:
# {'as': '(!)as(現在形)',
#  'is': '(!)is(過去形)',
#  'os': '(!)os(未来形)',
#  'us': '(!)us(条件法)',
#  'at': '(!)at(受動・継続)',
#  'it': '(!)it(受動・完了)',
#  'ot': '(!)ot(受動・将然)',
#  'ad': '(!)ad(行為)',
#  'igx': '(!)igx(なる)',
#  'ig': '(!)ig(させる)',
#  'ant': '(!)ant(能動・継続)',
#  'int': '(!)int(能動・完了)',
#  'ont': '(!)ont(能動・将然)'}

# %%
###一番の工夫ポイント(如何にして置換の優先順位を定め、置換精度を向上させるか。)
##基本は単語の文字数が多い順に置換していくことになるが、
##例えば、"置換対象の単語に接頭辞、接尾辞を追加し、単語の文字数を増やし、置換の優先順位を上げたものを、置換対象の単語として新たに追加する。"などが、置換精度を上げる方策として考えられる。
##しかし、いろいろ試した結果、動詞に対してのみ活用語尾を追加し、置換対象の単語の文字数を増やす(置換の優先順位を上げる。)のが、ベストに近いことがわかった。

## SS→QQ→RR  ("'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換し終えたリスト"(SS)を最終的な漢字置換リストに成形していく。)
 
### RR内での重複の検査
# UU,VV,WW=[],[],[]
# UU_2,VV_2,WW_2,XXX=[],[],[],[]
# kosu_0,kosu_1,kosu_2,kosu_3,kosu_4,kosu_5=0,0,0,0,0,0
# kei_1,kei_2,kei_3,kei_4=0,0,0,0

# RR={}
# # 辞書をコピーする
# QQ_copy = QQ.copy()##これがあるので、2回繰り返しするときは数個前のセルに戻ってQQを作り直してからでないといけない。
# for i,j in QQ_copy.items():##j[0]:置換後の文字列　j[1]:品詞 j[2]:置換優先順位
#     if (j[1] == "名詞") and (len(i)<=6) and not(j[2]==60000 or j[2]==50000 or j[2]==40000 or j[2]==30000 or j[2]==20000):##名詞だけで、6文字以下で、漢字化しないやつ  ##置換ミスを防ぐための条件(20240614) altajo,aviso,malm,abes 固有名詞対策  意味ふりがなのときは再検討
#         for k in ["o"]:##4 ['buro', 'haloo', 'tauxro', 'unesko']
#             if not i+k in QQ_copy:##if not ありのままで良い。
#                 RR[i+k]=[j[0]+k,j[2]+len(k)*10000-2000]#実質5000 #既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
#                 kosu_0+=1
#         QQ.pop(i, None)
#         kosu_1+=1

# for i,j in QQ.items():##j[0]:置換後の文字列　j[1]:品詞 j[2]:置換優先順位
#     if j[2]==20000:##2文字で漢字化するやつ##len(i)<=2:#1文字は存在しないはずではある。
#         ##基本的に非動詞の2文字の語根単体を以て漢字置換することはない。　ただし、世界语全部单词_大约44100个(原pejvo.txt).txtに最初から含まれている2文字の語根は既に漢字化されており、実際の漢字置換にも反映されることになる。
#         ##2文字の語根でも、動詞については活用語尾を追加することで、自動的に+2文字以上できるので追加した。
#         if "名詞" in j[1]:
#             for k in ["o","on",'oj']:##"ojn"は不要か
#                 if not i+k in RR:
#                     RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
#                 if (i+k in RR):
#                     UU.append([i+k,RR[i+k][0],j[0]+k])
#         if "形容詞" in j[1]:
#             for k in ["a","aj",'an']:##"ajn"は不要か  ##sia pian ,'an 'も不要
#                 # if not i+k in QQ:##if not なしのほうが良い
#                 RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
#                 # else:
#                 #     UU.append(i+k)
#             kei_1+=1
#         if "副詞" in j[1]:
#             for k in ["e",'en']:##ege   エーゲ海を意味するegeoを元の辞書に追加
#                 # if not i+k in QQ:##if not なしのほうが良い
#                 RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
#                 # else:
#                 # UU.append(i+k)
#         if "動詞" in j[1]:
#             for k1,k2 in verb_suffix_2l_2.items():
#                 if not i+k1 in RR:
#                     RR[i+k1]=[j[0]+k2,j[2]+len(k1)*10000-3000]
#                 if (i+k1 in RR) and (j[0]+k2 != RR[i+k1][0]):
#                     UU_2.append([i+k1,RR[i+k1][0],j[0]+k2])##該当なし
#             for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
#                 if not i+k in RR:
#                     RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
#                 if (i+k in RR) and (j[0]+k != RR[i+k][0]):
#                     UU_2.append([i+k,RR[i+k][0],j[0]+k])##該当なし
#         kosu_2+=1
#         continue

#     else:
#         if (i in RR) and (j[0] != RR[i][0]):
#             XXX.append([i,RR[i][0],j[0]])##該当なし
#         RR[i]=[j[0],j[2]]##品詞情報はここで用いるためにあった。以後は不要なので省いていく。
#         if j[2]==60000 or j[2]==50000 or j[2]==40000 or j[2]==30000:##文字数が比較的少なく(<=5)、実際に漢字化するエスペラント語根(文字数×10000)のみを対象とする 
#             if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
#                 for k in ["o","on",'oj']:
#                     if not i+k in RR:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
#                     if (i+k in RR) and (j[0]+k != RR[i+k][0]):
#                         VV.append([i+k,RR[i+k][0],j[0]+k])##該当なし
#             if "形容詞" in j[1]:
#                 for k in ["a","aj",'an']:
#                     if not i+k in RR:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
#                     if (i+k in RR) and (j[0]+k != RR[i+k][0]):
#                         VV.append([i+k,RR[i+k][0],j[0]+k])##該当なし
#                 kei_2+=1
#             if "副詞" in j[1]:
#                 for k in ["e",'en']:
#                     if not i+k in RR:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
#                     if (i+k in RR) and (j[0]+k != RR[i+k][0]):
#                         VV.append([i+k,RR[i+k][0],j[0]+k])##該当なし
#             if "動詞" in j[1]:
#                 for k1,k2 in verb_suffix_2l_2.items():
#                     if not i+k1 in RR:
#                         RR[i+k1]=[j[0]+k2,j[2]+len(k1)*10000-3000]
#                     if (i+k1 in RR) and (j[0]+k2 != RR[i+k1][0]):
#                         VV_2.append([i+k1,RR[i+k1][0],j[0]+k2])##該当なし
#                 for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
#                     if not i+k in RR:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
#                     if (i+k in RR) and (j[0]+k != RR[i+k][0]):
#                         VV_2.append([i+k,RR[i+k][0],j[0]+k])##該当なし
#             kosu_3+=1            
#         elif len(i)>=3 and len(i)<=6:##3文字から6文字の語根で漢字化しないもの　　結局2文字の語根で漢字化しないものについては、完全に除外している。
#             if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
#                 for k in ["o","on",'oj']:
#                     if not i+k in RR:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]#実質3000#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
#                     if (i+k in RR) and (j[0]+k != RR[i+k][0]):
#                         WW.append([i+k,RR[i+k][0],j[0]+k])##該当なし
#             if "形容詞" in j[1]:
#                 for k in ["a","aj",'an']:
#                     if not i+k in RR:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
#                     if (i+k in RR) and (j[0]+k != RR[i+k][0]):
#                         WW.append([i+k,RR[i+k][0],j[0]+k])##該当なし
#                 kei_3+=1
#             if "副詞" in j[1]:
#                 for k in ["e",'en']:
#                     if not i+k in RR:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
#                     if (i+k in RR) and (j[0]+k != RR[i+k][0]):
#                         WW.append([i+k,RR[i+k][0],j[0]+k])##該当なし
#             if "動詞" in j[1]:
#                 for k1,k2 in verb_suffix_2l_2.items():
#                     if not i+k1 in RR:
#                         RR[i+k1]=[j[0]+k2,j[2]+(len(k1)-1)*10000-5000]
#                     if (i+k1 in RR) and (j[0]+k2 != RR[i+k1][0]):
#                         WW_2.append([i+k1,RR[i+k1][0],j[0]+k2])##該当なし
#                 for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
#                     if not i+k in RR:
#                         RR[i+k]=[j[0]+k,j[2]+(len(k)-1)*10000-5000]
#                     if (i+k in RR) and (j[0]+k != RR[i+k][0]):
#                         WW_2.append([i+k,RR[i+k][0],j[0]+k])##該当なし
#             kosu_4+=1
#         elif  i in ["regulus","kolorad","satirus","spirant","traktat","akirant","ordinat"]:#7文字以上の例外処理
#             if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
#                 for k in ["o"]:
#                     if not i+k in RR:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]#実質3000#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
#                     if (i+k in RR) and (j[0]+k != RR[i+k][0]):
#                         WW_2.append([i+k,RR[i+k][0],j[0]+k])##該当なし
#             if "形容詞" in j[1]:
#                 for k in ["a"]:
#                     if not i+k in RR:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
#                     if (i+k in RR) and (j[0]+k != RR[i+k][0]):
#                         WW_2.append([i+k,RR[i+k][0],j[0]+k])##該当なし
#             if "副詞" in j[1]:
#                 for k in ["e"]:
#                     if not i+k in RR:
#                         RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
#                     if (i+k in RR) and (j[0]+k != RR[i+k][0]):
#                         WW_2.append([i+k,RR[i+k][0],j[0]+k])##該当なし
#             if "動詞" in j[1]:
#                 for k1,k2 in verb_suffix_2l_2.items():
#                     if not i+k1 in RR:
#                         RR[i+k1]=[j[0]+k2,j[2]+(len(k1)-1)*10000-5000]
#                     if (i+k1 in RR) and (j[0]+k2 != RR[i+k1][0]):
#                         WW_2.append([i+k1,RR[i+k1][0],j[0]+k2])##該当なし
#                 for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
#                     if not i+k in RR:
#                         RR[i+k]=[j[0]+k,j[2]+(len(k)-1)*10000-5000]
#                     if (i+k in RR) and (j[0]+k != RR[i+k][0]):
#                         WW_2.append([i+k,RR[i+k][0],j[0]+k])##該当なし
#             kosu_5+=1

# print(len(UU),UU)
# print(len(VV),VV)
# print(len(WW),WW)

# print(len(UU_2),UU_2)
# print(len(VV_2),VV_2)
# print(len(WW_2),WW_2)
# print(len(XXX),XXX)
# print(kosu_0,kosu_1,kosu_2,kosu_3,kosu_4,kosu_5)
# print(kei_1,kei_2,kei_3)
# Out:
# 1 [['duon', 'du(二)on(分数)', 'du(二)on']]
# 8 [['ordon', 'ordon(命令する)', 'ord(順序)on'], ['teren', 'teren(地所)', 'ter(土地)en'], ['kanon', 'kanon(大砲)', 'kan(アシ)on'], ['kolon', 'kolon(円柱)', 'kol(首)on'], ['komision', 'komision(委員会)', 'komisi(委託する)on'], ['menton', 'menton(下あご)', 'ment(ハッカ)on'], ['samo', 'samo', 'sam(同一の)o'], ['saten', 'saten(サテン)', 'sat(満腹した)en']]
# 3 [['budhan', 'budhan(会員)', 'budhan'], ['roman', 'roman(長編小説)', 'roman'], ['person', 'person(人)', 'person']]
# 1 [['amas', 'amas(集積)', 'am(愛する)as(現在形)']]
# 26 [['akirant', 'akirant', 'akir(獲得する)ant(能動・継続)'], ['statu', 'statu(立像)', 'stat(状態)u'], ['devi', 'devi', 'dev(しなければならない)i'], ['diplomat', 'diplomat(外交官)', 'diplom(免状)at(受動・継続)'], ['pensi', 'pensi(年金)', 'pens(思う)i'], ['konus', 'konus(円錐)', 'kon(知っている)us(条件法)'], ['salat', 'salat(サラダ)', 'sal(塩)at(受動・継続)'], ['konsili', 'konsili', 'konsil(助言する)i'], ['legat', 'legat(教皇特使)', 'leg(読む)at(受動・継続)'], ['legi', 'legi(軍団)', 'leg(読む)i'], ['lekant', 'lekant(マーガレット)', 'lek(なめる)ant(能動・継続)'], ['licenci', 'licenci', 'licenc(認可)i'], ['lotus', 'lotus(ハス)', 'lot(くじ)us(条件法)'], ['patos', 'patos(パトス)', 'pat(フライパン)os(未来形)'], ['revu', 'revu(専門雑誌)', 'rev(空想する)u'], ['predikat', 'predikat(述部)', 'predik(説教する)at(受動・継続)'], ['rabat', 'rabat(割引)', 'rab(強奪する)at(受動・継続)'], ['religi', 'religi(宗教)', 're(再び)lig(結ぶ)i'], ['sekci', 'sekci(部)', 'sekc(切断する)i'], ['sendat', 'sen(なしで)dat(日付)', 'send(送る)at(受動・継続)'], ['spirit', 'spirit(精神)', 'spir(呼吸する)it(受動・完了)'], ['spirant', 'spirant', 'spir(呼吸する)ant(能動・継続)'], ['tenis', 'tenis', 'ten(支え持つ)is(過去形)'], ['traktat', 'traktat(条約)', 'trakt(取り扱う)at(受動・継続)'], ['vaku', 'vaku', 'vak(あいている)u'], ['vizit', 'vizit(訪問する)', 'viz(ビザ)it(受動・完了)']]
# 4 [['arogant', 'arogant(横柄な)', 'arogant(能動・継続)'], ['brokant', 'brokant(古物売買する)', 'brokant(能動・継続)'], ['ferlad', 'fer(鉄)lad(ブリキ板)', 'ferlad(行為)'], ['ordinat', 'ordinat', 'ordinat(受動・継続)']]
# 229 [['afrikan', 'afrik(アフリカ)an', 'afrik(アフリカ)an(会員)'], ['agat', 'ag(行動する)at(受動・継続)', 'agat(メノウ)'], ['agit', 'ag(行動する)it(受動・完了)', 'agit(扇動する)'], ['agxi', 'agx(年齢)i', 'agxi(打ち歩)'], ['akcian', 'akci(株式)an', 'akci(株式)an(会員)'], ['aldon', 'ald(アルト)on', 'al(～の方へ)don(与える)'], ['alte', 'alt(高い)e', 'alte(タチアオイ)'], ['karbon', 'karb(炭)on', 'karbon(炭素)'], ['aparten', 'apart(別々の)en', 'aparten(所属する)'], ['apoge', 'apog(支える)e', 'apoge(遠地点)'], ['asocian', 'asoci(協会)an', 'asoci(協会)an(会員)'], ['azian', 'azi(アジア)an', 'azi(アジア)an(会員)'], ['balon', 'bal(舞踏会)on', 'balon(気球)'], ['bari', 'bar(障害)i', 'bari'], ['baron', 'bar(障害)on', 'baron(男爵)'], ['baston', 'bast(じん皮)on', 'baston(棒)'], ['beton', 'bet(ビート)on', 'beton'], ['bombon', 'bomb(爆弾)on', 'bombon(キャンデー)'], ['brazilan', 'brazilan', 'brazilan(会員)'], ['breton', 'bret(棚)on', 'breton'], ['burgxon', 'burgx(ブルジョワ)on', 'burgxon(芽)'], ['centon', 'cent(百)on', 'cent(百)on(分数)'], ['ciklon', 'cikl(周期)on', 'ciklon(低気圧)'], ['citron', 'citr(チター)on', 'citron(シトロン)'], ['dekan', 'dek(十)an', 'dekan(学部長)'], ['dekon', 'dek(十)on', 'dek(十)on(分数)'], ['dezertan', 'dezert(砂漠)an', 'dezert(砂漠)an(会員)'], ['platon', 'plat(平たい)on', 'platon'], ['dietan', 'diet(規定食)an', 'diet(規定食)an(会員)'], ['diskont', 'disk(円盤)ont(能動・将然)', 'diskont(手形割引する)'], ['doman', 'dom(家)an', 'dom(家)an(会員)'], ['domen', 'dom(家)en', 'domen(ドミノ)'], ['dragon', 'dragon', 'dragon(竜騎兵)'], ['drakon', 'drak(竜)on', 'drakon'], ['premi', 'prem(押える)i', 'premi(賞品)'], ['egiptan', 'egiptan', 'egiptan(会員)'], ['eklezian', 'eklezi(教会)an', 'eklezi(教会)an(会員)'], ['elektron', 'elektr(電気)on', 'elektron'], ['endos', 'end(必要)os(未来形)', 'endos'], ['enlandan', 'en(中で)land(国)an', 'en(中で)land(国)an(会員)'], ['epikuran', 'epikuran', 'epikuran(会員)'], ['eskadron', 'eskadr(艦隊)on', 'eskadron'], ['esperant', 'esper(希望する)ant(能動・継続)', 'esperant(エスペラント)'], ['eston', 'est(である)on', 'eston'], ['estraran', 'estr(長)ar(集団)an', 'estr(長)ar(集団)an(会員)'], ['etnan', 'etn(民族)an', 'etn(民族)an(会員)'], ['euxropan', 'euxrop(ヨーロッパ)an', 'euxrop(ヨーロッパ)an(会員)'], ['familian', 'famili(家族)an', 'famili(家族)an(会員)'], ['fanfaron', 'fanfar(ファンファーレ)on', 'fanfaron(大言壮語する)'], ['fazan', 'faz(位相)an', 'fazan(キジ)'], ['feri', 'fer(鉄)i', 'feri(休日)'], ['fero', 'fer(鉄)o', 'fero'], ['procesi', 'proces(訴訟)i', 'procesi(行列)'], ['feston', 'fest(祝う)on', 'feston(花綱)'], ['flegmon', 'flegm(冷静)on', 'flegmon'], ['fleksi', 'fleks(曲げる)i', 'fleksi(語尾変化)'], ['forkant', 'fork(フォーク)ant(能動・継続)', 'for(離れて)kant(歌う)'], ['format', 'form(形)at(受動・継続)', 'format(判)'], ['forten', 'fort(強い)en', 'for(離れて)ten(支え持つ)'], ['foton', 'fot(写真、写真をとる)on', 'fot(写真、写真をとる)on(分数)'], ['fronton', 'front(正面)on', 'fronton(ペディメント)'], ['galon', 'gal(胆汁)on', 'galon(モール)'], ['ganglion', 'gangli(神経節)on', 'ganglion'], ['gravit', 'grav(重要な)it(受動・完了)', 'gravit'], ['grupan', 'grup(グループ)an', 'grup(グループ)an(会員)'], ['gvinean', 'gvinean', 'gvinean(会員)'], ['harpi', 'harpi', 'harpi(ハルピュイア)'], ['havaj', 'hav(持っている)aj', 'havaj'], ['helen', 'hel(明るい)en', 'helen'], ['helikon', 'helik(カタツムリ)on', 'helikon'], ['ilirian', 'ilirian', 'ilirian(会員)'], ['amerikan', 'amerik(アメリカ)an', 'amerik(アメリカ)an(会員)'], ['inka', 'ink(インク)a', 'inka'], ['insulan', 'insul(島)an', 'insul(島)an(会員)'], ['ionian', 'ionian', 'ionian(会員)'], ['iranan', 'iranan', 'iranan(会員)'], ['iris', 'ir(行く)is(過去形)', 'iris(虹彩)'], ['irit', 'ir(行く)it(受動・完了)', 'irit'], ['irlandan', 'irlandan', 'irlandan(会員)'], ['islaman', 'islaman', 'islaman(会員)'], ['islandan', 'islandan', 'islandan(会員)'], ['israelan', 'israelan', 'israelan(会員)'], ['jesu', 'jes(はい)u', 'jesu(イエス)'], ['jxaluzi', 'jxaluz(嫉妬深い)i', 'jxaluzi'], ['kalkan', 'kalk(石灰)an', 'kalkan(踵)'], ['kanadan', 'kanadan', 'kanadan(会員)'], ['kantat', 'kant(歌う)at(受動・継続)', 'kantat(カンタータ)'], ['kanton', 'kant(歌う)on', 'kanton(郡)'], ['kapon', 'kap(頭)on', 'kapon(去勢オンドリ)'], ['karen', 'kar(親愛な)en', 'karen'], ['karton', 'kart(カード)on', 'karton(厚紙)'], ['kaze', 'kaz(格)e', 'kaze(凝乳)'], ['kokon', 'kok(ニワトリ)on', 'kokon(繭)'], ['kolorad', 'kolor(色)ad(行為)', 'kolorad'], ['konfesi', 'konfes(告白する)i', 'konfesi'], ['orden', 'ord(順序)en', 'orden(勲章) ...
# 2601 2605 72 6982 1007 7
# 25 1967 520

# %%
# bunseki=UU+VV+WW+UU_2+VV_2+WW_2+XXX
# an=[]
# on=[]
# en=[]
# at=[]
# it=[]
# sonota=[]
# for jj in bunseki:
#     if jj[0].endswith("an"):
#         an.append(jj)
#     elif jj[0].endswith("on"):
#         on.append(jj)
#     elif jj[0].endswith("en"):
#         en.append(jj)
#     elif jj[0].endswith("at"):
#         at.append(jj)
#     elif jj[0].endswith("it"):
#         it.append(jj)
#     else:
#         sonota.append(jj)
        
# print(len(an),an)
# print(len(on),on)
# print(len(en),en)
# print(len(at),at)
# print(len(it),it)
# print(len(sonota),sonota)
# Out:
# 87 [['budhan', 'budhan(会員)', 'budhan'], ['roman', 'roman(長編小説)', 'roman'], ['afrikan', 'afrik(アフリカ)an', 'afrik(アフリカ)an(会員)'], ['akcian', 'akci(株式)an', 'akci(株式)an(会員)'], ['asocian', 'asoci(協会)an', 'asoci(協会)an(会員)'], ['azian', 'azi(アジア)an', 'azi(アジア)an(会員)'], ['brazilan', 'brazilan', 'brazilan(会員)'], ['dekan', 'dek(十)an', 'dekan(学部長)'], ['dezertan', 'dezert(砂漠)an', 'dezert(砂漠)an(会員)'], ['dietan', 'diet(規定食)an', 'diet(規定食)an(会員)'], ['doman', 'dom(家)an', 'dom(家)an(会員)'], ['egiptan', 'egiptan', 'egiptan(会員)'], ['eklezian', 'eklezi(教会)an', 'eklezi(教会)an(会員)'], ['enlandan', 'en(中で)land(国)an', 'en(中で)land(国)an(会員)'], ['epikuran', 'epikuran', 'epikuran(会員)'], ['estraran', 'estr(長)ar(集団)an', 'estr(長)ar(集団)an(会員)'], ['etnan', 'etn(民族)an', 'etn(民族)an(会員)'], ['euxropan', 'euxrop(ヨーロッパ)an', 'euxrop(ヨーロッパ)an(会員)'], ['familian', 'famili(家族)an', 'famili(家族)an(会員)'], ['fazan', 'faz(位相)an', 'fazan(キジ)'], ['grupan', 'grup(グループ)an', 'grup(グループ)an(会員)'], ['gvinean', 'gvinean', 'gvinean(会員)'], ['ilirian', 'ilirian', 'ilirian(会員)'], ['amerikan', 'amerik(アメリカ)an', 'amerik(アメリカ)an(会員)'], ['insulan', 'insul(島)an', 'insul(島)an(会員)'], ['ionian', 'ionian', 'ionian(会員)'], ['iranan', 'iranan', 'iranan(会員)'], ['irlandan', 'irlandan', 'irlandan(会員)'], ['islaman', 'islaman', 'islaman(会員)'], ['islandan', 'islandan', 'islandan(会員)'], ['israelan', 'israelan', 'israelan(会員)'], ['kalkan', 'kalk(石灰)an', 'kalkan(踵)'], ['kanadan', 'kanadan', 'kanadan(会員)'], ['koran', 'kor(心)an', 'koran(コーラン)'], ['kuban', 'kub(立方体)an', 'kub(立方体)an(会員)'], ['landan', 'land(国)an', 'land(国)an(会員)'], ['laosan', 'laosan', 'laosan(会員)'], ['lernejan', 'lern(学習する)ej(場所)an', 'lern(学習する)ej(場所)an(会員)'], ['libian', 'libian', 'libian(会員)'], ['ligan', 'lig(結ぶ)an', 'lig(結ぶ)an(会員)'], ['lokan', 'lok(場所)an', 'lok(場所)an(会員)'], ['majoran', 'major(陸軍少佐)an', 'major(陸軍少佐)an(会員)'], ['malavian', 'malavian', 'malavian(会員)'], ['marian', 'mari(マリア)an', 'marian'], ['meksikan', 'meksikan', 'meksikan(会員)'], ['montan', 'mont(山)an', 'mont(山)an(会員)'], ['montaran', 'mont(山)ar(集団)an', 'mont(山)ar(集団)an(会員)'], ['movadan', 'mov(動かす)ad(行為)an', 'mov(動かす)ad(行為)an(会員)'], ['nacian', 'naci(国民)an', 'naci(国民)an(会員)'], ['nepalan', 'nepalan', 'nepalan(会員)'], ['nordan', 'nord(北)an', 'nord(北)an(会員)'], ['orientan', 'orient(東)an', 'orient(東)an(会員)'], ['paran', 'par(一対)an', 'paran'], ['parizan', 'pariz(パリ)an', 'pariz(パリ)an(会員)'], ['parokan', 'parok(教区)an', 'parok(教区)an(会員)'], ['partian', 'parti(党派)an', 'parti(党派)an(会員)'], ['podian', 'podi(ひな壇)an', 'podi(ひな壇)an(会員)'], ['polican', 'polic(警察)an', 'polic(警察)an(会員)'], ['popolan', 'popol(人民)an', 'popol(人民)an(会員)'], ['regnan', 'regn(国家)an', 'regn(国家)an(会員)'], ['religian', 'religi(宗教)an', 'religi(宗教)an(会員)'], ['romian', 'romian', 'romian(会員)'], ['rusian', 'rus(ロシア人)ian', 'rus(ロシア人)ian(会員)'], ['satan', 'sat(満腹した)an', 'satan(サタン)'], ['sektan', 'sekt(宗派)an', 'sekt(宗派)an(会員)'], ['senatan', 'senat(参議院)an', 'senat(参議院)an(会員)'], ['sirian', 'sirian', 'sirian(会員)'], ['skisman', 'skism(分裂)an', 'skism(分裂)an(会員)'], ['socian', 'soci(社会)an', 'soci(社会)an(会員)'], ['societan', 'societ(会)an', 'societ(会)an(会員)'], ['somalian', 'somalian', 'somalian(会員)'], ['sovetan', 'sovetan', 'sovetan(会員)'], ['sovetian', 'sovetian', 'sovetian(会員)'], ['sudan', 'sud(南)an', 'sudan'], ['sudanan', 'sudanan', 'sudanan(会員)'], ['sxipan', 'sxip(船)an', 'sxip(船)an(会員)'], ['sxtatan', 'sxtat(国家)an', 'sxtat(国家)an(会員)'], ['tibetan', 'tibetan', 'tibetan(会員)'], ['togolan', 'togolan', 'togolan(会員)'], ['tokian', 'tokian', 'tokian(会員)'], ['tongan', 'tongan', 'tongan(会員)'], ['triban', 'triban', 'triban(会員)'], ['trojan', 'trojan', 'trojan(会員)'], ['urban', 'urb(市)an', 'urb(市)an(会員)'], ['usonan', 'usonan', 'usonan(会員)'], ['utopian', 'utopi(ユートピア)an', 'utopi(ユートピア)an(会員)'], ['vilagxan', 'vilagx(村)an', 'vilagx(村)an(会員)']]
# 72 [['duon', 'du(二)on(分数)', 'du(二)on'], ['ordon', 'ordon(命令する)', 'ord(順序)on'], ['kanon', 'kanon(大砲)', 'kan(アシ)on'], ['kolon', 'kolon(円柱)', 'kol(首)on'], ['komision', 'komision(委員会)', 'komisi(委託する)on'], ['menton', 'menton(下あご)', 'ment(ハッカ)on'], ['person', 'person(人)', 'person'], ['aldon', 'ald(アルト)on', 'al(～の方へ)don(与える)'], ['karbon', 'karb(炭)on', 'karbon(炭素)'], ['balon', 'bal(舞踏会)on', 'balon(気球)'], ['baron', 'bar(障害)on', 'baron(男爵)'], ['baston', 'bast(じん皮)on', 'baston(棒)'], ['beton', 'bet(ビート)on', 'beton'], ['bombon', 'bomb(爆弾)on', 'bombon(キャンデー)'], ['breton', 'bret(棚)on', 'breton'], ['burgxon', 'burgx(ブルジョワ)on', 'burgxon(芽)'], ['centon', 'cent(百)on', 'cent(百)on(分数)'], ['ciklon', 'cikl(周期)on', 'ciklon(低気圧)'], ['citron', 'citr(チター)on', 'citron(シトロン)'], ['dekon', 'dek(十)on', 'dek(十)on(分数)'], ['platon', 'plat(平たい)on', 'platon'], ['dragon', 'dragon', 'dragon(竜騎兵)'], ['drakon', 'drak(竜)on', 'drakon'], ['elektron', 'elektr(電気)on', 'elektron'], ['eskadron', 'eskadr(艦隊)on', 'eskadron'], ['eston', 'est(である)on', 'eston'], ['fanfaron', 'fanfar(ファンファーレ)on', 'fanfaron(大言壮語する)'], ['feston', 'fest(祝う)on', 'feston(花綱)'], ['flegmon', 'flegm(冷静)on', 'flegmon'], ['foton', 'fot(写真、写真をとる)on', 'fot(写真、写真をとる)on(分数)'], ['fronton', 'front(正面)on', 'fronton(ペディメント)'], ['galon', 'gal(胆汁)on', 'galon(モール)'], ['ganglion', 'gangli(神経節)on', 'ganglion'], ['helikon', 'helik(カタツムリ)on', 'helikon'], ['kanton', 'kant(歌う)on', 'kanton(郡)'], ['kapon', 'kap(頭)on', 'kapon(去勢オンドリ)'], ['karton', 'kart(カード)on', 'karton(厚紙)'], ['kokon', 'kok(ニワトリ)on', 'kokon(繭)'], ['salon', 'sal(塩)on', 'salon(サロン)'], ['koton', 'kot(泥)on', 'koton(綿)'], ['kripton', 'kript(地下聖堂)on', 'kripton'], ['kupon', 'kup(吸い玉)on', 'kupon(クーポン券)'], ['kvaron', 'kvar(四)on', 'kvar(四)on(分数)'], ['kvinon', 'kvin(五)on', 'kvin(五)on(分数)'], ['lakon', 'lak(ラッカー)on', 'lakon'], ['ludon', 'lud(遊ぶ)on', 'lu(賃借する)don(与える)'], ['magneton', 'magnet(磁石)on', 'magneton'], ['mason', 'mas(かたまり)on', 'mason(築く)'], ['melon', 'mel(アナグマ)on', 'melon(メロン)'], ['milion', 'mili(キビ)on', 'milion(百万)'], ['milionon', 'milion(百万)on', 'milion(百万)on(分数)'], ['milon', 'mil(千)on', 'mil(千)on(分数)'], ['mondon', 'mond(世界)on', 'mon(金銭)don(与える)'], ['nauxon', 'naux(九)on', 'naux(九)on(分数)'], ['nombron', 'nombr(数)on', 'nombr(数)on(分数)'], ['papilion', 'papili(チョウ)on', 'papilion'], ['patron', 'patr(父)on', 'patron(後援者)'], ['pension', 'pensi(年金)on', 'pension(下宿屋)'], ['peron', 'per(よって)on', 'peron(階段)'], ['ponton', 'pont(橋)on', 'ponton(平底舟)'], ['senson', 'sens(感覚)on', 'sen(なしで)son(音がする)'], ['senton', 'sent(感じる)on', 'sen(なしで)ton(楽音)'], ['sepon', 'sep(七)on', 'sep(七)on(分数)'], ['seson', 'ses(六)on', 'ses(六)on(分数)'], ['skadron', 'skadr(騎兵中隊)on', 'skadron'], ['stadion', 'stadi(段階)on', 'stadion(スタジアム)'], ['tetraon', 'tetra(エゾライチョウ)on', 'tetraon'], ['timon', 'tim(恐れる)on', 'timon(かじ棒)'], ['trion', 'tri(三)on', 'tri(三)on(分数)'], ['trombon', 'tromb(たつまき)on', 'trombon(トロンボーン)'], ['valon', 'val(谷)on', 'valon'], ['violon', 'viol(スミレ)on', 'violon(バイオリン)']]
# 12 [['teren', 'teren(地所)', 'ter(土地)en'], ['saten', 'saten(サテン)', 'sat(満腹した)en'], ['aparten', 'apart(別々の)en', 'aparten(所属する)'], ['domen', 'dom(家)en', 'domen(ドミノ)'], ['forten', 'fort(強い)en', 'for(離れて)ten(支え持つ)'], ['helen', 'hel(明るい)en', 'helen'], ['karen', 'kar(親愛な)en', 'karen'], ['orden', 'ord(順序)en', 'orden(勲章)'], ['platen', 'plat(平たい)en', 'platen(白金)'], ['posten', 'post(後で)en', 'posten(部署)'], ['reten', 'ret(網)en', 're(再び)ten(支え持つ)'], ['solen', 'sol(唯一の)en', 'solen(荘厳な)']]
# 12 [['diplomat', 'diplomat(外交官)', 'diplom(免状)at(受動・継続)'], ['salat', 'salat(サラダ)', 'sal(塩)at(受動・継続)'], ['legat', 'legat(教皇特使)', 'leg(読む)at(受動・継続)'], ['predikat', 'predikat(述部)', 'predik(説教する)at(受動・継続)'], ['rabat', 'rabat(割引)', 'rab(強奪する)at(受動・継続)'], ['sendat', 'sen(なしで)dat(日付)', 'send(送る)at(受動・継続)'], ['traktat', 'traktat(条約)', 'trakt(取り扱う)at(受動・継続)'], ['ordinat', 'ordinat', 'ordinat(受動・継続)'], ['agat', 'ag(行動する)at(受動・継続)', 'agat(メノウ)'], ['format', 'form(形)at(受動・継続)', 'format(判)'], ['kantat', 'kant(歌う)at(受動・継続)', 'kantat(カンタータ)'], ['sonat', 'son(音がする)at(受動・継続)', 'sonat(ソナタ)']]
# 7 [['spirit', 'spirit(精神)', 'spir(呼吸する)it(受動・完了)'], ['vizit', 'vizit(訪問する)', 'viz(ビザ)it(受動・完了)'], ['agit', 'ag(行動する)it(受動・完了)', 'agit(扇動する)'], ['gravit', 'grav(重要な)it(受動・完了)', 'gravit'], ['irit', 'ir(行く)it(受動・完了)', 'irit'], ['revizit', 'revizit(受動・完了)', 're(再び)vizit(訪問する)'], ['trilit', 'tril(トリル)it(受動・完了)', 'tri(三)lit(ベッド)']]
# 82 [['samo', 'samo', 'sam(同一の)o'], ['amas', 'amas(集積)', 'am(愛する)as(現在形)'], ['akirant', 'akirant', 'akir(獲得する)ant(能動・継続)'], ['statu', 'statu(立像)', 'stat(状態)u'], ['devi', 'devi', 'dev(しなければならない)i'], ['pensi', 'pensi(年金)', 'pens(思う)i'], ['konus', 'konus(円錐)', 'kon(知っている)us(条件法)'], ['konsili', 'konsili', 'konsil(助言する)i'], ['legi', 'legi(軍団)', 'leg(読む)i'], ['lekant', 'lekant(マーガレット)', 'lek(なめる)ant(能動・継続)'], ['licenci', 'licenci', 'licenc(認可)i'], ['lotus', 'lotus(ハス)', 'lot(くじ)us(条件法)'], ['patos', 'patos(パトス)', 'pat(フライパン)os(未来形)'], ['revu', 'revu(専門雑誌)', 'rev(空想する)u'], ['religi', 'religi(宗教)', 're(再び)lig(結ぶ)i'], ['sekci', 'sekci(部)', 'sekc(切断する)i'], ['spirant', 'spirant', 'spir(呼吸する)ant(能動・継続)'], ['tenis', 'tenis', 'ten(支え持つ)is(過去形)'], ['vaku', 'vaku', 'vak(あいている)u'], ['arogant', 'arogant(横柄な)', 'arogant(能動・継続)'], ['brokant', 'brokant(古物売買する)', 'brokant(能動・継続)'], ['ferlad', 'fer(鉄)lad(ブリキ板)', 'ferlad(行為)'], ['agxi', 'agx(年齢)i', 'agxi(打ち歩)'], ['alte', 'alt(高い)e', 'alte(タチアオイ)'], ['apoge', 'apog(支える)e', 'apoge(遠地点)'], ['bari', 'bar(障害)i', 'bari'], ['diskont', 'disk(円盤)ont(能動・将然)', 'diskont(手形割引する)'], ['premi', 'prem(押える)i', 'premi(賞品)'], ['endos', 'end(必要)os(未来形)', 'endos'], ['esperant', 'esper(希望する)ant(能動・継続)', 'esperant(エスペラント)'], ['feri', 'fer(鉄)i', 'feri(休日)'], ['fero', 'fer(鉄)o', 'fero'], ['procesi', 'proces(訴訟)i', 'procesi(行列)'], ['fleksi', 'fleks(曲げる)i', 'fleksi(語尾変化)'], ['forkant', 'fork(フォーク)ant(能動・継続)', 'for(離れて)kant(歌う)'], ['harpi', 'harpi', 'harpi(ハルピュイア)'], ['havaj', 'hav(持っている)aj', 'havaj'], ['inka', 'ink(インク)a', 'inka'], ['iris', 'ir(行く)is(過去形)', 'iris(虹彩)'], ['jesu', 'jes(はい)u', 'jesu(イエス)'], ['jxaluzi', 'jxaluz(嫉妬深い)i', 'jxaluzi'], ['kaze', 'kaz(格)e', 'kaze(凝乳)'], ['kolorad', 'kolor(色)ad(行為)', 'kolorad'], ['konfesi', 'konfes(告白する)i', 'konfesi'], ['kore', 'kor(心)e', 'kore'], ['lama', 'lam(びっこの)a', 'lama(ラマ僧)'], ['logxi', 'logx(住む)i', 'logxi(桟敷)'], ['premis', 'prem(押える)is(過去形)', 'premis(前提)'], ['malaj', 'mal(正反対)aj', 'malaj'], ['male', 'mal(正反対)e', 'male'], ['malvolont', 'mal(正反対)vol(意志がある)ont(能動・将然)', 'mal(正反対)volont(自ら進んで)'], ['mankis', 'mank(欠けている)is(過去形)', 'man(手)kis(キスする)'], ['markot', 'mark(しるし)ot(受動・将然)', 'markot(取木)'], ['meti', 'met(置く)i', 'meti(手仕事)'], ['minus', 'min(鉱山)us(条件法)', 'minus(マイナス)'], ['noktu', 'nokt(夜)u', 'noktu(コフクロウ)'], ['nomad', 'nom(名前)ad(行為)', 'nomad(遊牧民)'], ['pasi', 'pas(通過する)i', 'pasi(情熱)'], ['patrici', 'patrici', 'patrici(貴族)'], ['pere', 'per(よって)e', 'pere(破滅する)'], ['rabi', 'rab(強奪する)i', 'rabi(狂犬病)'], ['rabot', 'rab(強奪する)ot(受動・将然)', 'rabot(かんなをかける)'], ['radius', 'radi(線)us(条件法)', 'radius'], ['refoj', 'ref(リーフ)oj', 're(再び)foj(回)'], ['regulus', 'regul(規則)us(条件法)', 'regulus'], ['remont', 'rem(漕ぐ)ont(能動・将然)', 'remont'], ['revizi', 'revizi', 'revizi(校閲する)'], ['sagu', 'sag(矢)u', 'sagu(サゴ粉)'], ['satirus', 'satir(諷刺)us(条件法)', 'satirus'], ['savoj', 'sav(救助する)oj', 'savoj'], ['sendi', 'send(送る)i', 'sen(なしで)di(神)'], ['sendot', 'send(送る)ot(受動・将然)', 'sen(なしで)dot(持参金)'], ['sole', 'sol(唯一の)e', 'sole(シタビラメ)'], ['sugesti', 'sugesti', 'sugesti(暗示)'], ['taksus', 'taks(評価する)us(条件法)', 'taksus(イチイ)'], ['tempi', 'temp(時間)i', 'tempi(こめかみ)'], ['teni', 'ten(支え持つ)i', 'teni(サナダムシ)'], ['trikot', 'trik(編み物をする)ot(受動・将然)', 'trikot(トリコット)'], ['vakcini', 'vakcin(ワクチン)i', 'vakcini'], ['veto', 'vet(賭ける)o', 'veto'], ['vizi', 'viz(ビザ)i', 'vizi(幻影)'], ['volont', 'vol(意志がある)ont(能動・将然)', 'volont(自ら進んで)']]

# %%
###一番の工夫ポイント(如何にして置換の優先順位を定め、置換精度を向上させるか。)
##基本は単語の文字数が多い順に置換していくことになるが、
##例えば、"置換対象の単語に接頭辞、接尾辞を追加し、単語の文字数を増やし、置換の優先順位を上げたものを、置換対象の単語として新たに追加する。"などが、置換精度を上げる方策として考えられる。
##しかし、いろいろ試した結果、動詞に対してのみ活用語尾を追加し、置換対象の単語の文字数を増やす(置換の優先順位を上げる。)のが、ベストに近いことがわかった。

## SS→QQ→RR  ("'単語の語尾だけをカットした、完全に語根分解された状態の全単語リスト'(result)を漢字置換し終えたリスト"(SS)を最終的な漢字置換リストに成形していく。)

### RR内での重複の検査
UU,VV,WW=[],[],[]
UU_2,VV_2,WW_2,XXX=[],[],[],[]
kosu_0,kosu_1,kosu_2,kosu_3,kosu_4,kosu_5=0,0,0,0,0,0
kei_1,kei_2,kei_3,kei_4=0,0,0,0

RR={}
# 辞書をコピーする
QQ_copy = QQ.copy()##これがあるので、2回繰り返しするときは数個前のセルに戻ってQQを作り直してからでないといけない。
for i,j in QQ_copy.items():##j[0]:置換後の文字列　j[1]:品詞 j[2]:置換優先順位
    if (j[1] == "名詞") and (len(i)<=6) and not(j[2]==60000 or j[2]==50000 or j[2]==40000 or j[2]==30000 or j[2]==20000):##名詞だけで、6文字以下で、漢字化しないやつ  ##置換ミスを防ぐための条件(20240614) altajo,aviso,malm,abes 固有名詞対策  意味ふりがなのときは再検討
        for k in ["o"]:##4 ['buro', 'haloo', 'tauxro', 'unesko']
            if not i+k in QQ_copy:##if not ありのままで良い。
                RR[i+k]=[j[0]+k,j[2]+len(k)*10000-2000]#実質5000 #既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
                kosu_0+=1
        QQ.pop(i, None)
        kosu_1+=1

for i,j in QQ.items():##j[0]:置換後の文字列　j[1]:品詞 j[2]:置換優先順位
    if j[2]==20000:##2文字で漢字化するやつ##len(i)<=2:#1文字は存在しないはずではある。
        ##基本的に非動詞の2文字の語根単体を以て漢字置換することはない。　ただし、世界语全部单词_大约44100个(原pejvo.txt).txtに最初から含まれている2文字の語根は既に漢字化されており、実際の漢字置換にも反映されることになる。
        ##2文字の語根でも、動詞については活用語尾を追加することで、自動的に+2文字以上できるので追加した。
        if "名詞" in j[1]:
            for k in ["o","on",'oj']:##"ojn"は不要か
                if not i+k in QQ:
                    RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
                else:
                    UU.append([i+k,QQ[i+k][0],j[0]+k])
        if "形容詞" in j[1]:
            for k in ["a","aj",'an']:##"ajn"は不要か  ##sia pian ,'an 'も不要
                # if not i+k in QQ:##if not なしのほうが良い
                RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
                # else:
                #     UU.append(i+k)
            kei_1+=1
        if "副詞" in j[1]:
            for k in ["e",'en']:##ege   エーゲ海を意味するegeoを元の辞書に追加
                # if not i+k in QQ:##if not なしのほうが良い
                RR[' '+i+k]=[' '+j[0]+k,j[2]+(len(k)+1)*10000-5000]
                # else:
                # UU.append(i+k)
        if "動詞" in j[1]:
            for k1,k2 in verb_suffix_2l_2.items():
                if not i+k1 in QQ:
                    RR[i+k1]=[j[0]+k2,j[2]+len(k1)*10000-3000]
                elif j[0]+k2 != QQ[i+k1][0]:
                    UU_2.append([i+k1,QQ[i+k1][0],j[0]+k2])##該当なし
            for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                if not i+k in QQ:
                    RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                elif j[0]+k != QQ[i+k][0]:
                    UU_2.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
        kosu_2+=1
        continue

    else:
        RR[i]=[j[0],j[2]]##品詞情報はここで用いるためにあった。以後は不要なので省いていく。
        if j[2]==60000 or j[2]==50000 or j[2]==40000 or j[2]==30000:##文字数が比較的少なく(<=5)、実際に漢字化するエスペラント語根(文字数×10000)のみを対象とする 
            if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
                for k in ["o","on",'oj']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
                    elif j[0]+k != QQ[i+k][0]:
                        VV.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            if "形容詞" in j[1]:
                for k in ["a","aj",'an']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                    elif j[0]+k != QQ[i+k][0]:
                        VV.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
                kei_2+=1
            if "副詞" in j[1]:
                for k in ["e",'en']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                    elif j[0]+k != QQ[i+k][0]:
                        VV.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            if "動詞" in j[1]:
                for k1,k2 in verb_suffix_2l_2.items():
                    if not i+k1 in QQ:
                        RR[i+k1]=[j[0]+k2,j[2]+len(k1)*10000-3000]
                    elif j[0]+k2 != QQ[i+k1][0]:
                        VV_2.append([i+k1,QQ[i+k1][0],j[0]+k2])##該当なし
                for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-3000]
                    elif j[0]+k != QQ[i+k][0]:
                        VV_2.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            kosu_3+=1            
        elif len(i)>=3 and len(i)<=6:##3文字から6文字の語根で漢字化しないもの　　結局2文字の語根で漢字化しないものについては、完全に除外している。
            if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
                for k in ["o","on",'oj']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]#実質3000#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
                    elif j[0]+k != QQ[i+k][0]:
                        WW.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            if "形容詞" in j[1]:
                for k in ["a","aj",'an']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
                    elif j[0]+k != QQ[i+k][0]:
                        WW.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
                kei_3+=1
            if "副詞" in j[1]:
                for k in ["e",'en']:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
                    elif j[0]+k != QQ[i+k][0]:
                        WW.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            if "動詞" in j[1]:
                for k1,k2 in verb_suffix_2l_2.items():
                    if not i+k1 in QQ:
                        RR[i+k1]=[j[0]+k2,j[2]+(len(k1)-1)*10000-5000]
                    elif j[0]+k2 != QQ[i+k1][0]:
                        WW_2.append([i+k1,QQ[i+k1][0],j[0]+k2])##該当なし
                for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+(len(k)-1)*10000-5000]
                    elif j[0]+k != QQ[i+k][0]:
                        WW_2.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            kosu_4+=1
        elif  i in ["regulus","kolorad","satirus","spirant","traktat","akirant","ordinat"]:#7文字以上の例外処理
            if "名詞" in j[1]:##名詞については形容詞、副詞と違い、漢字化しないものにもoをつける。
                for k in ["o"]:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]#実質3000#既存でないものは優先順位を大きく下げる→普通の品詞接尾辞が既存でないという言い方はおかしい気がしてきた。(20240612)
                    if (i+k in QQ) and (j[0]+k != QQ[i+k][0]):
                        WW_2.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            if "形容詞" in j[1]:
                for k in ["a"]:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
                    if (i+k in QQ) and (j[0]+k != QQ[i+k][0]):
                        WW_2.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            if "副詞" in j[1]:
                for k in ["e"]:
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+len(k)*10000-5000]
                    if (i+k in QQ) and (j[0]+k != QQ[i+k][0]):
                        WW_2.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            if "動詞" in j[1]:
                for k1,k2 in verb_suffix_2l_2.items():
                    if not i+k1 in QQ:
                        RR[i+k1]=[j[0]+k2,j[2]+(len(k1)-1)*10000-5000]
                    if (i+k1 in QQ) and (j[0]+k2 != QQ[i+k1][0]):
                        WW_2.append([i+k1,QQ[i+k1][0],j[0]+k2])##該当なし
                for k in ["u ","i ","u","i"]:##動詞の"u","i"単体の接尾辞は後ろが空白と決まっているので、2文字分増やすことができる。
                    if not i+k in QQ:
                        RR[i+k]=[j[0]+k,j[2]+(len(k)-1)*10000-5000]
                    if (i+k in QQ) and (j[0]+k != QQ[i+k][0]):
                        WW_2.append([i+k,QQ[i+k][0],j[0]+k])##該当なし
            kosu_5+=1
print(len(UU),UU)
print(len(VV),VV)
print(len(WW),WW)

print(len(UU_2),UU_2)
print(len(VV_2),VV_2)
print(len(WW_2),WW_2)
print(len(XXX),XXX)
print(kosu_0,kosu_1,kosu_2,kosu_3,kosu_4,kosu_5)
print(kei_1,kei_2,kei_3)
# Out:
# 3 [['alo', '(!)alo(アロエ)', '(!)al(～の方へ)o'], ['duon', '(!)du(二)(!)on(分数)', '(!)du(二)on'], ['okon', '(!)ok(八)(!)on(分数)', '(!)ok(八)on']]
# 152 [['dietan', '(!)diet(規定食)(!)an(会員)', '(!)diet(規定食)an'], ['nombron', '(!)nombr(数)(!)on(分数)', '(!)nombr(数)on'], ['patron', '(!)patron(後援者)', '(!)patr(父)on'], ['afrikan', '(!)afrik(アフリカ)(!)an(会員)', '(!)afrik(アフリカ)an'], ['movadan', '(!)mov(動かす)(!)ad(行為)(!)an(会員)', '(!)mov(動かす)(!)ad(行為)an'], ['akcian', '(!)akci(株式)(!)an(会員)', '(!)akci(株式)an'], ['karbon', '(!)karbon(炭素)', '(!)karb(炭)on'], ['ciklon', '(!)ciklon(低気圧)', '(!)cikl(周期)on'], ['aldon', '(!)al(～の方へ)(!)don(与える)', '(!)ald(アルト)on'], ['alte', '(!)alte(タチアオイ)', '(!)alt(高い)e'], ['montaran', '(!)mont(山)(!)ar(集団)(!)an(会員)', '(!)mont(山)(!)ar(集団)an'], ['forten', '(!)for(離れて)(!)ten(支え持つ)', '(!)fort(強い)en'], ['amerikan', '(!)amerik(アメリカ)(!)an(会員)', '(!)amerik(アメリカ)an'], ['regnan', '(!)regn(国家)(!)an(会員)', '(!)regn(国家)an'], ['aparten', '(!)aparten(所属する)', '(!)apart(別々の)en'], ['apoge', '(!)apoge(遠地点)', '(!)apog(支える)e'], ['dezertan', '(!)dezert(砂漠)(!)an(会員)', '(!)dezert(砂漠)an'], ['asocian', '(!)asoci(協会)(!)an(会員)', '(!)asoci(協会)an'], ['insulan', '(!)insul(島)(!)an(会員)', '(!)insul(島)an'], ['azian', '(!)azi(アジア)(!)an(会員)', '(!)azi(アジア)an'], ['balon', '(!)balon(気球)', '(!)bal(舞踏会)on'], ['sxtatan', '(!)sxtat(国家)(!)an(会員)', '(!)sxtat(国家)an'], ['baron', '(!)baron(男爵)', '(!)bar(障害)on'], ['baston', '(!)baston(棒)', '(!)bast(じん皮)on'], ['magneton', 'magneton', '(!)magnet(磁石)on'], ['beton', 'beton', '(!)bet(ビート)on'], ['doman', '(!)dom(家)(!)an(会員)', '(!)dom(家)an'], ['domen', '(!)domen(ドミノ)', '(!)dom(家)en'], ['montan', '(!)mont(山)(!)an(会員)', '(!)mont(山)an'], ['bombon', '(!)bombon(キャンデー)', '(!)bomb(爆弾)on'], ['familian', '(!)famili(家族)(!)an(会員)', '(!)famili(家族)an'], ['breton', 'breton', '(!)bret(棚)on'], ['burgxon', '(!)burgxon(芽)', '(!)burgx(ブルジョワ)on'], ['centon', '(!)cent(百)(!)on(分数)', '(!)cent(百)on'], ['milon', '(!)mil(千)(!)on(分数)', '(!)mil(千)on'], ['kanton', '(!)kanton(郡)', '(!)kant(歌う)on'], ['citron', '(!)citron(シトロン)', '(!)citr(チター)on'], ['papilion', 'papilion', '(!)papili(チョウ)on'], ['kaze', '(!)kaze(凝乳)', '(!)kaz(格)e'], ['urban', '(!)urb(市)(!)an(会員)', '(!)urb(市)an'], ['inka', 'inka', '(!)ink(インク)a'], ['popolan', '(!)popol(人民)(!)an(会員)', '(!)popol(人民)an'], ['platon', 'platon', '(!)plat(平たい)on'], ['platen', '(!)platen(白金)', '(!)plat(平たい)en'], ['dekon', '(!)dek(十)(!)on(分数)', '(!)dek(十)on'], ['dekan', '(!)dekan(学部長)', '(!)dek(十)an'], ['kvaron', '(!)kvar(四)(!)on(分数)', '(!)kvar(四)on'], ['kvinon', '(!)kvin(五)(!)on(分数)', '(!)kvin(五)on'], ['seson', '(!)ses(六)(!)on(分数)', '(!)ses(六)on'], ['partian', '(!)parti(党派)(!)an(会員)', '(!)parti(党派)an'], ['trion', '(!)tri(三)(!)on(分数)', '(!)tri(三)on'], ['reten', '(!)re(再び)(!)ten(支え持つ)', '(!)ret(網)en'], ['karton', '(!)karton(厚紙)', '(!)kart(カード)on'], ['posten', '(!)posten(部署)', '(!)post(後で)en'], ['foton', '(!)fot(写真、写真をとる)(!)on(分数)', '(!)fot(写真、写真をとる)on'], ['peron', '(!)peron(階段)', '(!)per(よって)on'], ['pere', '(!)pere(破滅する)', '(!)per(よって)e'], ['elektron', 'elektron', '(!)elektr(電気)on'], ['lokan', '(!)lok(場所)(!)an(会員)', '(!)lok(場所)an'], ['drakon', 'drakon', '(!)drak(竜)on'], ['sxipan', '(!)sxip(船)(!)an(会員)', '(!)sxip(船)an'], ['eklezian', '(!)eklezi(教会)(!)an(会員)', '(!)eklezi(教会)an'], ['landan', '(!)land(国)(!)an(会員)', '(!)land(国)an'], ['mondon', '(!)mon(金銭)(!)don(与える)', '(!)mond(世界)on'], ['orientan', '(!)orient(東)(!)an(会員)', '(!)orient(東)an'], ['lernejan', '(!)lern(学習する)(!)ej(場所)(!)an(会員)', '(!)lern(学習する)(!)ej(場所)an'], ['pension', '(!)pension(下宿屋)', '(!)pensi(年金)on'], ['enlandan', '(!)en(中で)(!)land(国)(!)an(会員)', '(!)en(中で)(!)land(国)an'], ['ordon', '(!)ordon(命令する)', '(!)ord(順序)on'], ['orden', '(!)orden(勲章)', '(!)ord(順序)en'], ['eskadron', 'eskadron', '(!)eskadr(艦隊)on'], ['senton', '(!)sen(なしで)(!)ton(楽音)', '(!)sent(感じる)on'], ['eston', 'eston', '(!)est(である)on'], ['kalkan', '(!)kalkan(踵)', '(!)kalk(石灰)an'], ['estraran', '(!)estr(長)(!)ar(集団)(!)an(会員)', '(!)estr(長)(!)ar(集団)an'], ['etnan', '(!)etn(民族)(!)an(会員)', '(!)etn(民族)an'], ['euxropan', '(!)euxrop(ヨーロッパ)(!)an(会員)', '(!)euxrop(ヨーロッパ)an'], ['fanfaron', '(!)fanfaron(大言壮語する)', '(!)fanfar(ファンファーレ)on'], ['fazan', '(!)fazan(キジ)', '(!)faz( ...
# 34 [['brazilan', 'brazil(!)an(会員)', 'brazilan'], ['budhan', 'budh(!)an(会員)', 'budhan'], ['dragon', '(!)dragon(竜騎兵)', 'dragon'], ['egiptan', 'egipt(!)an(会員)', 'egiptan'], ['gvinean', 'gvine(!)an(会員)', 'gvinean'], ['epikuran', 'epikur(!)an(会員)', 'epikuran'], ['ilirian', 'iliri(!)an(会員)', 'ilirian'], ['ionian', 'ioni(!)an(会員)', 'ionian'], ['iranan', 'iran(!)an(会員)', 'iranan'], ['irlandan', 'irland(!)an(会員)', 'irlandan'], ['islaman', 'islam(!)an(会員)', 'islaman'], ['islandan', 'island(!)an(会員)', 'islandan'], ['israelan', 'israel(!)an(会員)', 'israelan'], ['kanadan', 'kanad(!)an(会員)', 'kanadan'], ['roman', '(!)roman(長編小説)', 'roman'], ['laosan', 'laos(!)an(会員)', 'laosan'], ['libian', 'libi(!)an(会員)', 'libian'], ['malavian', 'malavi(!)an(会員)', 'malavian'], ['meksikan', 'meksik(!)an(会員)', 'meksikan'], ['nepalan', 'nepal(!)an(会員)', 'nepalan'], ['person', '(!)person(人)', 'person'], ['romian', 'romi(!)an(会員)', 'romian'], ['sirian', 'siri(!)an(会員)', 'sirian'], ['somalian', 'somali(!)an(会員)', 'somalian'], ['sovetan', 'sovet(!)an(会員)', 'sovetan'], ['sovetian', 'soveti(!)an(会員)', 'sovetian'], ['sudanan', 'sudan(!)an(会員)', 'sudanan'], ['tibetan', 'tibet(!)an(会員)', 'tibetan'], ['togolan', 'togol(!)an(会員)', 'togolan'], ['tokian', 'toki(!)an(会員)', 'tokian'], ['tongan', 'tong(!)an(会員)', 'tongan'], ['triban', 'trib(!)an(会員)', 'triban'], ['trojan', 'troj(!)an(会員)', 'trojan'], ['usonan', 'uson(!)an(会員)', 'usonan']]
# 5 [['agat', '(!)agat(メノウ)', '(!)ag(行動する)(!)at(受動・継続)'], ['agit', '(!)agit(扇動する)', '(!)ag(行動する)(!)it(受動・完了)'], ['amas', '(!)amas(集積)', '(!)am(愛する)(!)as(現在形)'], ['iris', '(!)iris(虹彩)', '(!)ir(行く)(!)is(過去形)'], ['irit', 'irit', '(!)ir(行く)(!)it(受動・完了)']]
# 71 [['regulus', 'regulus', '(!)regul(規則)(!)us(条件法)'], ['agxi', '(!)agxi(打ち歩)', '(!)agx(年齢)i'], ['akirant', 'akirant', '(!)akir(獲得する)(!)ant(能動・継続)'], ['radius', 'radius', '(!)radi(線)(!)us(条件法)'], ['premis', '(!)premis(前提)', '(!)prem(押える)(!)is(過去形)'], ['premi', '(!)premi(賞品)', '(!)prem(押える)i'], ['sonat', '(!)sonat(ソナタ)', '(!)son(音がする)(!)at(受動・継続)'], ['bari', 'bari', '(!)bar(障害)i'], ['format', '(!)format(判)', '(!)form(形)(!)at(受動・継続)'], ['markot', '(!)markot(取木)', '(!)mark(しるし)(!)ot(受動・将然)'], ['tempi', '(!)tempi(こめかみ)', '(!)temp(時間)i'], ['noktu', '(!)noktu(コフクロウ)', '(!)nokt(夜)u'], ['vakcini', 'vakcini', '(!)vakcin(ワクチン)i'], ['nomad', '(!)nomad(遊牧民)', '(!)nom(名前)(!)ad(行為)'], ['kantat', '(!)kantat(カンタータ)', '(!)kant(歌う)(!)at(受動・継続)'], ['procesi', '(!)procesi(行列)', '(!)proces(訴訟)i'], ['statu', '(!)statu(立像)', '(!)stat(状態)u'], ['kolorad', 'kolorad', '(!)kolor(色)(!)ad(行為)'], ['devi', 'devi', '(!)dev(しなければならない)i'], ['diplomat', '(!)diplomat(外交官)', '(!)diplom(免状)(!)at(受動・継続)'], ['diskont', '(!)diskont(手形割引する)', '(!)disk(円盤)(!)ont(能動・将然)'], ['endos', 'endos', '(!)end(必要)(!)os(未来形)'], ['esperant', '(!)esperant(エスペラント)', '(!)esper(希望する)(!)ant(能動・継続)'], ['feri', '(!)feri(休日)', '(!)fer(鉄)i'], ['fleksi', '(!)fleksi(語尾変化)', '(!)fleks(曲げる)i'], ['forkant', '(!)for(離れて)(!)kant(歌う)', '(!)fork(フォーク)(!)ant(能動・継続)'], ['pensi', '(!)pensi(年金)', '(!)pens(思う)i'], ['gravit', 'gravit', '(!)grav(重要な)(!)it(受動・完了)'], ['konus', '(!)konus(円錐)', '(!)kon(知っている)(!)us(条件法)'], ['jesu', '(!)jesu(イエス)', '(!)jes(はい)u'], ['jxaluzi', 'jxaluzi', '(!)jxaluz(嫉妬深い)i'], ['konfesi', 'konfesi', '(!)konfes(告白する)i'], ['salat', '(!)salat(サラダ)', '(!)sal(塩)(!)at(受動・継続)'], ['konsili', 'konsili', '(!)konsil(助言する)i'], ['legat', '(!)legat(教皇特使)', '(!)leg(読む)(!)at(受動・継続)'], ['legi', '(!)legi(軍団)', '(!)leg(読む)i'], ['lekant', '(!)lekant(マーガレット)', '(!)lek(なめる)(!)ant(能動・継続)'], ['licenci', 'licenci', '(!)licenc(認可)i'], ['logxi', '(!)logxi(桟敷)', '(!)logx(住む)i'], ['lotus', '(!)lotus(ハス)', '(!)lot(くじ)(!)us(条件法)'], ['malvolont', '(!)mal(正反対)(!)volont(自ら進んで)', '(!)mal(正反対)(!)vol(意志がある)(!)ont(能動・将然)'], ['mankis', '(!)man(手)(!)kis(キスする)', '(!)mank(欠けている)(!)is(過去形)'], ['meti', '(!)meti(手仕事)', '(!)met(置く)i'], ['minus', '(!)minus(マイナス)', '(!)min(鉱山)(!)us(条件法)'], ['pasi', '(!)pasi(情熱)', '(!)pas(通過する)i'], ['patos', '(!)patos(パトス)', '(!)pat(フライパン)(!)os(未来形)'], ['revu', '(!)revu(専門雑誌)', '(!)rev(空想する)u'], ['predikat', '(!)predikat(述部)', '(!)predik(説教する)(!)at(受動・継続)'], ['rabat', '(!)rabat(割引)', '(!)rab(強奪する)(!)at(受動・継続)'], ['rabot', '(!)rabot(かんなをかける)', '(!)rab(強奪する)(!)ot(受動・将然)'], ['rabi', '(!)rabi(狂犬病)', '(!)rab(強奪する)i'], ['religi', '(!)religi(宗教)', '(!)re(再び)(!)lig(結ぶ)i'], ['remont', 'remont', '(!)rem(漕ぐ)(!)ont(能動・将然)'], ['sagu', '(!)sagu(サゴ粉)', '(!)sag(矢)u'], ['satirus', 'satirus', '(!)satir(諷刺)(!)us(条件法)'], ['sekci', '(!)sekci(部)', '(!)sekc(切断する)i'], ['sendat', '(!)sen(なしで)(!)dat(日付)', '(!)send(送る)(!)at(受動・継続)'], ['sendot', '(!)sen(なしで)(!)dot(持参金)', '(!)send(送る)(!)ot(受動・将然)'], ['sendi', '(!)sen(なしで)(!)di(神)', '(!)send(送る)i'], ['spirit', '(!)spirit(精神)', '(!)spir(呼吸する)(!)it(受動・完了)'], ['spirant', 'spirant', '(!)spir(呼吸する)(!)ant(能動・継続)'], ['taksus', '(!)taksus(イチイ)', '(!)taks(評価する)(!)us(条件法)'], ['tenis', 'tenis', '(!)ten(支え持つ)(!)is(過去形)'], ['teni', '(!)teni(サナダムシ)', '(!)ten(支え持つ)i'], ['traktat', '(!)traktat(条約)', '(!)trakt(取り扱う)(!)at(受動・継続)'], ['trikot', '(!)trikot(トリコット)', '(!)trik(編み物をする)(!)ot(受動・将然)'], ['trilit', '(!)tri(三)(!)lit(ベッド)', '(!)tril(トリル)(!)it(受動・完了)'], ['vaku', 'vaku', '(!)vak(あいている)u'], ['vizit', '(!)vizit(訪問する)', '(!)viz(ビザ)(!)it(受動・完了)'], ['vizi', '(!)vizi(幻影)', '(!)viz(ビザ)i'], ['volont', '(!)volont(自ら進んで)', '(!)vol(意志がある)(!)ont(能動・将然)']]
# 9 [['arogant', '(!)arogant(横柄な)', 'arog(!)ant(能動・継続)'], ['brokant', '(!)brokant(古物売買する)', 'brok(!)ant(能動・継続)'], ['ferlad', '(!)fer(鉄)(!)lad(ブリキ板)', 'ferl(!)ad(行為)'], ['harpi', '(!)harpi(ハルピュイア)', 'harpi'], ['ordinat', 'ordinat', 'ordin(!)at(受動・継続)'], ['patrici', '(!)patrici(貴族)', 'patrici'], ['revizit', '(!)re(再び)(!)vizit(訪問する)', 'reviz(!)it(受動・完了)'], ['revizi', '(!)revizi(校閲する)', 'revizi'], ['sugesti', '(!)sugesti(暗示)', 'sugesti']]
# 0 []
# 2601 2605 72 6982 1007 7
# 25 1967 520

# %%
bunseki2=UU+VV+WW+UU_2+VV_2+WW_2+XXX
an=[]
on=[]
en=[]
at=[]
it=[]
sonota=[]
for jj in bunseki2:
    if jj[0].endswith("an"):
        an.append(jj)
    elif jj[0].endswith("on"):
        on.append(jj)
    elif jj[0].endswith("en"):
        en.append(jj)
    elif jj[0].endswith("at"):
        at.append(jj)
    elif jj[0].endswith("it"):
        it.append(jj)
    else:
        sonota.append(jj)
        
    
print(len(an),an)
print(len(on),on)
print(len(en),en)
print(len(at),at)
print(len(it),it)
print(len(sonota),sonota)
# Out:
# 87 [['dietan', '(!)diet(規定食)(!)an(会員)', '(!)diet(規定食)an'], ['afrikan', '(!)afrik(アフリカ)(!)an(会員)', '(!)afrik(アフリカ)an'], ['movadan', '(!)mov(動かす)(!)ad(行為)(!)an(会員)', '(!)mov(動かす)(!)ad(行為)an'], ['akcian', '(!)akci(株式)(!)an(会員)', '(!)akci(株式)an'], ['montaran', '(!)mont(山)(!)ar(集団)(!)an(会員)', '(!)mont(山)(!)ar(集団)an'], ['amerikan', '(!)amerik(アメリカ)(!)an(会員)', '(!)amerik(アメリカ)an'], ['regnan', '(!)regn(国家)(!)an(会員)', '(!)regn(国家)an'], ['dezertan', '(!)dezert(砂漠)(!)an(会員)', '(!)dezert(砂漠)an'], ['asocian', '(!)asoci(協会)(!)an(会員)', '(!)asoci(協会)an'], ['insulan', '(!)insul(島)(!)an(会員)', '(!)insul(島)an'], ['azian', '(!)azi(アジア)(!)an(会員)', '(!)azi(アジア)an'], ['sxtatan', '(!)sxtat(国家)(!)an(会員)', '(!)sxtat(国家)an'], ['doman', '(!)dom(家)(!)an(会員)', '(!)dom(家)an'], ['montan', '(!)mont(山)(!)an(会員)', '(!)mont(山)an'], ['familian', '(!)famili(家族)(!)an(会員)', '(!)famili(家族)an'], ['urban', '(!)urb(市)(!)an(会員)', '(!)urb(市)an'], ['popolan', '(!)popol(人民)(!)an(会員)', '(!)popol(人民)an'], ['dekan', '(!)dekan(学部長)', '(!)dek(十)an'], ['partian', '(!)parti(党派)(!)an(会員)', '(!)parti(党派)an'], ['lokan', '(!)lok(場所)(!)an(会員)', '(!)lok(場所)an'], ['sxipan', '(!)sxip(船)(!)an(会員)', '(!)sxip(船)an'], ['eklezian', '(!)eklezi(教会)(!)an(会員)', '(!)eklezi(教会)an'], ['landan', '(!)land(国)(!)an(会員)', '(!)land(国)an'], ['orientan', '(!)orient(東)(!)an(会員)', '(!)orient(東)an'], ['lernejan', '(!)lern(学習する)(!)ej(場所)(!)an(会員)', '(!)lern(学習する)(!)ej(場所)an'], ['enlandan', '(!)en(中で)(!)land(国)(!)an(会員)', '(!)en(中で)(!)land(国)an'], ['kalkan', '(!)kalkan(踵)', '(!)kalk(石灰)an'], ['estraran', '(!)estr(長)(!)ar(集団)(!)an(会員)', '(!)estr(長)(!)ar(集団)an'], ['etnan', '(!)etn(民族)(!)an(会員)', '(!)etn(民族)an'], ['euxropan', '(!)euxrop(ヨーロッパ)(!)an(会員)', '(!)euxrop(ヨーロッパ)an'], ['fazan', '(!)fazan(キジ)', '(!)faz(位相)an'], ['polican', '(!)polic(警察)(!)an(会員)', '(!)polic(警察)an'], ['socian', '(!)soci(社会)(!)an(会員)', '(!)soci(社会)an'], ['societan', '(!)societ(会)(!)an(会員)', '(!)societ(会)an'], ['grupan', '(!)grup(グループ)(!)an(会員)', '(!)grup(グループ)an'], ['ligan', '(!)lig(結ぶ)(!)an(会員)', '(!)lig(結ぶ)an'], ['nacian', '(!)naci(国民)(!)an(会員)', '(!)naci(国民)an'], ['koran', '(!)koran(コーラン)', '(!)kor(心)an'], ['religian', '(!)religi(宗教)(!)an(会員)', '(!)religi(宗教)an'], ['kuban', '(!)kub(立方体)(!)an(会員)', '(!)kub(立方体)an'], ['majoran', '(!)major(陸軍少佐)(!)an(会員)', '(!)major(陸軍少佐)an'], ['marian', 'marian', '(!)mari(マリア)an'], ['nordan', '(!)nord(北)(!)an(会員)', '(!)nord(北)an'], ['paran', 'paran', '(!)par(一対)an'], ['parizan', '(!)pariz(パリ)(!)an(会員)', '(!)pariz(パリ)an'], ['parokan', '(!)parok(教区)(!)an(会員)', '(!)parok(教区)an'], ['podian', '(!)podi(ひな壇)(!)an(会員)', '(!)podi(ひな壇)an'], ['rusian', '(!)rus(ロシア人)i(!)an(会員)', '(!)rus(ロシア人)ian'], ['satan', '(!)satan(サタン)', '(!)sat(満腹した)an'], ['sektan', '(!)sekt(宗派)(!)an(会員)', '(!)sekt(宗派)an'], ['senatan', '(!)senat(参議院)(!)an(会員)', '(!)senat(参議院)an'], ['skisman', '(!)skism(分裂)(!)an(会員)', '(!)skism(分裂)an'], ['sudan', 'sudan', '(!)sud(南)an'], ['utopian', '(!)utopi(ユートピア)(!)an(会員)', '(!)utopi(ユートピア)an'], ['vilagxan', '(!)vilagx(村)(!)an(会員)', '(!)vilagx(村)an'], ['brazilan', 'brazil(!)an(会員)', 'brazilan'], ['budhan', 'budh(!)an(会員)', 'budhan'], ['egiptan', 'egipt(!)an(会員)', 'egiptan'], ['gvinean', 'gvine(!)an(会員)', 'gvinean'], ['epikuran', 'epikur(!)an(会員)', 'epikuran'], ['ilirian', 'iliri(!)an(会員)', 'ilirian'], ['ionian', 'ioni(!)an(会員)', 'ionian'], ['iranan', 'iran(!)an(会員)', 'iranan'], ['irlandan', 'irland(!)an(会員)', 'irlandan'], ['islaman', 'islam(!)an(会員)', 'islaman'], ['islandan', 'island(!)an(会員)', 'islandan'], ['israelan', 'israel(!)an(会員)', 'israelan'], ['kanadan', 'kanad(!)an(会員)', 'kanadan'], ['roman', '(!)roman(長編小説)', 'roman'], ['laosan', 'laos(!)an(会員)', 'laosan'], ['libian', 'libi(!)an(会員)', 'libian'], ['malavian', 'malavi(!)an(会員)', 'malavian'], ['meksikan', 'meksik(!)an(会員)', 'meksikan'], ['nepalan', 'nepal(!)an(会員)', 'nepalan'], ['romian', 'romi(!)an(会員)', 'romian'], ['sirian', 'siri(!)an(会員)', 'sirian'], ['somalian', 'somali(!)an(会員)', 'somalian'], ['sovetan', 'sovet(!)an(会員)', 'sovetan'], ['sovetian', 'sov ...
# 73 [['duon', '(!)du(二)(!)on(分数)', '(!)du(二)on'], ['okon', '(!)ok(八)(!)on(分数)', '(!)ok(八)on'], ['nombron', '(!)nombr(数)(!)on(分数)', '(!)nombr(数)on'], ['patron', '(!)patron(後援者)', '(!)patr(父)on'], ['karbon', '(!)karbon(炭素)', '(!)karb(炭)on'], ['ciklon', '(!)ciklon(低気圧)', '(!)cikl(周期)on'], ['aldon', '(!)al(～の方へ)(!)don(与える)', '(!)ald(アルト)on'], ['balon', '(!)balon(気球)', '(!)bal(舞踏会)on'], ['baron', '(!)baron(男爵)', '(!)bar(障害)on'], ['baston', '(!)baston(棒)', '(!)bast(じん皮)on'], ['magneton', 'magneton', '(!)magnet(磁石)on'], ['beton', 'beton', '(!)bet(ビート)on'], ['bombon', '(!)bombon(キャンデー)', '(!)bomb(爆弾)on'], ['breton', 'breton', '(!)bret(棚)on'], ['burgxon', '(!)burgxon(芽)', '(!)burgx(ブルジョワ)on'], ['centon', '(!)cent(百)(!)on(分数)', '(!)cent(百)on'], ['milon', '(!)mil(千)(!)on(分数)', '(!)mil(千)on'], ['kanton', '(!)kanton(郡)', '(!)kant(歌う)on'], ['citron', '(!)citron(シトロン)', '(!)citr(チター)on'], ['papilion', 'papilion', '(!)papili(チョウ)on'], ['platon', 'platon', '(!)plat(平たい)on'], ['dekon', '(!)dek(十)(!)on(分数)', '(!)dek(十)on'], ['kvaron', '(!)kvar(四)(!)on(分数)', '(!)kvar(四)on'], ['kvinon', '(!)kvin(五)(!)on(分数)', '(!)kvin(五)on'], ['seson', '(!)ses(六)(!)on(分数)', '(!)ses(六)on'], ['trion', '(!)tri(三)(!)on(分数)', '(!)tri(三)on'], ['karton', '(!)karton(厚紙)', '(!)kart(カード)on'], ['foton', '(!)fot(写真、写真をとる)(!)on(分数)', '(!)fot(写真、写真をとる)on'], ['peron', '(!)peron(階段)', '(!)per(よって)on'], ['elektron', 'elektron', '(!)elektr(電気)on'], ['drakon', 'drakon', '(!)drak(竜)on'], ['mondon', '(!)mon(金銭)(!)don(与える)', '(!)mond(世界)on'], ['pension', '(!)pension(下宿屋)', '(!)pensi(年金)on'], ['ordon', '(!)ordon(命令する)', '(!)ord(順序)on'], ['eskadron', 'eskadron', '(!)eskadr(艦隊)on'], ['senton', '(!)sen(なしで)(!)ton(楽音)', '(!)sent(感じる)on'], ['eston', 'eston', '(!)est(である)on'], ['fanfaron', '(!)fanfaron(大言壮語する)', '(!)fanfar(ファンファーレ)on'], ['feston', '(!)feston(花綱)', '(!)fest(祝う)on'], ['flegmon', 'flegmon', '(!)flegm(冷静)on'], ['fronton', '(!)fronton(ペディメント)', '(!)front(正面)on'], ['galon', '(!)galon(モール)', '(!)gal(胆汁)on'], ['ganglion', 'ganglion', '(!)gangli(神経節)on'], ['mason', '(!)mason(築く)', '(!)mas(かたまり)on'], ['helikon', 'helikon', '(!)helik(カタツムリ)on'], ['kanon', '(!)kanon(大砲)', '(!)kan(アシ)on'], ['kapon', '(!)kapon(去勢オンドリ)', '(!)kap(頭)on'], ['kokon', '(!)kokon(繭)', '(!)kok(ニワトリ)on'], ['kolon', '(!)kolon(円柱)', '(!)kol(首)on'], ['komision', '(!)komision(委員会)', '(!)komisi(委託する)on'], ['salon', '(!)salon(サロン)', '(!)sal(塩)on'], ['ponton', '(!)ponton(平底舟)', '(!)pont(橋)on'], ['koton', '(!)koton(綿)', '(!)kot(泥)on'], ['kripton', 'kripton', '(!)kript(地下聖堂)on'], ['kupon', '(!)kupon(クーポン券)', '(!)kup(吸い玉)on'], ['lakon', 'lakon', '(!)lak(ラッカー)on'], ['ludon', '(!)lu(賃借する)(!)don(与える)', '(!)lud(遊ぶ)on'], ['melon', '(!)melon(メロン)', '(!)mel(アナグマ)on'], ['menton', '(!)menton(下あご)', '(!)ment(ハッカ)on'], ['milion', '(!)milion(百万)', '(!)mili(キビ)on'], ['milionon', '(!)milion(百万)(!)on(分数)', '(!)milion(百万)on'], ['nauxon', '(!)naux(九)(!)on(分数)', '(!)naux(九)on'], ['violon', '(!)violon(バイオリン)', '(!)viol(スミレ)on'], ['trombon', '(!)trombon(トロンボーン)', '(!)tromb(たつまき)on'], ['senson', '(!)sen(なしで)(!)son(音がする)', '(!)sens(感覚)on'], ['sepon', '(!)sep(七)(!)on(分数)', '(!)sep(七)on'], ['skadron', 'skadron', '(!)skadr(騎兵中隊)on'], ['stadion', '(!)stadion(スタジアム)', '(!)stadi(段階)on'], ['tetraon', 'tetraon', '(!)tetra(エゾライチョウ)on'], ['timon', '(!)timon(かじ棒)', '(!)tim(恐れる)on'], ['valon', 'valon', '(!)val(谷)on'], ['dragon', '(!)dragon(竜騎兵)', 'dragon'], ['person', '(!)person(人)', 'person']]
# 12 [['forten', '(!)for(離れて)(!)ten(支え持つ)', '(!)fort(強い)en'], ['aparten', '(!)aparten(所属する)', '(!)apart(別々の)en'], ['domen', '(!)domen(ドミノ)', '(!)dom(家)en'], ['platen', '(!)platen(白金)', '(!)plat(平たい)en'], ['reten', '(!)re(再び)(!)ten(支え持つ)', '(!)ret(網)en'], ['posten', '(!)posten(部署)', '(!)post(後で)en'], ['orden', '(!)orden(勲章)', '(!)ord(順序)en'], ['teren', '(!)teren(地所)', '(!)ter(土地)en'], ['helen', 'helen', '(!)hel(明るい)en'], ['karen', 'karen', '(!)kar(親愛な)en'], ['saten', '(!)saten(サテン)', '(!)sat(満腹した)en'], ['solen', '(!)solen(荘厳な)', '(!)sol(唯一の)en']]
# 12 [['agat', '(!)agat(メノウ)', '(!)ag(行動する)(!)at(受動・継続)'], ['sonat', '(!)sonat(ソナタ)', '(!)son(音がする)(!)at(受動・継続)'], ['format', '(!)format(判)', '(!)form(形)(!)at(受動・継続)'], ['kantat', '(!)kantat(カンタータ)', '(!)kant(歌う)(!)at(受動・継続)'], ['diplomat', '(!)diplomat(外交官)', '(!)diplom(免状)(!)at(受動・継続)'], ['salat', '(!)salat(サラダ)', '(!)sal(塩)(!)at(受動・継続)'], ['legat', '(!)legat(教皇特使)', '(!)leg(読む)(!)at(受動・継続)'], ['predikat', '(!)predikat(述部)', '(!)predik(説教する)(!)at(受動・継続)'], ['rabat', '(!)rabat(割引)', '(!)rab(強奪する)(!)at(受動・継続)'], ['sendat', '(!)sen(なしで)(!)dat(日付)', '(!)send(送る)(!)at(受動・継続)'], ['traktat', '(!)traktat(条約)', '(!)trakt(取り扱う)(!)at(受動・継続)'], ['ordinat', 'ordinat', 'ordin(!)at(受動・継続)']]
# 7 [['agit', '(!)agit(扇動する)', '(!)ag(行動する)(!)it(受動・完了)'], ['irit', 'irit', '(!)ir(行く)(!)it(受動・完了)'], ['gravit', 'gravit', '(!)grav(重要な)(!)it(受動・完了)'], ['spirit', '(!)spirit(精神)', '(!)spir(呼吸する)(!)it(受動・完了)'], ['trilit', '(!)tri(三)(!)lit(ベッド)', '(!)tril(トリル)(!)it(受動・完了)'], ['vizit', '(!)vizit(訪問する)', '(!)viz(ビザ)(!)it(受動・完了)'], ['revizit', '(!)re(再び)(!)vizit(訪問する)', 'reviz(!)it(受動・完了)']]
# 83 [['alo', '(!)alo(アロエ)', '(!)al(～の方へ)o'], ['alte', '(!)alte(タチアオイ)', '(!)alt(高い)e'], ['apoge', '(!)apoge(遠地点)', '(!)apog(支える)e'], ['kaze', '(!)kaze(凝乳)', '(!)kaz(格)e'], ['inka', 'inka', '(!)ink(インク)a'], ['pere', '(!)pere(破滅する)', '(!)per(よって)e'], ['fero', 'fero', '(!)fer(鉄)o'], ['havaj', 'havaj', '(!)hav(持っている)aj'], ['kore', 'kore', '(!)kor(心)e'], ['lama', '(!)lama(ラマ僧)', '(!)lam(びっこの)a'], ['malaj', 'malaj', '(!)mal(正反対)aj'], ['male', 'male', '(!)mal(正反対)e'], ['refoj', '(!)re(再び)(!)foj(回)', '(!)ref(リーフ)oj'], ['samo', 'samo', '(!)sam(同一の)o'], ['savoj', 'savoj', '(!)sav(救助する)oj'], ['sole', '(!)sole(シタビラメ)', '(!)sol(唯一の)e'], ['veto', 'veto', '(!)vet(賭ける)o'], ['amas', '(!)amas(集積)', '(!)am(愛する)(!)as(現在形)'], ['iris', '(!)iris(虹彩)', '(!)ir(行く)(!)is(過去形)'], ['regulus', 'regulus', '(!)regul(規則)(!)us(条件法)'], ['agxi', '(!)agxi(打ち歩)', '(!)agx(年齢)i'], ['akirant', 'akirant', '(!)akir(獲得する)(!)ant(能動・継続)'], ['radius', 'radius', '(!)radi(線)(!)us(条件法)'], ['premis', '(!)premis(前提)', '(!)prem(押える)(!)is(過去形)'], ['premi', '(!)premi(賞品)', '(!)prem(押える)i'], ['bari', 'bari', '(!)bar(障害)i'], ['markot', '(!)markot(取木)', '(!)mark(しるし)(!)ot(受動・将然)'], ['tempi', '(!)tempi(こめかみ)', '(!)temp(時間)i'], ['noktu', '(!)noktu(コフクロウ)', '(!)nokt(夜)u'], ['vakcini', 'vakcini', '(!)vakcin(ワクチン)i'], ['nomad', '(!)nomad(遊牧民)', '(!)nom(名前)(!)ad(行為)'], ['procesi', '(!)procesi(行列)', '(!)proces(訴訟)i'], ['statu', '(!)statu(立像)', '(!)stat(状態)u'], ['kolorad', 'kolorad', '(!)kolor(色)(!)ad(行為)'], ['devi', 'devi', '(!)dev(しなければならない)i'], ['diskont', '(!)diskont(手形割引する)', '(!)disk(円盤)(!)ont(能動・将然)'], ['endos', 'endos', '(!)end(必要)(!)os(未来形)'], ['esperant', '(!)esperant(エスペラント)', '(!)esper(希望する)(!)ant(能動・継続)'], ['feri', '(!)feri(休日)', '(!)fer(鉄)i'], ['fleksi', '(!)fleksi(語尾変化)', '(!)fleks(曲げる)i'], ['forkant', '(!)for(離れて)(!)kant(歌う)', '(!)fork(フォーク)(!)ant(能動・継続)'], ['pensi', '(!)pensi(年金)', '(!)pens(思う)i'], ['konus', '(!)konus(円錐)', '(!)kon(知っている)(!)us(条件法)'], ['jesu', '(!)jesu(イエス)', '(!)jes(はい)u'], ['jxaluzi', 'jxaluzi', '(!)jxaluz(嫉妬深い)i'], ['konfesi', 'konfesi', '(!)konfes(告白する)i'], ['konsili', 'konsili', '(!)konsil(助言する)i'], ['legi', '(!)legi(軍団)', '(!)leg(読む)i'], ['lekant', '(!)lekant(マーガレット)', '(!)lek(なめる)(!)ant(能動・継続)'], ['licenci', 'licenci', '(!)licenc(認可)i'], ['logxi', '(!)logxi(桟敷)', '(!)logx(住む)i'], ['lotus', '(!)lotus(ハス)', '(!)lot(くじ)(!)us(条件法)'], ['malvolont', '(!)mal(正反対)(!)volont(自ら進んで)', '(!)mal(正反対)(!)vol(意志がある)(!)ont(能動・将然)'], ['mankis', '(!)man(手)(!)kis(キスする)', '(!)mank(欠けている)(!)is(過去形)'], ['meti', '(!)meti(手仕事)', '(!)met(置く)i'], ['minus', '(!)minus(マイナス)', '(!)min(鉱山)(!)us(条件法)'], ['pasi', '(!)pasi(情熱)', '(!)pas(通過する)i'], ['patos', '(!)patos(パトス)', '(!)pat(フライパン)(!)os(未来形)'], ['revu', '(!)revu(専門雑誌)', '(!)rev(空想する)u'], ['rabot', '(!)rabot(かんなをかける)', '(!)rab(強奪する)(!)ot(受動・将然)'], ['rabi', '(!)rabi(狂犬病)', '(!)rab(強奪する)i'], ['religi', '(!)religi(宗教)', '(!)re(再び)(!)lig(結ぶ)i'], ['remont', 'remont', '(!)rem(漕ぐ)(!)ont(能動・将然)'], ['sagu', '(!)sagu(サゴ粉)', '(!)sag(矢)u'], ['satirus', 'satirus', '(!)satir(諷刺)(!)us(条件法)'], ['sekci', '(!)sekci(部)', '(!)sekc(切断する)i'], ['sendot', '(!)sen(なしで)(!)dot(持参金)', '(!)send(送る)(!)ot(受動・将然)'], ['sendi', '(!)sen(なしで)(!)di(神)', '(!)send(送る)i'], ['spirant', 'spirant', '(!)spir(呼吸する)(!)ant(能動・継続)'], ['taksus', '(!)taksus(イチイ)', '(!)taks(評価する)(!)us(条件法)'], ['tenis', 'tenis', '(!)ten(支え持つ)(!)is(過去形)'], ['teni', '(!)teni(サナダムシ)', '(!)ten(支え持つ)i'], ['trikot', '(!)trikot(トリコット)', '(!)trik(編み物をする)(!)ot(受動・将然)'], ['vaku', 'vaku', '(!)vak(あいている)u'], ['vizi', '(!)vizi(幻影)', '(!)viz(ビザ)i'], ['volont', '(!)volont(自ら進んで)', '(!)vol(意志がある)(!)ont(能動・将然)'], ['arogant', '(!)arogant(横柄な)', 'arog(!)ant(能動・継続)'], ['brokant', '(!)brokant(古物売買する)', 'brok(!)ant(能動・継続)'], ['ferlad', '(!)fer(鉄)(!)lad(ブリキ板)', 'ferl(!)ad(行為)'], ['harpi', '(!)harpi(ハルピュイア)', 'harpi'], ['patrici', '(!)patrici(貴族)', 'patrici'], ['revizi', '(!)revizi(校閲する)', 'revizi'], ['sugesti', '(!)sugesti(暗示)', 'sugesti']]

# %%
# 一番目の要素をセットに変換
set1 = {i[0] for i in bunseki}
set2 = {i[0] for i in bunseki2}

# 違いを見つける
differences = set1.symmetric_difference(set2)

# 結果を出力
print("Differences between bunseki and bunseki2 in the first elements of their lists:")
for diff in differences:
    print(diff)
# Out:
# Differences between bunseki and bunseki2 in the first elements of their lists:
# alo
# okon

# %%
import re
# 入力データ
data=[['dietan', '(!)diet(規定食)(!)an(会員)', '(!)diet(規定食)an'], ['afrikan', '(!)afrik(アフリカ)(!)an(会員)', '(!)afrik(アフリカ)an'], ['movadan', '(!)mov(動かす)(!)ad(行為)(!)an(会員)', '(!)mov(動かす)(!)ad(行為)an'], ['akcian', '(!)akci(株式)(!)an(会員)', '(!)akci(株式)an'], ['montaran', '(!)mont(山)(!)ar(集団)(!)an(会員)', '(!)mont(山)(!)ar(集団)an'], ['amerikan', '(!)amerik(アメリカ)(!)an(会員)', '(!)amerik(アメリカ)an'], ['regnan', '(!)regn(国家)(!)an(会員)', '(!)regn(国家)an'], ['dezertan', '(!)dezert(砂漠)(!)an(会員)', '(!)dezert(砂漠)an'], ['asocian', '(!)asoci(協会)(!)an(会員)', '(!)asoci(協会)an'], ['insulan', '(!)insul(島)(!)an(会員)', '(!)insul(島)an'], ['azian', '(!)azi(アジア)(!)an(会員)', '(!)azi(アジア)an'], ['sxtatan', '(!)sxtat(国家)(!)an(会員)', '(!)sxtat(国家)an'], ['doman', '(!)dom(家)(!)an(会員)', '(!)dom(家)an'], ['montan', '(!)mont(山)(!)an(会員)', '(!)mont(山)an'], ['familian', '(!)famili(家族)(!)an(会員)', '(!)famili(家族)an'], ['urban', '(!)urb(市)(!)an(会員)', '(!)urb(市)an'], ['popolan', '(!)popol(人民)(!)an(会員)', '(!)popol(人民)an'], ['dekan', '(!)dekan(学部長)', '(!)dek(十)an'], ['partian', '(!)parti(党派)(!)an(会員)', '(!)parti(党派)an'], ['lokan', '(!)lok(場所)(!)an(会員)', '(!)lok(場所)an'], ['sxipan', '(!)sxip(船)(!)an(会員)', '(!)sxip(船)an'], ['eklezian', '(!)eklezi(教会)(!)an(会員)', '(!)eklezi(教会)an'], ['landan', '(!)land(国)(!)an(会員)', '(!)land(国)an'], ['orientan', '(!)orient(東)(!)an(会員)', '(!)orient(東)an'], ['lernejan', '(!)lern(学習する)(!)ej(場所)(!)an(会員)', '(!)lern(学習する)(!)ej(場所)an'], ['enlandan', '(!)en(中で)(!)land(国)(!)an(会員)', '(!)en(中で)(!)land(国)an'], ['kalkan', '(!)kalkan(踵)', '(!)kalk(石灰)an'], ['estraran', '(!)estr(長)(!)ar(集団)(!)an(会員)', '(!)estr(長)(!)ar(集団)an'], ['etnan', '(!)etn(民族)(!)an(会員)', '(!)etn(民族)an'], ['euxropan', '(!)euxrop(ヨーロッパ)(!)an(会員)', '(!)euxrop(ヨーロッパ)an'], ['fazan', '(!)fazan(キジ)', '(!)faz(位相)an'], ['polican', '(!)polic(警察)(!)an(会員)', '(!)polic(警察)an'], ['socian', '(!)soci(社会)(!)an(会員)', '(!)soci(社会)an'], ['societan', '(!)societ(会)(!)an(会員)', '(!)societ(会)an'], ['grupan', '(!)grup(グループ)(!)an(会員)', '(!)grup(グループ)an'], ['ligan', '(!)lig(結ぶ)(!)an(会員)', '(!)lig(結ぶ)an'], ['nacian', '(!)naci(国民)(!)an(会員)', '(!)naci(国民)an'], ['koran', '(!)koran(コーラン)', '(!)kor(心)an'], ['religian', '(!)religi(宗教)(!)an(会員)', '(!)religi(宗教)an'], ['kuban', '(!)kub(立方体)(!)an(会員)', '(!)kub(立方体)an'], ['majoran', '(!)major(陸軍少佐)(!)an(会員)', '(!)major(陸軍少佐)an'], ['marian', 'marian', '(!)mari(マリア)an'], ['nordan', '(!)nord(北)(!)an(会員)', '(!)nord(北)an'], ['paran', 'paran', '(!)par(一対)an'], ['parizan', '(!)pariz(パリ)(!)an(会員)', '(!)pariz(パリ)an'], ['parokan', '(!)parok(教区)(!)an(会員)', '(!)parok(教区)an'], ['podian', '(!)podi(ひな壇)(!)an(会員)', '(!)podi(ひな壇)an'], ['rusian', '(!)rus(ロシア人)i(!)an(会員)', '(!)rus(ロシア人)ian'], ['satan', '(!)satan(サタン)', '(!)sat(満腹した)an'], ['sektan', '(!)sekt(宗派)(!)an(会員)', '(!)sekt(宗派)an'], ['senatan', '(!)senat(参議院)(!)an(会員)', '(!)senat(参議院)an'], ['skisman', '(!)skism(分裂)(!)an(会員)', '(!)skism(分裂)an'], ['sudan', 'sudan', '(!)sud(南)an'], ['utopian', '(!)utopi(ユートピア)(!)an(会員)', '(!)utopi(ユートピア)an'], ['vilagxan', '(!)vilagx(村)(!)an(会員)', '(!)vilagx(村)an'], ['brazilan', 'brazil(!)an(会員)', 'brazilan'], ['budhan', 'budh(!)an(会員)', 'budhan'], ['egiptan', 'egipt(!)an(会員)', 'egiptan'], ['gvinean', 'gvine(!)an(会員)', 'gvinean'], ['epikuran', 'epikur(!)an(会員)', 'epikuran'], ['ilirian', 'iliri(!)an(会員)', 'ilirian'], ['ionian', 'ioni(!)an(会員)', 'ionian'], ['iranan', 'iran(!)an(会員)', 'iranan'], ['irlandan', 'irland(!)an(会員)', 'irlandan'], ['islaman', 'islam(!)an(会員)', 'islaman'], ['islandan', 'island(!)an(会員)', 'islandan'], ['israelan', 'israel(!)an(会員)', 'israelan'], ['kanadan', 'kanad(!)an(会員)', 'kanadan'], ['roman', '(!)roman(長編小説)', 'roman'], ['laosan', 'laos(!)an(会員)', 'laosan'], ['libian', 'libi(!)an(会員)', 'libian'], ['malavian', 'malavi(!)an(会員)', 'malavian'], ['meksikan', 'meksik(!)an(会員)', 'meksikan'], ['nepalan', 'nepal(!)an(会員)', 'nepalan'], ['romian', 'romi(!)an(会員)', 'romian'], ['sirian', 'siri(!)an(会員)', 'sirian'], ['somalian', 'somali(!)an(会員)', 'somalian'], ['sovetan', 'sovet(!)an(会員)', 'sovetan'], ['sovetian', 'soveti(!)an(会員)', 'sovetian'], ['sudanan', 'sudan(!)an(会員)', 'sudanan'], ['tibetan', 'tibet(!)an(会員)', 'tibetan'], ['togolan', 'togol(!)an(会員)', 'togolan'], ['tokian', 'toki(!)an(会員)', 'tokian'], ['tongan', 'tong(!)an(会員)', 'tongan'], ['triban', 'trib(!)an(会員)', 'triban'], ['trojan', 'troj(!)an(会員)', 'trojan'], ['usonan', 'uson(!)an(会員)', 'usonan']]
# 変換のための関数を定義
def replace_pattern(input_list):
    # 変換後のリストを保存するための新しいリスト
    new_list = []
    # 各要素について
    for sublist in input_list:
        # サブリスト内の各文字列を変換
        new_sublist = [re.sub(r'\(.*?\)', '/', item) for item in sublist]
        new_list.append(new_sublist)
    return new_list

# 変換を実行
converted_data = replace_pattern(data)
# converted_data
# # 結果を表示
# for item in converted_data:
#     print(item)
replace_pattern(an)
# Out:
# [['dietan', '/diet//an/', '/diet/an'],
#  ['afrikan', '/afrik//an/', '/afrik/an'],
#  ['movadan', '/mov//ad//an/', '/mov//ad/an'],
#  ['akcian', '/akci//an/', '/akci/an'],
#  ['montaran', '/mont//ar//an/', '/mont//ar/an'],
#  ['amerikan', '/amerik//an/', '/amerik/an'],
#  ['regnan', '/regn//an/', '/regn/an'],
#  ['dezertan', '/dezert//an/', '/dezert/an'],
#  ['asocian', '/asoci//an/', '/asoci/an'],
#  ['insulan', '/insul//an/', '/insul/an'],
#  ['azian', '/azi//an/', '/azi/an'],
#  ['sxtatan', '/sxtat//an/', '/sxtat/an'],
#  ['doman', '/dom//an/', '/dom/an'],
#  ['montan', '/mont//an/', '/mont/an'],
#  ['familian', '/famili//an/', '/famili/an'],
#  ['urban', '/urb//an/', '/urb/an'],
#  ['popolan', '/popol//an/', '/popol/an'],
#  ['dekan', '/dekan/', '/dek/an'],
#  ['partian', '/parti//an/', '/parti/an'],
#  ['lokan', '/lok//an/', '/lok/an'],
#  ['sxipan', '/sxip//an/', '/sxip/an'],
#  ['eklezian', '/eklezi//an/', '/eklezi/an'],
#  ['landan', '/land//an/', '/land/an'],
#  ['orientan', '/orient//an/', '/orient/an'],
#  ['lernejan', '/lern//ej//an/', '/lern//ej/an'],
#  ['enlandan', '/en//land//an/', '/en//land/an'],
#  ['kalkan', '/kalkan/', '/kalk/an'],
#  ['estraran', '/estr//ar//an/', '/estr//ar/an'],
#  ['etnan', '/etn//an/', '/etn/an'],
#  ['euxropan', '/euxrop//an/', '/euxrop/an'],
#  ['fazan', '/fazan/', '/faz/an'],
#  ['polican', '/polic//an/', '/polic/an'],
#  ['socian', '/soci//an/', '/soci/an'],
#  ['societan', '/societ//an/', '/societ/an'],
#  ['grupan', '/grup//an/', '/grup/an'],
#  ['ligan', '/lig//an/', '/lig/an'],
#  ['nacian', '/naci//an/', '/naci/an'],
#  ['koran', '/koran/', '/kor/an'],
#  ['religian', '/religi//an/', '/religi/an'],
#  ['kuban', '/kub//an/', '/kub/an'],
#  ['majoran', '/major//an/', '/major/an'],
#  ['marian', 'marian', '/mari/an'],
#  ['nordan', '/nord//an/', '/nord/an'],
#  ['paran', 'paran', '/par/an'],
#  ['parizan', '/pariz//an/', '/pariz/an'],
#  ['parokan', '/parok//an/', '/parok/an'],
#  ['podian', '/podi//an/', '/podi/an'],
#  ['rusian', '/rus/i/an/', '/rus/ian'],
#  ['satan', '/satan/', '/sat/an'],
#  ['sektan', '/sekt//an/', '/sekt/an'],
#  ['senatan', '/senat//an/', '/senat/an'],
#  ['skisman', '/skism//an/', '/skism/an'],
#  ['sudan', 'sudan', '/sud/an'],
#  ['utopian', '/utopi//an/', '/utopi/an'],
#  ['vilagxan', '/vilagx//an/', '/vilagx/an'],
#  ['brazilan', 'brazil/an/', 'brazilan'],
#  ['budhan', 'budh/an/', 'budhan'],
#  ['egiptan', 'egipt/an/', 'egiptan'],
#  ['gvinean', 'gvine/an/', 'gvinean'],
#  ['epikuran', 'epikur/an/', 'epikuran'],
#  ['ilirian', 'iliri/an/', 'ilirian'],
#  ['ionian', 'ioni/an/', 'ionian'],
#  ['iranan', 'iran/an/', 'iranan'],
#  ['irlandan', 'irland/an/', 'irlandan'],
#  ['islaman', 'islam/an/', 'islaman'],
#  ['islandan', 'island/an/', 'islandan'],
#  ['israelan', 'israel/an/', 'israelan'],
#  ['kanadan', 'kanad/an/', 'kanadan'],
#  ['roman', '/roman/', 'roman'],
#  ['laosan', 'laos/an/', 'laosan'],
#  ['libian', 'libi/an/', 'libian'],
#  ['malavian', 'malavi/an/', 'malavian'],
#  ['meksikan', 'meksik/an/', 'meksikan'],
#  ['nepalan', 'nepal/an/', 'nepalan'],
#  ['romian', 'romi/an/', 'romian'],
#  ['sirian', 'siri/an/', 'sirian'],
#  ['somalian', 'somali/an/', 'somalian'],
#  ['sovetan', 'sovet/an/', 'sovetan'],
#  ['sovetian', 'soveti/an/', 'sovetian'],
#  ['sudanan', 'sudan/an/', 'sudanan'],
#  ['tibetan', 'tibet/an/', 'tibetan'],
#  ['togolan', 'togol/an/', 'togolan'],
#  ['tokian', 'toki/an/', 'tokian'],
#  ['tongan', 'tong/an/', 'tongan'],
#  ['triban', 'trib/an/', 'triban'],
#  ['trojan', 'troj/an/', 'trojan'],
#  ['usonan', 'uson/an/', 'usonan']]

# %%
RR["dekano"]
# Out:
# ['dekan(学部長)o', 57000]

# %%
##an系
ANAN={}
AN=replace_pattern(an)
for an1 in AN:
    i2=an1[1]
    ANAN[i2.replace('/', '')]=[safe_replace(i2,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i2)-1)*10000+3000]
    i3 = re.sub(r"/an/$", "", i2)##正規表現を使わないと、etn/a/n　において、etnのnまで削られてしまった。
    i4=i3+"/an/o"
    i5=i3+"/an/a"
    i6=i3+"/an/e"
    ANAN[i4.replace('/', '')]=[safe_replace(i4,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i4)-1)*10000+3000]
    ANAN[i5.replace('/', '')]=[safe_replace(i5,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i5)-1)*10000+3000]
    ANAN[i6.replace('/', '')]=[safe_replace(i6,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i6)-1)*10000+3000]
    print(i2)
ANAN
# Out:
# /diet//an/
# /afrik//an/
# /mov//ad//an/
# /akci//an/
# /mont//ar//an/
# /amerik//an/
# /regn//an/
# /dezert//an/
# /asoci//an/
# /insul//an/
# /azi//an/
# /sxtat//an/
# /dom//an/
# /mont//an/
# /famili//an/
# /urb//an/
# /popol//an/
# /dekan/
# /parti//an/
# /lok//an/
# /sxip//an/
# /eklezi//an/
# /land//an/
# /orient//an/
# /lern//ej//an/
# /en//land//an/
# /kalkan/
# /estr//ar//an/
# /etn//an/
# /euxrop//an/
# /fazan/
# /polic//an/
# /soci//an/
# /societ//an/
# /grup//an/
# /lig//an/
# /naci//an/
# /koran/
# /religi//an/
# /kub//an/
# /major//an/
# marian
# /nord//an/
# paran
# /pariz//an/
# /parok//an/
# /podi//an/
# /rus/i/an/
# /satan/
# /sekt//an/
# /senat//an/
# /skism//an/
# sudan
# /utopi//an/
# /vilagx//an/
# brazil/an/
# budh/an/
# egipt/an/
# gvine/an/
# epikur/an/
# iliri/an/
# ioni/an/
# iran/an/
# irland/an/
# islam/an/
# island/an/
# israel/an/
# kanad/an/
# /roman/
# laos/an/
# libi/an/
# malavi/an/
# meksik/an/
# nepal/an/
# romi/an/
# siri/an/
# somali/an/
# sovet/an/
# soveti/an/
# sudan/an/
# tibet/an/
# togol/an/
# toki/an/
# tong/an/
# trib/an/
# troj/an/
# uson/an/
# {'dietan': ['(!)diet(規定食)(!)an(会員)', 93000],
#  'dietano': ['(!)diet(規定食)(!)an(会員)o', 103000],
#  'dietana': ['(!)diet(規定食)(!)an(会員)a', 103000],
#  'dietane': ['(!)diet(規定食)(!)an(会員)e', 103000],
#  'afrikan': ['(!)afrik(アフリカ)(!)an(会員)', 103000],
#  'afrikano': ['(!)afrik(アフリカ)(!)an(会員)o', 113000],
#  'afrikana': ['(!)afrik(アフリカ)(!)an(会員)a', 113000],
#  'afrikane': ['(!)afrik(アフリカ)(!)an(会員)e', 113000],
#  'movadan': ['(!)mov(動かす)(!)ad(行為)(!)an(会員)', 123000],
#  'movadano': ['(!)mov(動かす)(!)ad(行為)(!)an(会員)o', 133000],
#  'movadana': ['(!)mov(動かす)(!)ad(行為)(!)an(会員)a', 133000],
#  'movadane': ['(!)mov(動かす)(!)ad(行為)(!)an(会員)e', 133000],
#  'akcian': ['(!)akci(株式)(!)an(会員)', 93000],
#  'akciano': ['(!)akci(株式)(!)an(会員)o', 103000],
#  'akciana': ['(!)akci(株式)(!)an(会員)a', 103000],
#  'akciane': ['(!)akci(株式)(!)an(会員)e', 103000],
#  'montaran': ['(!)mont(山)(!)ar(集団)(!)an(会員)', 133000],
#  'montarano': ['(!)mont(山)(!)ar(集団)(!)an(会員)o', 143000],
#  'montarana': ['(!)mont(山)(!)ar(集団)(!)an(会員)a', 143000],
#  'montarane': ['(!)mont(山)(!)ar(集団)(!)an(会員)e', 143000],
#  'amerikan': ['(!)amerik(アメリカ)(!)an(会員)', 113000],
#  'amerikano': ['(!)amerik(アメリカ)(!)an(会員)o', 123000],
#  'amerikana': ['(!)amerik(アメリカ)(!)an(会員)a', 123000],
#  'amerikane': ['(!)amerik(アメリカ)(!)an(会員)e', 123000],
#  'regnan': ['(!)regn(国家)(!)an(会員)', 93000],
#  'regnano': ['(!)regn(国家)(!)an(会員)o', 103000],
#  'regnana': ['(!)regn(国家)(!)an(会員)a', 103000],
#  'regnane': ['(!)regn(国家)(!)an(会員)e', 103000],
#  'dezertan': ['(!)dezert(砂漠)(!)an(会員)', 113000],
#  'dezertano': ['(!)dezert(砂漠)(!)an(会員)o', 123000],
#  'dezertana': ['(!)dezert(砂漠)(!)an(会員)a', 123000],
#  'dezertane': ['(!)dezert(砂漠)(!)an(会員)e', 123000],
#  'asocian': ['(!)asoci(協会)(!)an(会員)', 103000],
#  'asociano': ['(!)asoci(協会)(!)an(会員)o', 113000],
#  'asociana': ['(!)asoci(協会)(!)an(会員)a', 113000],
#  'asociane': ['(!)asoci(協会)(!)an(会員)e', 113000],
#  'insulan': ['(!)insul(島)(!)an(会員)', 103000],
#  'insulano': ['(!)insul(島)(!)an(会員)o', 113000],
#  'insulana': ['(!)insul(島)(!)an(会員)a', 113000],
#  'insulane': ['(!)insul(島)(!)an(会員)e', 113000],
#  'azian': ['(!)azi(アジア)(!)an(会員)', 83000],
#  'aziano': ['(!)azi(アジア)(!)an(会員)o', 93000],
#  'aziana': ['(!)azi(アジア)(!)an(会員)a', 93000],
#  'aziane': ['(!)azi(アジア)(!)an(会員)e', 93000],
#  'sxtatan': ['(!)sxtat(国家)(!)an(会員)', 103000],
#  'sxtatano': ['(!)sxtat(国家)(!)an(会員)o', 113000],
#  'sxtatana': ['(!)sxtat(国家)(!)an(会員)a', 113000],
#  'sxtatane': ['(!)sxtat(国家)(!)an(会員)e', 113000],
#  'doman': ['(!)dom(家)(!)an(会員)', 83000],
#  'domano': ['(!)dom(家)(!)an(会員)o', 93000],
#  'domana': ['(!)dom(家)(!)an(会員)a', 93000],
#  'domane': ['(!)dom(家)(!)an(会員)e', 93000],
#  'montan': ['(!)mont(山)(!)an(会員)', 93000],
#  'montano': ['(!)mont(山)(!)an(会員)o', 103000],
#  'montana': ['(!)mont(山)(!)an(会員)a', 103000],
#  'montane': ['(!)mont(山)(!)an(会員)e', 103000],
#  'familian': ['(!)famili(家族)(!)an(会員)', 113000],
#  'familiano': ['(!)famili(家族)(!)an(会員)o', 123000],
#  'familiana': ['(!)famili(家族)(!)an(会員)a', 123000],
#  'familiane': ['(!)famili(家族)(!)an(会員)e', 123000],
#  'urban': ['(!)urb(市)(!)an(会員)', 83000],
#  'urbano': ['(!)urb(市)(!)an(会員)o', 93000],
#  'urbana': ['(!)urb(市)(!)an(会員)a', 93000],
#  'urbane': ['(!)urb(市)(!)an(会員)e', 93000],
#  'popolan': ['(!)popol(人民)(!)an(会員)', 103000],
#  'popolano': ['(!)popol(人民)(!)an(会員)o', 113000],
#  'popolana': ['(!)popol(人民)(!)an(会員)a', 113000],
#  'popolane': ['(!)popol(人民)(!)an(会員)e', 113000],
#  'dekan': ['(!)dekan(学部長)', 63000],
#  'dekanano': ['(!)dekan(学部長)(!)an(会員)o', 113000],
#  'dekanana': ['(!)dekan(学部長)(!)an(会員)a', 113000],
#  'dekanane': ['(!)dekan(学部長)(!)an(会員)e', 113000],
#  'partian': ['(!)parti(党派)(!)an(会員)', 103000],
#  'partiano': ['(!)parti(党派)(!)an(会員)o', 113000],
#  'partiana': ['(!)parti(党派)(!)an(会員)a', 113000],
#  'partiane': ['(!)parti(党派)(!)an(会員)e', 113000],
#  'lokan': ['(!)lok(場所)(!)an(会員)', 83000],
#  'lokano': ['(!)lok(場所)(!)an(会員)o', 93000],
#  'lokana': ['(!)lok(場所)(!)an(会員)a', 93000],
#  'lokane': ['(!)lok(場所)(!)an(会員)e', 93000],
#  'sxipan': ['(!)sxip(船)(!)an(会員)', 93000],
#  'sxipano': ['(!)sxip(船)(!)an(会員)o', 103000],
#  'sxipana': ['(!)sxip(船)(!)an(会員)a', 103000],
#  'sxipane': ['(!)sxip(船)(!)an(会員)e', 103000],
#  'eklezian': ['(!)eklezi(教会)(!)an(会員)', 113000],
#  'ekleziano': ['(!)eklezi(教会)(!)an(会員)o', 123000],
#  'ekleziana': ['(!)eklezi(教会)(!)an(会員)a', 123000],
#  'ekleziane': ['(!)eklezi(教会)(!)an(会員)e', 123000],
#  'landan': ['(!)land(国)(!)an(会員)', 93000],
#  'landano': ['(!)land(国)(!)an(会員)o', 103000],
#  'landana': ['(!)land(国)(!)an(会員)a', 103000],
#  'landane': ['(!)land(国)(!)an(会員)e', 103000],
#  'orientan': ['(!)orient(東)(!)an(会員)', 113000],
#  'orientano': ['(!)orient(東)(!)an(会員)o', 123000],
#  'orientana': ['(!)orient(東)(!)an(会員)a', 123000],
#  'orientane': ['(!)orient(東)(!)an(会員)e', 123000],
#  'lernejan': ['(!)lern(学習する)(!)ej(場所)(!)an(会員)', 133000],
#  'lernejano': ['(!)lern(学習する)(!)ej(場所)(!)an(会員)o', 143000],
#  'lernejana': ['(!)lern(学習する)(!)ej(場所)(!)an(会員)a', 143000],
#  'lernejane': ['(!)lern(学習する)(!)ej(場所)(!)an(会員)e', 143000],
#  'enlandan': ['(!)en(中で)(!)land(国)(!)an(会員)', 133000],
#  'enlandano': ['(!)en(中で)(!)land(国)(!)an(会員)o', 143000],
#  'enlandana': ['(!)en(中で)(!)land(国)(!)an(会員)a', 143000],
#  'enlandane': ['(!)en(中で)(!)land(国)(!)an(会員)e', 143000],
#  'kalkan': ['(!)kalkan(踵)', 73000],
#  'kalkanano': ['(!)kalkan(踵)(!)an(会員)o', 123000],
#  'kalkanana': ['(!)kalkan(踵)(!)an(会員)a', 123000],
#  'kalkanane': ['(!)kalkan(踵)(!)an(会員)e', 123000],
#  'estraran': ['(!)estr(長)(!)ar(集団)(!)an(会員)', 133000],
#  'estrarano': ['(!)estr(長)(!)ar(集団)(!)an(会員)o', 143000],
#  'estrarana': ['(!)estr(長)(!)ar(集団)(!)an(会員)a', 143000],
#  'estrarane': ['(!)estr(長)(!)ar(集団)(!)an(会員)e', 143000],
#  'etnan': ['(!)etn(民族)(!)an(会員)', 83000],
#  'etnano': ['(!)etn(民族)(!)an(会員)o', 93000],
#  'etnana': ['(!)etn(民族)(!)an(会員)a', 93000],
#  'etnane': ['(!)etn(民族)(!)an(会員)e', 93000],
#  'euxropan': ['(!)euxrop(ヨーロッパ)(!)an(会員)', 113000],
#  'euxropano': ['(!)euxrop(ヨーロッパ)(!)an(会員)o', 123000],
#  'euxropana': ['(!)euxrop(ヨーロッパ)(!)an(会員)a', 123000],
#  'euxropane': ['(!)euxrop(ヨーロッパ)(!)an(会員)e', 123000],
#  'fazan': ['(!)fazan(キジ)', 63000],
#  'fazanano': ['(!)fazan(キジ)(!)an(会員)o', 113000],
#  'fazanana': ['(!)fazan(キジ)(!)an(会員)a', 113000],
#  'fazanane': ['(!)fazan(キジ)(!)an(会員)e', 113000],
#  'polican': ['(!)polic(警察)(!)an(会員)', 103000],
#  'policano': ['(!)polic(警察)(!)an(会員)o', 113000],
#  'policana': ['(!)polic(警察)(!)an(会員)a', 113000],
#  'policane': ['(!)polic(警察)(!)an(会員)e', 113000],
#  'socian': ['(!)soci(社会)(!)an(会員)', 93000],
#  'sociano': ['(!)soci(社会)(!)an(会員)o', 103000],
#  'sociana': ['(!)soci(社会)(!)an(会員)a', 103000],
#  'sociane': ['(!)soci(社会)(!)an(会員)e', 103000],
#  'societan': ['(!)societ(会)(!)an(会員)', 113000],
#  'societano': ['(!)societ(会)(!)an(会員)o', 123000],
#  'societana': ['(!)societ(会)(!)an(会員)a', 123000],
#  'societane': ['(!)societ(会)(!)an(会員)e', 123000],
#  'grupan': ['(!)grup(グループ)(!)an(会員)', 93000],
#  'grupano': ['(!)grup(グループ)(!)an(会員)o', 103000],
#  'grupana': ['(!)grup(グループ)(!)an(会員)a', 103000],
#  'grupane': ['(!)grup(グループ)(!)an(会員)e', 103000],
#  'ligan': ['(!)lig(結ぶ)(!)an(会員)', 83000],
#  'ligano': ['(!)lig(結ぶ)(!)an(会員)o', 93000],
#  'ligana': ['(!)lig(結ぶ)(!)an(会員)a', 93000],
#  'ligane': ['(!)lig(結ぶ)(!)an(会員)e', 93000],
#  'nacian': ['(!)naci(国民)(!)an(会員)', 93000],
#  'naciano': ['(!)naci(国民)(!)an(会員)o', 103000],
#  'naciana': ['(!)naci(国民)(!)an(会員)a', 103000],
#  'naciane': ['(!)naci(国民)(!)an(会員)e', 103000],
#  'koran': ['(!)koran(コーラン)', 63000],
#  'koranano': ['(!)koran(コーラン)(!)an(会員)o', 113000],
#  'koranana': ['(!)koran(コーラン)(!)an(会員)a', 113000],
#  'koranane': ['(!)koran(コーラン)(!)an(会員)e', 113000],
#  'religian': ['(!)religi(宗教)(!)an(会員)', 113000],
#  'religiano': ['(!)religi(宗教)(!)an(会員)o', 123000],
#  'religiana': ['(!)religi(宗教)(!)an(会員)a', 123000],
#  'religiane': ['(!)religi(宗教)(!)an(会員)e', 123000],
#  'kuban': ['(!)kub(立方体)(!)an(会員)', 83000],
#  'kubano': ['(!)kub(立方体)(!)an(会員)o', 93000],
#  'kubana': ['(!)kub(立方体)(!)an(会員)a', 93000],
#  'kubane': ['(!)kub(立方体)(!)an(会員)e', 93000],
#  'majoran': ['(!)major(陸軍少佐)(!)an(会員)', 103000],
#  'majorano': ['(!)major(陸軍少佐)(!)an(会員)o', 113000],
#  'majorana': ['(!)major(陸軍少佐)(!)an(会員)a', 113000],
#  'majorane': ['(!)major(陸軍少佐)(!)an(会員)e', 113000],
#  'marian': ['marian', 53000],
#  'marianano': ['marian(!)an(会員)o', 103000],
#  'marianana': ['marian(!)an(会員)a', 103000],
#  'marianane': ['marian(!)an(会員)e', 103000],
#  'nordan': ['(!)nord(北)(!)an(会員)', 93000],
#  'nordano': ['(!)nord(北)(!)an(会員)o', 103000],
#  'nordana': ['(!)nord(北)(!)an(会員)a', 103000],
#  'nordane': ['(!)nord(北)(!)an(会員)e', 103000],
#  'paran': ['paran', 43000],
#  'paranano': ['paran(!)an(会員)o', 93000],
#  'paranana': ['paran(!)an(会員)a', 93000],
#  'paranane': ['paran(!)an(会員)e', 93000],
#  'parizan': ['(!)pariz(パリ)(!)an(会員)', 103000],
#  'parizano': ['(!)pariz(パリ)(!)an(会員)o', 113000],
#  'parizana': ['(!)pariz(パリ)(!)an(会員)a', 113000],
#  'parizane': ['(!)pariz(パリ)(!)an(会員)e', 113000],
#  'parokan': ['(!)parok(教区)(!)an(会員)', 103000],
#  'parokano': ['(!)parok(教区)(!)an(会員)o', 113000],
#  'parokana': ['(!)parok(教区)(!)an(会員)a', 113000],
#  'parokane': ['(!)parok(教区)(!)an(会員)e', 113000],
#  'podian': ['(!)podi(ひな壇)(!)an(会員)', 93000],
#  'podiano': ['(!)podi(ひな壇)(!)an(会員)o', 103000],
#  'podiana': ['(!)podi(ひな壇)(!)an(会員)a', 103000],
#  'podiane': ['(!)podi(ひな壇)(!)an(会員)e', 103000],
#  'rusian': ['(!)rus(ロシア人)i(!)an(会員)', 93000],
#  'rusiano': ['(!)rus(ロシア人)i(!)an(会員)o', 103000],
#  'rusiana': ['(!)rus(ロシア人)i(!)an(会員)a', 103000],
#  'rusiane': ['(!)rus(ロシア人)i(!)an(会員)e', 103000],
#  'satan': ['(!)satan(サタン)', 63000],
#  'satanano': ['(!)satan(サタン)(!)an(会員)o', 113000],
#  'satanana': ['(!)satan(サタン)(!)an(会員)a', 113000],
#  'satanane': ['(!)satan(サタン)(!)an(会員)e', 113000],
#  'sektan': ['(!)sekt(宗派)(!)an(会員)', 93000],
#  'sektano': ['(!)sekt(宗派)(!)an(会員)o', 103000],
#  'sektana': ['(!)sekt(宗派)(!)an(会員)a', 103000],
#  'sektane': ['(!)sekt(宗派)(!)an(会員)e', 103000],
#  'senatan': ['(!)senat(参議院)(!)an(会員)', 103000],
#  'senatano': ['(!)senat(参議院)(!)an(会員)o', 113000],
#  'senatana': ['(!)senat(参議院)(!)an(会員)a', 113000],
#  'senatane': ['(!)senat(参議院)(!)an(会員)e', 113000],
#  'skisman': ['(!)skism(分裂)(!)an(会員)', 103000],
#  'skismano': ['(!)skism(分裂)(!)an(会員)o', 113000],
#  'skismana': ['(!)skism(分裂)(!)an(会員)a', 113000],
#  'skismane': ['(!)skism(分裂)(!)an(会員)e', 113000],
#  'sudan': ['sudan', 43000],
#  'sudanano': ['sudan(!)an(会員)o', 93000],
#  'sudanana': ['sudan(!)an(会員)a', 93000],
#  'sudanane': ['sudan(!)an(会員)e', 93000],
#  'utopian': ['(!)utopi(ユートピア)(!)an(会員)', 103000],
#  'utopiano': ['(!)utopi(ユートピア)(!)an(会員)o', 113000],
#  'utopiana': ['(!)utopi(ユートピア)(!)an(会員)a', 113000],
#  'utopiane': ['(!)utopi(ユートピア)(!)an(会員)e', 113000],
#  'vilagxan': ['(!)vilagx(村)(!)an(会員)', 113000],
#  'vilagxano': ['(!)vilagx(村)(!)an(会員)o', 123000],
#  'vilagxana': ['(!)vilagx(村)(!)an(会員)a', 123000],
#  'vilagxane': ['(!)vilagx(村)(!)an(会員)e', 123000],
#  'brazilan': ['brazil(!)an(会員)', 93000],
#  'brazilano': ['brazil(!)an(会員)o', 103000],
#  'brazilana': ['brazil(!)an(会員)a', 103000],
#  'brazilane': ['brazil(!)an(会員)e', 103000],
#  'budhan': ['budh(!)an(会員)', 73000],
#  'budhano': ['budh(!)an(会員)o', 83000],
#  'budhana': ['budh(!)an(会員)a', 83000],
#  'budhane': ['budh(!)an(会員)e', 83000],
#  'egiptan': ['egipt(!)an(会員)', 83000],
#  'egiptano': ['egipt(!)an(会員)o', 93000],
#  'egiptana': ['egipt(!)an(会員)a', 93000],
#  'egiptane': ['egipt(!)an(会員)e', 93000],
#  'gvinean': ['gvine(!)an(会員)', 83000],
#  'gvineano': ['gvine(!)an(会員)o', 93000],
#  'gvineana': ['gvine(!)an(会員)a', 93000],
#  'gvineane': ['gvine(!)an(会員)e', 93000],
#  'epikuran': ['epikur(!)an(会員)', 93000],
#  'epikurano': ['epikur(!)an(会員)o', 103000],
#  'epikurana': ['epikur(!)an(会員)a', 103000],
#  'epikurane': ['epikur(!)an(会員)e', 103000],
#  'ilirian': ['iliri(!)an(会員)', 83000],
#  'iliriano': ['iliri(!)an(会員)o', 93000],
#  'iliriana': ['iliri(!)an(会員)a', 93000],
#  'iliriane': ['iliri(!)an(会員)e', 93000],
#  'ionian': ['ioni(!)an(会員)', 73000],
#  'ioniano': ['ioni(!)an(会員)o', 83000],
#  'ioniana': ['ioni(!)an(会員)a', 83000],
#  'ioniane': ['ioni(!)an(会員)e', 83000],
#  'iranan': ['iran(!)an(会員)', 73000],
#  'iranano': ['iran(!)an(会員)o', 83000],
#  'iranana': ['iran(!)an(会員)a', 83000],
#  'iranane': ['iran(!)an(会員)e', 83000],
#  'irlandan': ['irland(!)an(会員)', 93000],
#  'irlandano': ['irland(!)an(会員)o', 103000],
#  'irlandana': ['irland(!)an(会員)a', 103000],
#  'irlandane': ['irland(!)an(会員)e', 103000],
#  'islaman': ['islam(!)an(会員)', 83000],
#  'islamano': ['islam(!)an(会員)o', 93000],
#  'islamana': ['islam(!)an(会員)a', 93000],
#  'islamane': ['islam(!)an(会員)e', 93000],
#  'islandan': ['island(!)an(会員)', 93000],
#  'islandano': ['island(!)an(会員)o', 103000],
#  'islandana': ['island(!)an(会員)a', 103000],
#  'islandane': ['island(!)an(会員)e', 103000],
#  'israelan': ['israel(!)an(会員)', 93000],
#  'israelano': ['israel(!)an(会員)o', 103000],
#  'israelana': ['israel(!)an(会員)a', 103000],
#  'israelane': ['israel(!)an(会員)e', 103000],
#  'kanadan': ['kanad(!)an(会員)', 83000],
#  'kanadano': ['kanad(!)an(会員)o', 93000],
#  'kanadana': ['kanad(!)an(会員)a', 93000],
#  'kanadane': ['kanad(!)an(会員)e', 93000],
#  'roman': ['(!)roman(長編小説)', 63000],
#  'romanano': ['(!)roman(長編小説)(!)an(会員)o', 113000],
#  'romanana': ['(!)roman(長編小説)(!)an(会員)a', 113000],
#  'romanane': ['(!)roman(長編小説)(!)an(会員)e', 113000],
#  'laosan': ['laos(!)an(会員)', 73000],
#  'laosano': ['laos(!)an(会員)o', 83000],
#  'laosana': ['laos(!)an(会員)a', 83000],
#  'laosane': ['laos(!)an(会員)e', 83000],
#  'libian': ['libi(!)an(会員)', 73000],
#  'libiano': ['libi(!)an(会員)o', 83000],
#  'libiana': ['libi(!)an(会員)a', 83000],
#  'libiane': ['libi(!)an(会員)e', 83000],
#  'malavian': ['malavi(!)an(会員)', 93000],
#  'malaviano': ['malavi(!)an(会員)o', 103000],
#  'malaviana': ['malavi(!)an(会員)a', 103000],
#  'malaviane': ['malavi(!)an(会員)e', 103000],
#  'meksikan': ['meksik(!)an(会員)', 93000],
#  'meksikano': ['meksik(!)an(会員)o', 103000],
#  'meksikana': ['meksik(!)an(会員)a', 103000],
#  'meksikane': ['meksik(!)an(会員)e', 103000],
#  'nepalan': ['nepal(!)an(会員)', 83000],
#  'nepalano': ['nepal(!)an(会員)o', 93000],
#  'nepalana': ['nepal(!)an(会員)a', 93000],
#  'nepalane': ['nepal(!)an(会員)e', 93000],
#  'romian': ['romi(!)an(会員)', 73000],
#  'romiano': ['romi(!)an(会員)o', 83000],
#  'romiana': ['romi(!)an(会員)a', 83000],
#  'romiane': ['romi(!)an(会員)e', 83000],
#  'sirian': ['siri(!)an(会員)', 73000],
#  'siriano': ['siri(!)an(会員)o', 83000],
#  'siriana': ['siri(!)an(会員)a', 83000],
#  'siriane': ['siri(!)an(会員)e', 83000],
#  'somalian': ['somali(!)an(会員)', 93000],
#  'somaliano': ['somali(!)an(会員)o', 103000],
#  'somaliana': ['somali(!)an(会員)a', 103000],
#  'somaliane': ['somali(!)an(会員)e', 103000],
#  'sovetan': ['sovet(!)an(会員)', 83000],
#  'sovetano': ['sovet(!)an(会員)o', 93000],
#  'sovetana': ['sovet(!)an(会員)a', 93000],
#  'sovetane': ['sovet(!)an(会員)e', 93000],
#  'sovetian': ['soveti(!)an(会員)', 93000],
#  'sovetiano': ['soveti(!)an(会員)o', 103000],
#  'sovetiana': ['soveti(!)an(会員)a', 103000],
#  'sovetiane': ['soveti(!)an(会員)e', 103000],
#  'sudanan': ['sudan(!)an(会員)', 83000],
#  'tibetan': ['tibet(!)an(会員)', 83000],
#  'tibetano': ['tibet(!)an(会員)o', 93000],
#  'tibetana': ['tibet(!)an(会員)a', 93000],
#  'tibetane': ['tibet(!)an(会員)e', 93000],
#  'togolan': ['togol(!)an(会員)', 83000],
#  'togolano': ['togol(!)an(会員)o', 93000],
#  'togolana': ['togol(!)an(会員)a', 93000],
#  'togolane': ['togol(!)an(会員)e', 93000],
#  'tokian': ['toki(!)an(会員)', 73000],
#  'tokiano': ['toki(!)an(会員)o', 83000],
#  'tokiana': ['toki(!)an(会員)a', 83000],
#  'tokiane': ['toki(!)an(会員)e', 83000],
#  'tongan': ['tong(!)an(会員)', 73000],
#  'tongano': ['tong(!)an(会員)o', 83000],
#  'tongana': ['tong(!)an(会員)a', 83000],
#  'tongane': ['tong(!)an(会員)e', 83000],
#  'triban': ['trib(!)an(会員)', 73000],
#  'tribano': ['trib(!)an(会員)o', 83000],
#  'tribana': ['trib(!)an(会員)a', 83000],
#  'tribane': ['trib(!)an(会員)e', 83000],
#  'trojan': ['troj(!)an(会員)', 73000],
#  'trojano': ['troj(!)an(会員)o', 83000],
#  'trojana': ['troj(!)an(会員)a', 83000],
#  'trojane': ['troj(!)an(会員)e', 83000],
#  'usonan': ['uson(!)an(会員)', 73000],
#  'usonano': ['uson(!)an(会員)o', 83000],
#  'usonana': ['uson(!)an(会員)a', 83000],
#  'usonane': ['uson(!)an(会員)e', 83000]}

# %%
##RRの編集(主に置換の優先順位の変更) ここでも置換の仕方の変更ができないことはないが、品詞の種類に応じて接尾辞や接頭辞を追加するところをスキップすることになってしまう。

never_used_as_roots_only=["vin","lin","sin","min"]
for i in never_used_as_roots_only:
    RR[i]=[i,len(i)*10000+3000]##これらについては数字の大きさはそこまで重要ではない
# QQ[i.replace('/', '')]=[j[0].replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),j[1],len(i.replace('/', ''))*10000-3000]##漢字化しない単語は優先順位を下げる
# conversion_format(hanzi, word, format_type)


# RR['amas']=['<ruby>爱<rt>am</rt></ruby>as',len('amas')*10000+2500]##漢字化しない語根単体については上記で、うまく処理できているはずだが、amasoは群oと漢字化するので。
RR['farigx'][1]=len('farigx')*10000+27500##優先順位だけ変更

x='mondo/n'
RR[x.replace('/', '')]=[safe_replace(x,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),  len(x.replace('/', ''))*10000+3000]

##正しく語根分解・漢字変換してほしいやつ  anとenは念の為a/n/,e/n/としておく。ant,int,ontは大丈夫  空白を使うのは最終手段。  ","は絶対に使っては駄目
y1=[['gvid/ant/o',73000],['am/as',33000],["kor/a/n",43000],["ink/a",33000],["post/e/n",53000],["per/e",33000],["fer/o",33000],["kor/e",33000],["mal/a/j",43000],["mal/e",33000],
    ['sam/o',33000],['sat/a/n',43000],['sav/oj',43000],['sud/a/n',43000],['vet/o',33000],['ir/is',33000],['regul/us',63000],['akir/ant',63000],["prem/is",53000],
    ["mark/ot",53000],["kolor/ad",63000],["lot/us",43000],["mank/is",53000],["pat/os",43000],["rem/ont",53000],["satir/us",63000],["send/at",53000],["send/ot",53000],
    ["spir/ant",63000],["ten/is",43000],["trakt/at",63000],["alt/e",33000],["apog/e ",53000],["dom/e/n",4300],["kaz/e/ ",43000],
    ["post/e/n",53000],["posten/ul",73000],["kalk/a/n ",63000],["faz/a/n",43000],["hav/a/j",43000],["sol/e",33000],["lam/a",33000],
    ["ref/oj",43000],["akir/ant",63000],["ordin/at",63000],["form/at",53000],["kant/at",53000],["end/os",43000],
    ["konus ",53000],["lek/ant",53000],["leg/at",43000],["taks/us",53000]]##["pi/a/n",38000] anをa/n/で分けるのは正しくはないが。  havaj
for i in y1:
    RR[i[0].replace('/', '')]=[safe_replace(i[0],replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), i[1]]

##an系
ANAN={}
for an1 in replace_pattern(an):
    i2=an1[2]
    ANAN[i2.replace('/', '')]=[safe_replace(i2,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i2)-1)*10000+3000]
    i3 = re.sub(r"/a/n$", "", i2)##正規表現を使わないと、etn/a/n　において、etnのnまで削られてしまった。
    i4=i3+"/an/o"
    i5=i3+"/an/a"
    i6=i3+"/an/e"
    ANAN[i4.replace('/', '')]=[safe_replace(i4,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i4)-1)*10000+3000]
    ANAN[i5.replace('/', '')]=[safe_replace(i5,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i5)-1)*10000+3000]
    ANAN[i6.replace('/', '')]=[safe_replace(i6,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i6)-1)*10000+3000]


y2=['diet/a/n','afrik/a/n','mov/ad/a/n','akci/a/n','mont/ar/a/n','amerik/a/n','regn/a/n','dezert/a/n','asoci/a/n','insul/a/n','azi/a/n','sxtat/a/n','dom/a/n',
    'mont/a/n','famili/a/n','urb/a/n','popol/a/n','parti/a/n','lok/a/n','sxip/a/n','eklezi/a/n','land/a/n','orient/a/n','lern/ej/a/n','en/land/a/n','estr/ar/a/n',
    'etn/a/n','euxrop/a/n','polic/a/n','soci/a/n','soci/et/a/n','grup/a/n','lig/a/n','naci/a/n','religi/a/n','kub/a/n','major/a/n','pariz/a/n','parok/a/n','podi/a/n',
    'rus/i/a/n','sekt/a/n','senat/a/n','skism/a/n','utopi/a/n','vilagx/a/n',"dek/a/n","nord/a/n","sat/a/n","par/a/n"]##["pi/a/n",38000] anをa/n/で分けるのは正しくはないが。  havaj
for i2 in y2:
    RR[i2.replace('/', '')]=[safe_replace(i2,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i2)-1)*10000+3000]
    i3 = re.sub(r"/a/n$", "", i2)##正規表現を使わないと、etn/a/n　において、etnのnまで削られてしまった。
    i4=i3+"/an/o"
    i5=i3+"/an/a"
    i6=i3+"/an/e"
    RR[i4.replace('/', '')]=[safe_replace(i4,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i4)-1)*10000+3000]
    RR[i5.replace('/', '')]=[safe_replace(i5,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i5)-1)*10000+3000]
    RR[i6.replace('/', '')]=[safe_replace(i6,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i6)-1)*10000+3000]

##正しく語根分解・漢字変換してほしいやつ  anとenは念の為a/n/,e/n/としておく。ant,int,ontは大丈夫  空白を使うのは最終手段。  ","は絶対に使っては駄目
y1=[['sole/o',43000],['sole/a',43000],["sudan/o",53000],["sudan/a",53000],["fazan/o",53000],["fazan/a",53000],["re/foj/a",53000],["re/foj/o",53000],
    ["re/foj/e",53000],["tenis/o",53000],["paran/o",53000],["paran/a",53000],["dekan/o",53000],["dekan/a",53000],["satan/a",53000],["satan/o",53000]]##["pi/a/n",38000] anをa/n/で分けるのは正しくはないが。  havaj
for i in y1:
    RR[i[0].replace('/', '')]=[safe_replace(i[0],replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), i[1]]


##以下は完全手作業
RR['dat/um/i'.replace('/', '')]=[safe_replace('dat/um/i',replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),  len('dat/um/i'.replace('/', ''))*10000+3000]
RR['dat/um/u'.replace('/', '')]=[safe_replace('dat/um/u',replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),  len('dat/um/u'.replace('/', ''))*10000+3000]
RR['dat/um/u!'.replace('/', '')]=[safe_replace('dat/um/u!',replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),  len('dat/um/u!'.replace('/', ''))*10000+3000]
#dat/um/u  dat/um/u!
RR['tra/met/i'.replace('/', '')]=[safe_replace('tra/met/i',replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),  len('tra/met/i'.replace('/', ''))*10000+3000]
RR['tra/met/u'.replace('/', '')]=[safe_replace('tra/met/u',replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),  len('tra/met/u'.replace('/', ''))*10000+3000]
RR['tra/met/u!'.replace('/', '')]=[safe_replace('tra/met/u!',replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"),  len('tra/met/u!'.replace('/', ''))*10000+3000]

# RR['trametu!']=['<ruby>通<rt>tra</rt></ruby><ruby>置<rt>met</rt></ruby>u!',len('trametu!')*10000+2500]
#tra/met/u  tra/met/u!

# %%
AAA={}
i2="etn/a/n"
AAA[i2.replace('/', '')]=[safe_replace(i2,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i2.replace('/', ''))-1)*10000+3000]
i3 = re.sub(r"/a/n$", "", i2)
i4=i3+"/an/o"
i5=i3+"/an/a"
i6=i3+"/an/e"
AAA[i4.replace('/', '')]=[safe_replace(i4,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i4.replace('/', ''))-1)*10000+3000]
AAA[i5.replace('/', '')]=[safe_replace(i5,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i5.replace('/', ''))-1)*10000+3000]
AAA[i6.replace('/', '')]=[safe_replace(i6,replacements).replace("</rt></ruby>","%%%").replace('/', '').replace("%%%","</rt></ruby>"), (len(i6.replace('/', ''))-1)*10000+3000]

# %%
AAA
# Out:
# {'etnan': ['etn(民族)an', 43000],
#  'etnano': ['etn(民族)an(会員)o', 53000],
#  'etnana': ['etn(民族)an(会員)a', 53000],
#  'etnane': ['etn(民族)an(会員)e', 53000]}

# %%
print(RR["dekano"],RR["satano"],RR["satana"])
print(RR["etnano"],RR["dekano"],RR["satano"],RR["satana"])
print(RR["parano"],RR["parana"],RR["montane"],RR["satan"])
# Out:
# ['dekan(学部長)o', 53000] ['satan(サタン)o', 53000] ['satan(サタン)a', 53000]
# ['etn(民族)an(会員)o', 73000] ['dekan(学部長)o', 53000] ['satan(サタン)o', 53000] ['satan(サタン)a', 53000]
# ['parano', 53000] ['parana', 53000] ['mont(山)an(会員)e', 83000] ['sat(満腹した)an', 63000]

# %%
print(RR["gvidanto"],RR["amas"],RR["koran"],RR["lian"])
print(RR["inka"],RR["posten"],RR["pere"],RR["fero"])
print(RR["korano"],RR["kore"],RR["malaj"],RR["male"],RR["paran"],RR["samo"])
print(RR["satan"],RR["savoj"],RR["sudan"],RR["veto"],RR["iris"],RR["regulus"])
print(RR["akirant"],RR["premis"],RR["markot"],RR["kolorad"],RR["iris"],RR["regulus"])
print(RR["lotus"],RR["premis"],RR["markot"],RR["kolorad"],RR["lotus"],RR["mankis"])
print(RR["patos"],RR["remont"],RR["satirus"],RR["sendat"],RR["sendot"],RR["spirant"])
print(RR["tenis "],RR["traktat"],RR["alte"],RR["apoge "],RR["domen"],RR["kaze "])
print(RR["dekan"],RR["posten"],RR["postenul"],RR["kalkan "],RR["fazan "],RR["havaj"])
print(RR["sole "],RR["lama"],RR["malaj"],RR["nordan "],RR["refoj "],RR["refojn"])
print(RR["ordinat"],RR["akirant"],RR["format"],RR["kantat"],RR["endos"])
print(RR["konus "],RR["lekant"],RR["legat"],RR["taksus"],RR["reguluso"],RR["endos"])

print(RR["reguluso"],RR["akiranto"],RR["kolorado"],RR["satiruso"],RR["spiranto"]
      ,RR["traktato"],RR["nordano"],RR["akiranto"],RR["ordinato"])
# zzzz=[['regul/us',63000],['akir/ant',63000],["kolor/ad",63000],["satir/us",63000]
#     ,["spir/ant",63000],["trakt/at",63000],["nord/a/n ",63000],["akir/ant",63000],["ordin/at",63000]]
# Out:
# ['gvid(案内する)ant(能動・継続)o', 73000] ['am(愛する)as(現在形)', 33000] ['kor(心)an', 43000] ['lian(つる植物)', 40000]
# ['ink(インク)a', 33000] ['post(後で)en', 53000] ['per(よって)e', 33000] ['fer(鉄)o', 33000]
# ['koran(コーラン)o', 57000] ['kor(心)e', 33000] ['mal(正反対)aj', 43000] ['mal(正反対)e', 33000] ['par(一対)an', 63000] ['sam(同一の)o', 33000]
# ['sat(満腹した)an', 63000] ['sav(救助する)oj', 43000] ['sud(南)an', 43000] ['vet(賭ける)o', 33000] ['ir(行く)is(過去形)', 33000] ['regul(規則)us(条件法)', 63000]
# ['akir(獲得する)ant(能動・継続)', 63000] ['prem(押える)is(過去形)', 53000] ['mark(しるし)ot(受動・将然)', 53000] ['kolor(色)ad(行為)', 63000] ['ir(行く)is(過去形)', 33000] ['regul(規則)us(条件法)', 63000]
# ['lot(くじ)us(条件法)', 43000] ['prem(押える)is(過去形)', 53000] ['mark(しるし)ot(受動・将然)', 53000] ['kolor(色)ad(行為)', 63000] ['lot(くじ)us(条件法)', 43000] ['mank(欠けている)is(過去形)', 53000]
# ['pat(フライパン)os(未来形)', 43000] ['rem(漕ぐ)ont(能動・将然)', 53000] ['satir(諷刺)us(条件法)', 63000] ['send(送る)at(受動・継続)', 53000] ['send(送る)ot(受動・将然)', 53000] ['spir(呼吸する)ant(能動・継続)', 63000]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 8
#       6 print(RR["lotus"],RR["premis"],RR["markot"],RR["kolorad"],RR["lotus"],RR["mankis"])
#       7 print(RR["patos"],RR["remont"],RR["satirus"],RR["sendat"],RR["sendot"],RR["spirant"])
# ----> 8 print(RR["tenis "],RR["traktat"],RR["alte"],RR["apoge "],RR["domen"],RR["kaze "])
#       9 print(RR["dekan"],RR["posten"],RR["postenul"],RR["kalkan "],RR["fazan "],RR["havaj"])
#      10 print(RR["sole "],RR["lama"],RR["malaj"],RR["nordan "],RR["refoj "],RR["refojn"])
#
# KeyError: 'tenis '

# %%
with open("RR.txt", 'w', encoding='utf-8') as file:
    for old,new in  RR.items():
        file.write(f'{old},{new[0]},{new[1]}\n')

# %%
##リストreplacementはコードの前半と後半で別物になるので注意が必要。
safe_replace("amas",replacements),safe_replace("min",replacements),safe_replace("mondo/n",replacements),safe_replace('gvid/ant/o',replacements)
# Out:
# ('amas(集積)', 'min(鉱山)', 'mond(世界)o/n', 'gvid(案内する)/ant(能動・継続)/o')

# %%
TT=[]
for old,new in  RR.items():
    if isinstance(new[1], int):
        TT.append((old,new[0],new[1]))
# print(len(TT),len(RR))

# %%
pre_replacements3= sorted(TT, key=lambda x: x[2], reverse=True)##(置換順序の数字の大きさ順にソート!)

# %%
with open("pre_replacements3.txt", 'w', encoding='utf-8') as file:
    for old,new,priority in pre_replacements3:
        file.write(f'{old},{new},{priority}\n')

# %%
##'エスペラント語根'、'置換漢字'、'place holder'の順に並べ、最終的な置換に用いる"replacements"リストを作成。
replacements=[]
for kk in range(len(pre_replacements3)):
    if len(pre_replacements3[kk][0])>1:
        replacements.append([pre_replacements3[kk][0],pre_replacements3[kk][1],loaded_strings[kk]])

# %%
len(replacements)
# Out:
# 103294

# %%
##'大文字'、'小文字'、'文頭だけ大文字'のケースに対応。
replacements2=[]
for old,new,place_holder in replacements:
    replacements2.append((old,new,place_holder))
    replacements2.append((old.upper(),new.upper(),place_holder[:-1]+'up$'))##place holderを少し変更する必要があった。
    if old[0]==' ':
        replacements2.append((old[0] + old[1].upper() + old[2:],new[0] + new[1].upper() + new[2:],place_holder[:-1]+'cap$'))##new[0] + new[1].upper() + new[2:]は本当は怪しいが。。  
    else:
        replacements2.append((old.capitalize(),new.capitalize(),place_holder[:-1]+'cap$'))
len(replacements2)
# Out:
# 309882

# %%
#"replacements2"リストの内容を確認
with open("replacements_list_html.txt", 'w', encoding='utf-8') as file:
    for old,new,place_holder in replacements2:
        file.write(f'{old},{new},{place_holder}\n')
#最終的な置換に用いる"replacements2"リストの長さ。

# %%
replacements3=[]
with open("replacements_list_html.txt", 'r', encoding='utf-8') as file:
    for line in file:
        line = line.rstrip()##stripでは置換に最初の空白を反映できなくなってしまう。
        j = line.split(',')
        if len(j)==3:
            old,new,place_holder=j[0],j[1],j[2]
            replacements3.append((old,new,place_holder))
#len(replacements3)  
#replacements2とreplacements3は全く同一のリストである。

# %%
##置換に用いる関数。正規表現、C++など様々な形式の置換を試したが、pythonで'place holder'を用いる形式の置換が、最も処理が高速であった。(しかも大変シンプルでわかりやすい。)
def safe_replace(text, replacements):
    valid_replacements = {}
    # 置換対象(old)を'place holder'に一時的に置換
    for old, new, placeholder in replacements:
        if old in text:
            text = text.replace(old, placeholder)
            valid_replacements[placeholder] = new# 後で置換後の文字列(new)に置換し直す必要がある'place holder'を辞書(valid_replacements)に記録しておく。
    #'place holder'を置換後の文字列(new)に置換)
    for placeholder, new in valid_replacements.items():
        text = text.replace(placeholder, new)
    return text

# %%
## multiprocessingのための関数群　テキストを行数によって設定プロセス数(num_processes)に等分割して、それぞれのプロセスで並列に置換処理を実行してから、再度分割したテキストを結合する。

import multiprocessing
def process_segment(lines, replacements):
    # 文字列のリストを結合してから置換処理を実行 linesには\nが含まれていない状態の文字列群が格納されている。
    segment = '\n'.join(lines)
    segment = safe_replace(segment, replacements)#ここでsafe_replace関数の実行
    return segment

def parallel_process(text, num_processes,replacements):
    #テキストを行で分割
    lines = text.split('\n')
    num_lines = len(lines)
    lines_per_process = num_lines // num_processes

    #各プロセスに割り当てる行のリストを決定
    ranges = [(i * lines_per_process, (i + 1) * lines_per_process) for i in range(num_processes)]
    ranges[-1] = (ranges[-1][0], num_lines)  #最後のプロセスが残り全てを処理

    with multiprocessing.Pool(processes=num_processes) as pool:
        # 並列処理を実行
        results = pool.starmap(process_segment, [(lines[start:end], replacements) for start, end in ranges])

    # 結果を結合
    return '\n'.join(result for result in results)

# %%
text="koran dankon vin sin lin lino sino amas amaso havis aviso  altaj altajo"
text=replace_esperanto_chars(text,esperanto_to_x)
safe_replace(text,replacements3)
# parallel_process(text*1,1, replacements)
# Out:
# 'kor(心)an dank(感謝する)on vin sin lin lin(亜麻)o sin(懐)o am(愛する)as(現在形) amas(集積)o hav(持っている)is(過去形) aviso  alt(高い)aj altajo'

# %%
# safe_replace("Membroj havas  Mi farigxis multaj taskoj  Mi amas vin multe necese movado sin senegal nova ",replacements3)
# safe_replace("mondon mondonas amon amo amonj! amojn! mondon mondo vino vinon  vinojn vin vino nova ",replacements3)
# safe_replace("sin sindoni sindonemo dion Dion amon amon dio dia Senegala senegal senegala senegalo",replacements3)
safe_replace("popolan parizan parizano/popolan. senatan senatan senatano/ skisman parizan skisman/ aman aman/dankon vin sin lin lino sino amas amaso havis aviso  altaj altajo",replacements3)
# Out:
# 'popol(人民)an pariz(パリ)an pariz(パリ)an(会員)o/popol(人民)an. senat(参議院)an senat(参議院)an senat(参議院)an(会員)o/ skism(分裂)an pariz(パリ)an skism(分裂)an/ aman(手) aman(手)/dank(感謝する)on vin sin lin lin(亜麻)o sin(懐)o am(愛する)as(現在形) amas(集積)o hav(持っている)is(過去形) aviso  alt(高い)aj altajo'

# %%
import re
def find_strings_in_text(text):
    # 正規表現パターンを定義
    pattern = re.compile(r'%%(.{1,50}?)%%')
    matches = []
    used_indices = set()

    # 正規表現のマッチを見つける
    for match in pattern.finditer(text):
        start, end = match.span()
        # 重複する%%を避けるためにインデックスをチェック
        if start not in used_indices and end-2 not in used_indices:  # end-2 because of double %%
            matches.append(match.group(1))
            # インデックスを使用済みセットに追加
            used_indices.update(range(start, end))
    return matches
def load_placeholders(filename):
    with open(filename, 'r') as file:
        placeholders = [line.strip() for line in file if line.strip()]
    return placeholders
def create_replacements(text, placeholders):
    # テキストから%%で囲まれた部分を抽出
    matches = find_strings_in_text(text)
    replacements_list_for_intact_parts = []
    # プレースホルダーとマッチを対応させる
    for i, match in enumerate(matches):
        if i < len(placeholders):
            replacements_list_for_intact_parts.append([f"%%{match}%%", placeholders[i]])
        else:
            break  # プレースホルダーが足りなくなった場合は終了
    return replacements_list_for_intact_parts
# 使用例
text = text = """%%L. Zamenhof.%% Kongresaj paroladoj
Kongresaj paroladoj
# %%Lazarj Markoviĉ Zamenhof%%

Kongresaj paroladoj

Serio Scio, №2

La 1a eldono: %%Jekaterinburgo%% Ruslanda Esperantisto, 1995.
La 2a eldono: %%Kaliningrado%%: Sezonoj; %%Kaunas: LEA, 2015.%%
"""
# プレースホルダーファイルから読み込む
placeholders = load_placeholders('No.1000_9999.txt')
# リストを作成
replacements_list_for_intact_parts = create_replacements(text, placeholders)
sorted_replacements_list_for_intact_parts = sorted(replacements_list_for_intact_parts, key=lambda x: len(x[0]), reverse=True)
# 結果を表示
# for item in sorted_replacements_list_for_intact_parts:
#     print(item)

# %%
with open('例文4.txt','r') as g:
    ll=g.read()
text2=replace_esperanto_chars(ll,esperanto_to_x)

replacements_list_for_intact_parts = create_replacements(text2, placeholders)
sorted_replacements_list_for_intact_parts = sorted(replacements_list_for_intact_parts, key=lambda x: len(x[0]), reverse=True)
for original, place_holder_ in sorted_replacements_list_for_intact_parts:
    text2 = text2.replace(original, place_holder_)

text3=safe_replace(text2, replacements3)

for original, place_holder_ in sorted_replacements_list_for_intact_parts:
    text3 = text3.replace(place_holder_, original.replace("%%",""))

# text3=parallel_process(text2*1,1, replacements2)
with open('出力4.html','w', encoding='utf-8') as h:
    h.write(text3)

# %%
sorted_replacements_list_for_intact_parts
# text2
# Out:
# [['%%Lazarj Markovicx Zamenhof%%', '&%1001&%'],
#  ['%%Aleksander Korjxenkov%%', '&%1005&%'],
#  ['%%Aleksander Korjxenkov%%', '&%1007&%'],
#  ['%%Aleksander Korjxenkov%%', '&%1010&%'],
#  ['%%Aleksander Korjxenkov%%', '&%1011&%'],
#  ['%%Aleksander Korjxenkov%%', '&%1012&%'],
#  ['%%Aleksander Korjxenkov%%', '&%1013&%'],
#  ['%%Kaunas: LEA, 2015.%%', '&%1004&%'],
#  ['%%Jekaterinburgo%%', '&%1002&%'],
#  ['%%Halina Gorecka%%', '&%1008&%'],
#  ['%%Halina Gorecka%%', '&%1009&%'],
#  ['%%L. Zamenhof.%%', '&%1000&%'],
#  ['%%Kaliningrado%%', '&%1003&%'],
#  ['%%Alla Dzjuba%%', '&%1006&%']]

# %% [markdown]
# 以下是附录(以下はおまけ)
